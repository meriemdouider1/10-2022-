# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/10-2022-/blob/main/Cs_longia/%20DFS%20(Mcc%20-%20sen%20%26%20spe%20-%20acc)%20xgboost%20backward%20mcc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
Cl1 = '/content/cs-longia.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
data
# Out:
#      Cs_longia     X_long      Y_lat    Bovins    Volaille   Caprins  \
# 0            1 -15.911420  23.794740  0.000000    0.000000  0.000000
# 1            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 2            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 3            0 -13.185620  27.157940  0.000000    0.000000  0.000000
# 4            0 -13.167180  27.157730  0.000000    0.000000  0.000000
# ..         ...        ...        ...       ...         ...       ...
# 249          1  -5.366667  35.766667  8.495770  105.550156  8.691405
# 250          1  -5.816667  35.783333  0.000000    0.000000  0.000000
# 251          1  -5.366667  35.833333  7.411978  111.459663  7.364459
# 252          1  -5.558611  35.841944  5.696193    5.641273  0.602672
# 253          1  -5.483333  35.900000  6.839514   15.082421  0.782080
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# ...

# %%
data["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cs_longia']
y = data.Cs_longia

# %%
X
# Out:
#         X_long      Y_lat    Bovins    Volaille   Caprins      Ovins  \
# 0   -15.911420  23.794740  0.000000    0.000000  0.000000   0.000000
# 1   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 2   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 3   -13.185620  27.157940  0.000000    0.000000  0.000000   0.000000
# 4   -13.167180  27.157730  0.000000    0.000000  0.000000   0.000000
# ..         ...        ...       ...         ...       ...        ...
# 249  -5.366667  35.766667  8.495770  105.550156  8.691405  15.116930
# 250  -5.816667  35.783333  0.000000    0.000000  0.000000   0.000000
# 251  -5.366667  35.833333  7.411978  111.459663  7.364459  15.054404
# 252  -5.558611  35.841944  5.696193    5.641273  0.602672   4.306276
# 253  -5.483333  35.900000  6.839514   15.082421  0.782080   6.042903
#
#       Equides  Coniferes  ZoneAride  ZonePel  ...  Vent_Mars  Vent_Avril  \
# ...

# %%
algo =  XGBClassifier(random_state=0,n_jobs=-1)

# %%
clmns=X.columns

# %%
clmns
# Out:
# Index(['X_long', 'Y_lat', 'Bovins', 'Volaille', 'Caprins', 'Ovins', 'Equides',
#        'Coniferes', 'ZoneAride', 'ZonePel',
#        ...
#        'Vent_Mars', 'Vent_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Juill',
#        'Vent_Aout', 'Vent_Sept', 'Vent_Oct', 'Vent_Nov', 'Vent_Dec'],
#       dtype='object', length=225)

# %%
def transform(X, fs) :
  X_ = X.copy()
  for i in range(len(fs)) :
    if fs[i] == False :
      X_.drop([clmns[i]], axis=1, inplace=True)
  return X_

# %%
def Retransform (lst):
  Fs=[]      
  for i in range(225):
    if clmns[i] in lst :
       Fs.append(True)
    else :
       Fs.append(False)
  return Fs

# %%
lst= ['Ovins',
 'Min_IRM',
 'Amp3_TempJ',
 'Max_TempJ',
 'Ph2_TempJ',
 'Var_TempJ',
 'Max_TempN',
 'Amp2_NDVI',
 'Var_EVI',
 'IPT_Min',
 'IPT_Moy',
 'IR_Moy',
 'IR_sd',
 'Bio_Tint',
 'Prec_Juill',
 'Vent_Aout']

# %%
Fs = Retransform (lst)

# %%
Fs
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred) 
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_pos
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)
explored_models = []
scores_mcc = []
models_mm=[]
def explor(fs, mcc, algo) :
  if (sum(fs) < 5 or sum(fs) > 225) :
    return
  explored_models.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models) :
      score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
      mean_score_mcc = np.mean(score_mcc)
      explored_models.append(neighbor)
      if (mean_score_mcc  > mcc  ) :
        models_mm.append(neighbor)
        print("mcc", mean_score_mcc)
        print(len(transform(X,neighbor).columns))
        print(transform(X,neighbor).columns)
        print("-----------")
        scores_mcc.append(mean_score_mcc)
        explor(neighbor, mean_score_mcc, algo)

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)
explored_models2 = []
scores_sensibilite = []
scores_specificite = []
models_mm2=[]
def explor2(fs, sen, spe, algo) :
  if (sum(fs) < 5 or sum(fs) > 225) :
    return
  explored_models2.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models2) :
      score_sensibilite = cross_val_score(algo, transform(X, neighbor) , y, scoring='recall', cv=cv, n_jobs=-1)
      score_specificite = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer, cv=cv, n_jobs=-1)
      mean_score_sensibilite = np.mean(score_sensibilite)
      mean_score_specificite = np.mean(score_specificite)
      explored_models2.append(neighbor)
      if (mean_score_sensibilite  > sen  and  mean_score_specificite > spe) :
        models_mm2.append(neighbor)
        print("sensibilite", mean_score_sensibilite)
        print("specificite", mean_score_specificite)
        print("-----------")
        scores_sensibilite.append(mean_score_sensibilite)
        scores_specificite.append(mean_score_specificite)
        explor2(neighbor, mean_score_sensibilite,mean_score_specificite, algo)

# %%
transform(X,Fs)
# Out:
#          Ovins  Min_IRM  Amp3_TempJ  Max_TempJ  Ph2_TempJ  Var_TempJ  \
# 0     0.000000     2690           7      15012        347          6
# 1     0.034352     3350          31      15609        336         26
# 2     0.034352     3350          31      15609        336         26
# 3     0.000000     2930          23      15502        335         25
# 4     0.000000     2350          33      15560        330         26
# ..         ...      ...         ...        ...        ...        ...
# 249  15.116930      880           5      15505        160         64
# 250   0.000000     1400           1      15319        214         49
# 251  15.054404     1080           6      15318        170         45
# 252   4.306276      620           0          0          0          0
# 253   6.042903      990           2      15087        184         29
#
#      Max_TempN  Amp2_NDVI  Var_EVI  IPT_Min   IPT_Moy     IR_Moy      IR_sd  \
# ...

# %%
classifiers = {
"XGB": XGBClassifier(random_state=0,n_jobs=-1)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  transform(X,Fs), y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  transform(X,Fs), y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, transform(X,Fs), y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, transform(X,Fs), y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, transform(X,Fs), y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, transform(X,Fs), y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  transform(X,Fs), y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  transform(X,Fs), y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  transform(X,Fs), y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  transform(X,Fs), y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  transform(X,Fs), y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# XGB
# Accuracy: [0.76470588 0.80392157 0.8627451  0.80392157 0.8       ]
# moy_accuracy: 0.807059
# -------------------------------------------------
# sensibilité : [0.67741935 0.81818182 0.8        0.85       0.75      ]
# moy_sensibilité: 0.779120
# -------------------------------------------------
# spécificité : [0.9        0.79310345 0.95238095 0.77419355 0.84615385]
# moy_spécificité: 0.853166
# -------------------------------------------------
# MCC : [0.56655783 0.60655022 0.74071542 0.61055897 0.60001249]
# MCC: 0.624879
# -------------------------------------------------
# precision-po: [0.91304348 0.75       0.96       0.70833333 0.81818182]
# moy_precision-po: 0.829912
# -------------------------------------------------
# precision-ne : [0.64285714 0.85185185 0.76923077 0.88888889 0.78571429]
# moy_precision-ne: 0.787709
# -------------------------------------------------
# AUC : [0.79758065 0.85815047 0.92857143 0.91612903 0.89102564]
# moy_AUC: 0.878291
# ...

# %%
explor(Fs,0.624879,algo)
# Out:
# mcc 0.6299892039937641
# 17
# Index(['Ovins', 'Min_IRM', 'Amp3_TempJ', 'Max_TempJ', 'Ph2_TempJ', 'Var_TempJ',
#        'Max_TempN', 'Amp2_NDVI', 'VarT_tri_EVI', 'Var_EVI', 'IPT_Min',
#        'IPT_Moy', 'IR_Moy', 'IR_sd', 'Bio_Tint', 'Prec_Juill', 'Vent_Aout'],
#       dtype='object')
# -----------
# mcc 0.6342834593162967
# 18
# Index(['Ovins', 'Lesfeuillus', 'Min_IRM', 'Amp3_TempJ', 'Max_TempJ',
#        'Ph2_TempJ', 'Var_TempJ', 'Max_TempN', 'Amp2_NDVI', 'VarT_tri_EVI',
#        'Var_EVI', 'IPT_Min', 'IPT_Moy', 'IR_Moy', 'IR_sd', 'Bio_Tint',
#        'Prec_Juill', 'Vent_Aout'],
#       dtype='object')
# -----------
# mcc 0.6376161984730254
# 19
# Index(['Ovins', 'Lesfeuillus', 'Pl_herb', 'Min_IRM', 'Amp3_TempJ', 'Max_TempJ',
#        'Ph2_TempJ', 'Var_TempJ', 'Max_TempN', 'Amp2_NDVI', 'VarT_tri_EVI',
#        'Var_EVI', 'IPT_Min', 'IPT_Moy', 'IR_Moy', 'IR_sd', 'Bio_Tint',
#        'Prec_Juill', 'Vent_Aout'],
#       dtype='object')
# -----------
# mcc 0.637875945040969
# 20
# ...

# %%
len(explored_models)
# Out:
# 30275

# %%
len(models_mm)
# Out:
# 146

# %%
models_mm
# Out:
# [[False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
# ...

# %%
max(scores_mcc)
# Out:
# 0.7092107916698529

# %%
scores_mcc

# %%
scores_mcc[36]
# Out:
# 0.7092107916698529

# %%
scores_mcc[37]
# Out:
# 0.7092107916698529

# %%
# evaluate model
scores1 = cross_val_score(algo, transform(X, models_mm[36]), y, scoring='accuracy', cv=cv, n_jobs=-1)
scores2 = cross_val_score(algo, transform(X, models_mm[36]), y, scoring='recall', cv=cv, n_jobs=-1)
scores3 = cross_val_score(algo, transform(X, models_mm[36]), y, scoring=my_scorer, cv=cv, n_jobs=-1)
scores4 = cross_val_score(algo, transform(X, models_mm[36]), y, scoring=my_scorer1, cv=cv, n_jobs=-1)
scores5 = cross_val_score(algo, transform(X, models_mm[36]), y, scoring=my_scorer2, cv=cv, n_jobs=-1)
scores6 = cross_val_score(algo, transform(X, models_mm[36]), y, scoring=my_scorer3, cv=cv, n_jobs=-1)
scores7 = cross_val_score(algo, transform(X, models_mm[36]), y, scoring='roc_auc', cv=cv, n_jobs=-1)
scores8 = cross_val_score(algo, transform(X, models_mm[36]), y, scoring=my_scorer4, cv=cv, n_jobs=-1)
scores9 = cross_val_score(algo, transform(X, models_mm[36]), y, scoring=my_scorer5, cv=cv, n_jobs=-1)
scores10 = cross_val_score(algo, transform(X, models_mm[36]), y, scoring=my_scorer6, cv=cv, n_jobs=-1)
scores11 = cross_val_score(algo, transform(X, models_mm[36]), y, scoring=my_scorer7, cv=cv, n_jobs=-1)
# report performance
print('Accuracy:',scores1)
print('moy_accuracy:',mean(scores1))
print("-------------------------------------------------")
print('sensibilité :',scores2)
print('moy_sensibilité: ',mean(scores2))
print("-------------------------------------------------")
print('spécificité :',scores3)
print('moy_spécificité:',mean(scores3))
print("-------------------------------------------------")
print('MCC :',scores4)
print('MCC: ',mean(scores4))
print("-------------------------------------------------")
print('precision-po:',scores5)
print('moy_precision-po:', mean(scores5))
print("-------------------------------------------------")
print('precision-ne :',scores6)
print('moy_precision-ne:',mean(scores6))
print("-------------------------------------------------")
print('AUC :',scores7)
print('moy_AUC: ',mean(scores7))
print("-------------------------------------------------")
print('VN :',scores8)
print('VP :',scores9)
print('FP :',scores10)
print('FN :',scores11)
print("-------------------------------------------------")
print("-------------------------------------------------")
# Out:
# Accuracy: [0.80392157 0.8627451  0.92156863 0.84313725 0.82      ]
# moy_accuracy: 0.8502745098039217
# -------------------------------------------------
# sensibilité : [0.70967742 0.86363636 0.9        0.9        0.75      ]
# moy_sensibilité:  0.8246627565982404
# -------------------------------------------------
# spécificité : [0.95       0.86206897 0.95238095 0.80645161 0.88461538]
# moy_spécificité: 0.891103383083361
# -------------------------------------------------
# MCC : [0.64726859 0.7223168  0.84306503 0.69102023 0.6423833 ]
# MCC:  0.7092107916698529
# -------------------------------------------------
# precision-po: [0.95652174 0.82608696 0.96428571 0.75       0.85714286]
# moy_precision-po: 0.870807453416149
# -------------------------------------------------
# precision-ne : [0.67857143 0.89285714 0.86956522 0.92592593 0.79310345]
# moy_precision-ne: 0.8320046326043329
# -------------------------------------------------
# ...

# %%
# evaluate model
scores1 = cross_val_score(algo, transform(X, models_mm[37]), y, scoring='accuracy', cv=cv, n_jobs=-1)
scores2 = cross_val_score(algo, transform(X, models_mm[37]), y, scoring='recall', cv=cv, n_jobs=-1)
scores3 = cross_val_score(algo, transform(X, models_mm[37]), y, scoring=my_scorer, cv=cv, n_jobs=-1)
scores4 = cross_val_score(algo, transform(X, models_mm[37]), y, scoring=my_scorer1, cv=cv, n_jobs=-1)
scores5 = cross_val_score(algo, transform(X, models_mm[37]), y, scoring=my_scorer2, cv=cv, n_jobs=-1)
scores6 = cross_val_score(algo, transform(X, models_mm[37]), y, scoring=my_scorer3, cv=cv, n_jobs=-1)
scores7 = cross_val_score(algo, transform(X, models_mm[37]), y, scoring='roc_auc', cv=cv, n_jobs=-1)
scores8 = cross_val_score(algo, transform(X, models_mm[37]), y, scoring=my_scorer4, cv=cv, n_jobs=-1)
scores9 = cross_val_score(algo, transform(X, models_mm[37]), y, scoring=my_scorer5, cv=cv, n_jobs=-1)
scores10 = cross_val_score(algo, transform(X, models_mm[37]), y, scoring=my_scorer6, cv=cv, n_jobs=-1)
scores11 = cross_val_score(algo, transform(X, models_mm[37]), y, scoring=my_scorer7, cv=cv, n_jobs=-1)
# report performance
print('Accuracy:',scores1)
print('moy_accuracy:',mean(scores1))
print("-------------------------------------------------")
print('sensibilité :',scores2)
print('moy_sensibilité: ',mean(scores2))
print("-------------------------------------------------")
print('spécificité :',scores3)
print('moy_spécificité:',mean(scores3))
print("-------------------------------------------------")
print('MCC :',scores4)
print('MCC: ',mean(scores4))
print("-------------------------------------------------")
print('precision-po:',scores5)
print('moy_precision-po:', mean(scores5))
print("-------------------------------------------------")
print('precision-ne :',scores6)
print('moy_precision-ne:',mean(scores6))
print("-------------------------------------------------")
print('AUC :',scores7)
print('moy_AUC: ',mean(scores7))
print("-------------------------------------------------")
print('VN :',scores8)
print('VP :',scores9)
print('FP :',scores10)
print('FN :',scores11)
print("-------------------------------------------------")
print("-------------------------------------------------")
# Out:
# Accuracy: [0.80392157 0.8627451  0.92156863 0.84313725 0.82      ]
# moy_accuracy: 0.8502745098039217
# -------------------------------------------------
# sensibilité : [0.70967742 0.86363636 0.9        0.9        0.75      ]
# moy_sensibilité:  0.8246627565982404
# -------------------------------------------------
# spécificité : [0.95       0.86206897 0.95238095 0.80645161 0.88461538]
# moy_spécificité: 0.891103383083361
# -------------------------------------------------
# MCC : [0.64726859 0.7223168  0.84306503 0.69102023 0.6423833 ]
# MCC:  0.7092107916698529
# -------------------------------------------------
# precision-po: [0.95652174 0.82608696 0.96428571 0.75       0.85714286]
# moy_precision-po: 0.870807453416149
# -------------------------------------------------
# precision-ne : [0.67857143 0.89285714 0.86956522 0.92592593 0.79310345]
# moy_precision-ne: 0.8320046326043329
# -------------------------------------------------
# ...

# %% [markdown]
# # Nouvelle section (explor 2 terminé)

# %%
explor2(Fs, 0.779120,0.853166, algo)
# Out:
# sensibilite 0.7791202346041056
# specificite 0.8531663590395514
# -----------
# sensibilite 0.7798778103616814
# specificite 0.8596179719427772
# -----------
# sensibilite 0.7791202346041056
# specificite 0.8531663590395514
# -----------
# sensibilite 0.7798778103616814
# specificite 0.8596179719427772
# -----------
# sensibilite 0.7793352883675465
# specificite 0.8539621150077213
# -----------
# sensibilite 0.790850439882698
# specificite 0.860413727910947
# -----------
# sensibilite 0.7817595307917888
# specificite 0.8608586667318591
# -----------
# sensibilite 0.7817595307917888
# specificite 0.8608586667318591
# -----------
# sensibilite 0.7791202346041056
# specificite 0.8531663590395514
# -----------
# sensibilite 0.7798778103616814
# specificite 0.8596179719427772
# -----------
# sensibilite 0.7793352883675465
# specificite 0.8539621150077213
# -----------
# sensibilite 0.790850439882698
# specificite 0.860413727910947
# -----------
# sensibilite 0.7817595307917888
# ...

# %%
len(explored_models2)
# Out:
# 5328

# %%
models_mm2
# Out:
# [[False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
# ...

# %% [markdown]
# # DFS _ACCURACY

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)
explored_models3 = []
scores_accuracy = []
models_mm3=[]
def explor3(fs, acc, algo) :
  if (sum(fs) < 5 or sum(fs) > 225) :
    return
  explored_models3.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models3) :
      score_acc = cross_val_score(algo, transform(X, neighbor) , y, scoring="accuracy", cv=cv, n_jobs=-1)
      mean_score_acc = np.mean(score_acc)
      explored_models3.append(neighbor)
      if (mean_score_acc  > acc) :
        models_mm3.append(neighbor)
        print("accuarcy", mean_score_acc)
        print(len(transform(X,neighbor).columns))
        print(transform(X,neighbor).columns)
        print("-----------")
        scores_accuracy.append(mean_score_acc)
        explor3(neighbor, mean_score_acc, algo)

# %%
explor3(Fs,0.807059,algo)
# Out:
# accuarcy 0.8109803921568627
# 17
# Index(['Ovins', 'Min_IRM', 'Amp3_TempJ', 'Max_TempJ', 'Ph2_TempJ', 'Var_TempJ',
#        'Max_TempN', 'Amp2_NDVI', 'VarT_tri_EVI', 'Var_EVI', 'IPT_Min',
#        'IPT_Moy', 'IR_Moy', 'IR_sd', 'Bio_Tint', 'Prec_Juill', 'Vent_Aout'],
#       dtype='object')
# -----------
# accuarcy 0.8111372549019608
# 18
# Index(['Ovins', 'Pl_herb', 'Min_IRM', 'Amp3_TempJ', 'Max_TempJ', 'Ph2_TempJ',
#        'Var_TempJ', 'Max_TempN', 'Amp2_NDVI', 'VarT_tri_EVI', 'Var_EVI',
#        'IPT_Min', 'IPT_Moy', 'IR_Moy', 'IR_sd', 'Bio_Tint', 'Prec_Juill',
#        'Vent_Aout'],
#       dtype='object')
# -----------
# accuarcy 0.8189803921568627
# 19
# Index(['Ovins', 'Coniferes', 'Pl_herb', 'Min_IRM', 'Amp3_TempJ', 'Max_TempJ',
#        'Ph2_TempJ', 'Var_TempJ', 'Max_TempN', 'Amp2_NDVI', 'VarT_tri_EVI',
#        'Var_EVI', 'IPT_Min', 'IPT_Moy', 'IR_Moy', 'IR_sd', 'Bio_Tint',
#        'Prec_Juill', 'Vent_Aout'],
#       dtype='object')
# -----------
# ...

# %%
lst_acc=['Ovins', 'Equides', 'Lesfeuillus', 'Caduc', 'Pl_herb', 'VarT_tri_IRM',
       'Min_IRM', 'Amp3_TempJ', 'Max_TempJ', 'Ph2_TempJ', 'Var_TempJ',
       'Max_TempN', 'Ph1_TempN', 'Amp2_NDVI', 'VarT_tri_EVI', 'Var_EVI',
       'Geom_maj', 'IPT_Min', 'IPT_Moy', 'IR_Moy', 'IR_sd', 'Bio_Tmax',
       'Bio_Tint', 'Prec_Mars', 'Prec_Juill', 'Tmax_Aout', 'Vent_Aout']

# %%
X[lst_acc]
# Out:
#          Ovins   Equides  Lesfeuillus  Caduc  Pl_herb  VarT_tri_IRM  Min_IRM  \
# 0     0.000000  0.624435            0      0        0             0     2690
# 1     0.034352  0.040295            0      0        0             0     3350
# 2     0.034352  0.040295            0      0        0             0     3350
# 3     0.000000  0.269410            0      0        0             0     2930
# 4     0.000000  0.379107            0      0        0             0     2350
# ..         ...       ...          ...    ...      ...           ...      ...
# 249  15.116930  0.698221            0     18        0             0      880
# 250   0.000000  1.725019            0      0        0             0     1400
# 251  15.054404  0.991284            0      8        0             0     1080
# 252   4.306276  0.000000            0      0       12             0      620
# 253   6.042903  0.595441           22     11       12             0      990
#
# ...

# %%
# evaluate model
scores1 = cross_val_score(algo, X[lst_acc], y, scoring='accuracy', cv=cv, n_jobs=-1)
scores2 = cross_val_score(algo, X[lst_acc], y, scoring='recall', cv=cv, n_jobs=-1)
scores3 = cross_val_score(algo, X[lst_acc], y, scoring=my_scorer, cv=cv, n_jobs=-1)
scores4 = cross_val_score(algo, X[lst_acc], y, scoring=my_scorer1, cv=cv, n_jobs=-1)
scores5 = cross_val_score(algo, X[lst_acc], y, scoring=my_scorer2, cv=cv, n_jobs=-1)
scores6 = cross_val_score(algo, X[lst_acc], y, scoring=my_scorer3, cv=cv, n_jobs=-1)
scores7 = cross_val_score(algo, X[lst_acc], y, scoring='roc_auc', cv=cv, n_jobs=-1)
scores8 = cross_val_score(algo, X[lst_acc], y, scoring=my_scorer4, cv=cv, n_jobs=-1)
scores9 = cross_val_score(algo, X[lst_acc], y, scoring=my_scorer5, cv=cv, n_jobs=-1)
scores10 = cross_val_score(algo, X[lst_acc], y, scoring=my_scorer6, cv=cv, n_jobs=-1)
scores11 = cross_val_score(algo, X[lst_acc], y, scoring=my_scorer7, cv=cv, n_jobs=-1)
# report performance
print('Accuracy:',scores1)
print('moy_accuracy:',mean(scores1))
print("-------------------------------------------------")
print('sensibilité :',scores2)
print('moy_sensibilité: ',mean(scores2))
print("-------------------------------------------------")
print('spécificité :',scores3)
print('moy_spécificité:',mean(scores3))
print("-------------------------------------------------")
print('MCC :',scores4)
print('MCC: ',mean(scores4))
print("-------------------------------------------------")
print('precision-po:',scores5)
print('moy_precision-po:', mean(scores5))
print("-------------------------------------------------")
print('precision-ne :',scores6)
print('moy_precision-ne:',mean(scores6))
print("-------------------------------------------------")
print('AUC :',scores7)
print('moy_AUC: ',mean(scores7))
print("-------------------------------------------------")
print('VN :',scores8)
print('VP :',scores9)
print('FP :',scores10)
print('FN :',scores11)
print("-------------------------------------------------")
print("-------------------------------------------------")
# Out:
# Accuracy: [0.74509804 0.8627451  0.90196078 0.84313725 0.86      ]
# moy_accuracy: 0.8425882352941176
# -------------------------------------------------
# sensibilité : [0.64516129 0.95454545 0.86666667 0.85       0.83333333]
# moy_sensibilité:  0.8299413489736069
# -------------------------------------------------
# spécificité : [0.9        0.79310345 0.95238095 0.83870968 0.88461538]
# moy_spécificité: 0.8737618925383106
# -------------------------------------------------
# MCC : [0.53741591 0.74185758 0.80759184 0.67892483 0.7196808 ]
# MCC:  0.6970941917199986
# -------------------------------------------------
# precision-po: [0.90909091 0.77777778 0.96296296 0.77272727 0.86956522]
# moy_precision-po: 0.8584248279900454
# -------------------------------------------------
# precision-ne : [0.62068966 0.95833333 0.83333333 0.89655172 0.85185185]
# moy_precision-ne: 0.8321519795657727
# -------------------------------------------------
# ...
