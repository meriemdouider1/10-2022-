# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/10-2022--12-2022/blob/main/Cs_longia/%20DFS%20MCC%20(MOD%C3%88LE%201%26%20MOD%C3%88LE%202%20%3E%200.74)%20gradient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # -----

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
Cl1 = '/content/cs-longia.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
data
# Out:
#      Cs_longia     X_long      Y_lat    Bovins    Volaille   Caprins  \
# 0            1 -15.911420  23.794740  0.000000    0.000000  0.000000
# 1            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 2            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 3            0 -13.185620  27.157940  0.000000    0.000000  0.000000
# 4            0 -13.167180  27.157730  0.000000    0.000000  0.000000
# ..         ...        ...        ...       ...         ...       ...
# 249          1  -5.366667  35.766667  8.495770  105.550156  8.691405
# 250          1  -5.816667  35.783333  0.000000    0.000000  0.000000
# 251          1  -5.366667  35.833333  7.411978  111.459663  7.364459
# 252          1  -5.558611  35.841944  5.696193    5.641273  0.602672
# 253          1  -5.483333  35.900000  6.839514   15.082421  0.782080
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.269410          0        100  ...        5.1         5.6
# 4     0.000000  0.379107          0        100  ...        5.0         5.2
# ..         ...       ...        ...        ...  ...        ...         ...
# 249  15.116930  0.698221          0          0  ...        4.6         4.3
# 250   0.000000  1.725019          0          0  ...        4.6         4.1
# 251  15.054404  0.991284          0          0  ...        4.5         4.3
# 252   4.306276  0.000000          0          0  ...        4.6         4.0
# 253   6.042903  0.595441          0          0  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 226 columns]

# %%
data["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cs_longia']
y = data.Cs_longia

# %%
X
# Out:
#         X_long      Y_lat    Bovins    Volaille   Caprins      Ovins  \
# 0   -15.911420  23.794740  0.000000    0.000000  0.000000   0.000000
# 1   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 2   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 3   -13.185620  27.157940  0.000000    0.000000  0.000000   0.000000
# 4   -13.167180  27.157730  0.000000    0.000000  0.000000   0.000000
# ..         ...        ...       ...         ...       ...        ...
# 249  -5.366667  35.766667  8.495770  105.550156  8.691405  15.116930
# 250  -5.816667  35.783333  0.000000    0.000000  0.000000   0.000000
# 251  -5.366667  35.833333  7.411978  111.459663  7.364459  15.054404
# 252  -5.558611  35.841944  5.696193    5.641273  0.602672   4.306276
# 253  -5.483333  35.900000  6.839514   15.082421  0.782080   6.042903
#
#       Equides  Coniferes  ZoneAride  ZonePel  ...  Vent_Mars  Vent_Avril  \
# 0    0.624435          0         97        3  ...        6.1         6.9
# 1    0.040295          0        100        0  ...        4.8         5.6
# 2    0.040295          0        100        0  ...        4.8         5.6
# 3    0.269410          0        100        0  ...        5.1         5.6
# 4    0.379107          0        100        0  ...        5.0         5.2
# ..        ...        ...        ...      ...  ...        ...         ...
# 249  0.698221          0          0        0  ...        4.6         4.3
# 250  1.725019          0          0        0  ...        4.6         4.1
# 251  0.991284          0          0        0  ...        4.5         4.3
# 252  0.000000          0          0       58  ...        4.6         4.0
# 253  0.595441          0          0        5  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 225 columns]

# %% [markdown]
# # ------

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred) 
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_pos
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %%
lst= ['X_long', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'Geom_maj', 'IR_sd','Bio_Tint', 'Prec_Juill','Tmax_Janv','Tmax_Avril','Tmax_Sept','Tmin_Avril','Tmin_Juin']

# %%
X1=X[lst]

# %%
classifiers = {
"Gradient_boosting": GradientBoostingClassifier(random_state=0)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  X1, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  X1, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X1, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X1, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, X1, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, X1, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  X1, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  X1, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  X1, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  X1, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  X1, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# Gradient_boosting
# Accuracy: [0.82352941 0.8627451  0.74509804 0.8627451  0.8       ]
# moy_accuracy: 0.818824
# -------------------------------------------------
# sensibilité : [0.77419355 0.86363636 0.66666667 0.9        0.83333333]
# moy_sensibilité: 0.807566
# -------------------------------------------------
# spécificité : [0.9        0.86206897 0.85714286 0.83870968 0.76923077]
# moy_spécificité: 0.845430
# -------------------------------------------------
# MCC : [0.65845145 0.7223168  0.51808466 0.72481421 0.6025641 ]
# MCC: 0.645246
# -------------------------------------------------
# precision-po: [0.92307692 0.82608696 0.86956522 0.7826087  0.76923077]
# moy_precision-po: 0.834114
# -------------------------------------------------
# precision-ne : [0.72       0.89285714 0.64285714 0.92857143 0.83333333]
# moy_precision-ne: 0.803524
# -------------------------------------------------
# AUC : [0.87419355 0.89733542 0.82380952 0.91935484 0.83974359]
# moy_AUC: 0.870887
# -------------------------------------------------
# VN : [18 25 18 26 20]
# VP : [24 19 20 18 20]
# FP : [2 4 3 5 6]
# FN : [ 7  3 10  2  4]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # DFS

# %%
clmns=X.columns

# %%
clmns
# Out:
# Index(['X_long', 'Y_lat', 'Bovins', 'Volaille', 'Caprins', 'Ovins', 'Equides',
#        'Coniferes', 'ZoneAride', 'ZonePel',
#        ...
#        'Vent_Mars', 'Vent_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Juill',
#        'Vent_Aout', 'Vent_Sept', 'Vent_Oct', 'Vent_Nov', 'Vent_Dec'],
#       dtype='object', length=225)

# %%
def transform(X, fs) :
  X_ = X.copy()
  for i in range(len(fs)) :
    if fs[i] == False :
      X_.drop([clmns[i]], axis=1, inplace=True)
  return X_

# %%
def Retransform (lst):
  Fs=[]      
  for i in range(225):
    if clmns[i] in lst :
       Fs.append(True)
    else :
       Fs.append(False)
  return Fs

# %%
Fs_mcc = Retransform (lst)

# %%
Fs_mcc
# Out:
# [True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
transform(X,Fs_mcc)
# Out:
#         X_long  VegInond  Min_IRM  VarT_cy_TempJ  Geom_maj      IR_sd  \
# 0   -15.911420         0     2690             53         1   0.899761
# 1   -13.188370         0     3350             87         1   0.397748
# 2   -13.188370         0     3350             87         1   0.397748
# 3   -13.185620         0     2930             85         6   1.639937
# 4   -13.167180         0     2350             77         8   3.913587
# ..         ...       ...      ...            ...       ...        ...
# 249  -5.366667         0      880             94         6   2.176535
# 250  -5.816667         0     1400             95         6   1.735360
# 251  -5.366667         0     1080             93         5   3.989664
# 252  -5.558611        11      620              0         1  12.156531
# 253  -5.483333         0      990             92         9  19.463408
#
#       Bio_Tint  Prec_Juill  Tmax_Janv  Tmax_Avril  Tmax_Sept  Tmin_Avril  \
# 0    12.000000           1       21.5   22.600000  26.500000        15.6
# 1    17.700001           0       21.9   24.600000  29.200001        14.7
# 2    17.700001           0       21.9   24.600000  29.200001        14.7
# 3    17.400001           0       21.9   24.600000  29.200001        15.0
# 4    17.500000           0       22.0   24.700001  29.400000        15.2
# ..         ...         ...        ...         ...        ...         ...
# 249  18.300001           1       15.2   18.900000  25.700001        13.1
# 250  17.699999           1       14.5   18.700001  25.700001        13.9
# 251  18.200001           1       15.3   18.900000  25.600000        12.9
# 252  18.299999           1       16.6   19.799999  25.500000        11.7
# 253  17.700000           1       16.0   19.000000  24.799999        11.8
#
#      Tmin_Juin
# 0    17.299999
# 1    17.299999
# 2    17.299999
# 3    17.600000
# 4    17.700001
# ..         ...
# 249  18.500000
# 250  19.400000
# 251  18.400000
# 252  16.700001
# 253  16.600000
#
# [254 rows x 13 columns]

# %%
classifiers = {
"Gradient_boosting": GradientBoostingClassifier(random_state=0)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, transform(X,Fs_mcc), y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, transform(X,Fs_mcc), y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, transform(X,Fs_mcc), y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, transform(X,Fs_mcc), y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('moy_MCC: %f' %mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# Gradient_boosting
# Accuracy: [0.82352941 0.8627451  0.74509804 0.8627451  0.8       ]
# moy_accuracy: 0.818824
# -------------------------------------------------
# sensibilité : [0.77419355 0.86363636 0.66666667 0.9        0.83333333]
# moy_sensibilité: 0.807566
# -------------------------------------------------
# spécificité : [0.9        0.86206897 0.85714286 0.83870968 0.76923077]
# moy_spécificité: 0.845430
# -------------------------------------------------
# MCC : [0.65845145 0.7223168  0.51808466 0.72481421 0.6025641 ]
# moy_MCC: 0.645246
# -------------------------------------------------
# precision-po: [0.92307692 0.82608696 0.86956522 0.7826087  0.76923077]
# moy_precision-po: 0.834114
# -------------------------------------------------
# precision-ne : [0.72       0.89285714 0.64285714 0.92857143 0.83333333]
# moy_precision-ne: 0.803524
# -------------------------------------------------
# AUC : [0.87419355 0.89733542 0.82380952 0.91935484 0.83974359]
# moy_AUC: 0.870887
# -------------------------------------------------
# VN : [18 25 18 26 20]
# VP : [24 19 20 18 20]
# FP : [2 4 3 5 6]
# FN : [ 7  3 10  2  4]
# -------------------------------------------------
# -------------------------------------------------

# %%
algo= GradientBoostingClassifier(random_state=0)

# %% [markdown]
# #dfs mcc

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)
explored_models_mcc = []
scores_mcc = []
models_mm_mcc=[]
def explor_mcc(fs, mcc, algo) :
  if (sum(fs) < 5 or sum(fs) > 225) :
    return
  explored_models_mcc.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models_mcc) :
      score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
      mean_score_mcc = np.mean(score_mcc)
      explored_models_mcc.append(neighbor)
      if (mean_score_mcc  > mcc) :
        models_mm_mcc.append(neighbor)
        print("mcc : %f" % mean_score_mcc)
        print(len(transform(X,neighbor).columns))
        print(transform(X,neighbor).columns)
        print("-----------")
        scores_mcc.append(mean_score_mcc)
        explor_mcc(neighbor, mean_score_mcc, algo)

# %%
explor_mcc(Fs_mcc,0.645246,algo)
# Out:
# mcc : 0.679321
# 14
# Index(['X_long', 'ZoneAride', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.687894
# 15
# Index(['X_long', 'ZoneAride', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ',
#        'Ph1_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.689175
# 16
# Index(['X_long', 'ZoneAride', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Ph1_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.691237
# 15
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Ph1_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.718596
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'VarT_bi_TempN', 'Ph1_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.695102
# 14
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.710860
# 15
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.726476
# 14
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.711700
# 15
# Index(['X_long', 'Lesfeuillus', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.702971
# 13
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.704943
# 14
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.705186
# 15
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.706174
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.710860
# 16
# Index(['X_long', 'ZonePel', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.707157
# 16
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'RV_Med',
#        'Bio_Tint', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.713458
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'RV_Med',
#        'Bio_Tint', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.717958
# 18
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Var_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd',
#        'RV_Med', 'Bio_Tint', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.729264
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Var_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'RV_Med',
#        'Bio_Tint', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.745628
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Var_TempJ', 'Geom_maj', 'IR_sd', 'RV_Med', 'Bio_Tint', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.718961
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'IR_sd', 'RV_Med', 'Bio_Tint',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.722922
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'IR_sd', 'RV_Med', 'Bio_Tint',
#        'Bio_Tfr_Moy', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.714209
# 18
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'RV_Med',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.717522
# 19
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'RV_Med',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin', 'Vap_Avril'],
#       dtype='object')
# -----------
# mcc : 0.714952
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'RV_Med', 'Bio_Tint',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.726283
# 16
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Var_TempJ', 'Geom_maj', 'IR_sd', 'RV_Med', 'Bio_Tint',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.719307
# 16
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'RV_Med', 'Bio_Tint',
#        'Bio_Pre_sec', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.705089
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmax_Nov', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.707916
# 12
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.713464
# 13
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.713620
# 14
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.718440
# 15
# Index(['X_long', 'ZonePel', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.728207
# 16
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.728207
# 16
# Index(['X_long', 'ZonePel', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.734886
# 17
# Index(['X_long', 'ZonePel', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.737062
# 18
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_TempJ', 'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.737515
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.722716
# 16
# Index(['X_long', 'ZonePel', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Bio_Pre_sec', 'Prec_Avril',
#        'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.714621
# 15
# Index(['X_long', 'VegCul', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.729925
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.725807
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Mars', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.715012
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Mai'],
#       dtype='object')
# -----------
# mcc : 0.723278
# 16
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'Geom_Shan', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Mai'],
#       dtype='object')
# -----------
# mcc : 0.719733
# 16
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_Max', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Mai'],
#       dtype='object')
# -----------
# mcc : 0.722325
# 17
# Index(['X_long', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_Max', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Mai'],
#       dtype='object')
# -----------
# mcc : 0.714985
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Nov'],
#       dtype='object')
# -----------
# mcc : 0.721078
# 16
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Nov'],
#       dtype='object')
# -----------
# mcc : 0.718945
# 14
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Prec_Nov',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.725013
# 15
# Index(['X_long', 'ZoneAride', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Prec_Nov',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.719046
# 13
# Index(['X_long', 'Min_IRM', 'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Prec_Nov', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.733141
# 14
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'Geom_maj', 'IR_sd',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Prec_Nov', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.726840
# 14
# Index(['X_long', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Prec_Nov',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.726840
# 14
# Index(['X_long', 'Min_IRM', 'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Prec_Nov',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.713617
# 14
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Fev', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.714398
# 14
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Vent_Juill'],
#       dtype='object')
# -----------
# mcc : 0.724164
# 15
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Vent_Juill'],
#       dtype='object')
# -----------
# mcc : 0.716590
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Vent_Juill'],
#       dtype='object')
# -----------
# mcc : 0.705186
# 15
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.697228
# 15
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.710749
# 16
# Index(['X_long', 'Coniferes', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.711785
# 15
# Index(['X_long', 'Coniferes', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.704682
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.704959
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.706387
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.720785
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.726840
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.718752
# 18
# Index(['X_long', 'VegInond', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.719011
# 17
# Index(['X_long', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.728163
# 19
# Index(['X_long', 'VegInond', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'RV_Min',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juin', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.712760
# 18
# Index(['X_long', 'VegInond', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin', 'Vap_Mai'],
#       dtype='object')
# -----------
# mcc : 0.721469
# 17
# Index(['X_long', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juin',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin', 'Vap_Mai'],
#       dtype='object')
# -----------
# mcc : 0.713933
# 19
# Index(['X_long', 'VegInond', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'VarT_bi_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin', 'Vap_Mai'],
#       dtype='object')
# -----------
# mcc : 0.713879
# 19
# Index(['X_long', 'VegInond', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin', 'Vap_Mai'],
#       dtype='object')
# -----------
# mcc : 0.705228
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.705792
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Ph1_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.720354
# 18
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Ph1_TempN', 'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.722101
# 19
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Ph1_TempN', 'Geom_maj', 'IR_sd', 'RV_Med', 'RV_Min',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.730454
# 20
# Index(['X_long', 'Caduc', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_TempJ', 'VarT_cy_TempJ', 'Ph1_TempN', 'Geom_maj', 'IR_sd',
#        'RV_Med', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.736844
# 19
# Index(['X_long', 'Caduc', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_TempJ', 'VarT_cy_TempJ', 'Ph1_TempN', 'Geom_maj', 'IR_sd',
#        'RV_Med', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.730635
# 20
# Index(['X_long', 'VegInond', 'Min_IRM', 'Var_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_TempJ', 'VarT_cy_TempJ', 'Ph1_TempN', 'Geom_maj', 'IR_sd',
#        'RV_Med', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.739491
# 20
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Ph1_TempN', 'Geom_maj', 'IR_sd',
#        'RV_Med', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.745165
# 21
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Ph1_TempN', 'Geom_maj', 'Pente_sd',
#        'IR_sd', 'RV_Med', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.722913
# 20
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Ph1_TempN', 'Geom_maj', 'IR_sd', 'RV_Med', 'RV_Min',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin', 'Vap_Sept'],
#       dtype='object')
# -----------
# mcc : 0.729816
# 20
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Ph1_TempN', 'Geom_maj', 'IR_sd', 'RV_Med', 'RV_Min',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin', 'Vap_Oct'],
#       dtype='object')
# -----------
# mcc : 0.738181
# 21
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_TempJ', 'VarT_cy_TempJ', 'Ph1_TempN', 'Geom_maj', 'IR_sd',
#        'RV_Med', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin', 'Vap_Oct'],
#       dtype='object')
# -----------
# mcc : 0.713284
# 18
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Ph1_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Bio_Tfr_Moy', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.712639
# 15
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.712715
# 14
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.735106
# 15
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'Ph1_TempN', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.741645
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'Ph1_TempN', 'Geom_Shan', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.712761
# 15
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_Med', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.713008
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_Med', 'IR_sd', 'Bio_Tint', 'Bio_Tfr_Moy', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.716958
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_Med', 'IR_sd', 'Bio_Tint', 'Bio_Tfr_Moy', 'Bio_Pre_sec',
#        'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.713932
# 15
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.729728
# 16
# Index(['X_long', 'Caduc', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.732288
# 15
# Index(['X_long', 'Caduc', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.734692
# 14
# Index(['X_long', 'Caduc', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'RV_Min',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.735010
# 16
# Index(['X_long', 'Caduc', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'VarT_tri_TempN', 'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.714949
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'RV_Max', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.723817
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'RV_Max', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Mars', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.726847
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'RV_Max',
#        'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Mars', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.718470
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'RV_Min', 'Bio_Tint', 'Bio_Pre_Qsec', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.718658
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Janv', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.727283
# 14
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.733584
# 13
# Index(['X_long', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ', 'IR_sd',
#        'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.727757
# 13
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'RV_Min',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.729360
# 14
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'VarT_cy_TempN',
#        'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.732070
# 15
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'VarT_tri_TempN',
#        'VarT_cy_TempN', 'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.731940
# 15
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'VarT_cy_TempN',
#        'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.715925
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin', 'Vap_Janv'],
#       dtype='object')
# -----------
# mcc : 0.716141
# 17
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin', 'Vap_Janv'],
#       dtype='object')
# -----------
# mcc : 0.719138
# 18
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_bi_TempJ',
#        'VarT_tri_TempJ', 'VarT_cy_TempJ', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin', 'Vap_Janv'],
#       dtype='object')
# -----------
# mcc : 0.723347
# 17
# Index(['X_long', 'Pl_herb', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin', 'Vap_Janv'],
#       dtype='object')
# -----------
# mcc : 0.712950
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ',
#        'VarT_tri_TempJ', 'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.718015
# 14
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.723383
# 15
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Mars', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.730728
# 14
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'IR_sd',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Mars',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.730973
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Mars', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.716590
# 14
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.729408
# 13
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.718015
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.711683
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.713945
# 18
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Bio_Pre_hum',
#        'Prec_Avril', 'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.715223
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.719563
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.720583
# 16
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.723551
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ', 'Geom_maj',
#        'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Prec_Aout',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.726805
# 16
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ', 'Geom_maj',
#        'Pente_sd', 'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.728040
# 16
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ', 'Geom_maj',
#        'IR_sd', 'RV_Min', 'Bio_Tint', 'Bio_Pre_hum', 'Prec_Avril',
#        'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.729329
# 17
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Bio_Pre_hum', 'Prec_Avril', 'Prec_Juill', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.721936
# 17
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mars',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.728311
# 18
# Index(['X_long', 'Moy_IRM', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mars',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.734602
# 16
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Mai'],
#       dtype='object')
# -----------
# mcc : 0.736380
# 17
# Index(['X_long', 'ZonePel', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Mai'],
#       dtype='object')
# -----------
# mcc : 0.753922
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Prec_Aout',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Mai'],
#       dtype='object')
# -----------
# mcc : 0.737786
# 17
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Mai'],
#       dtype='object')
# -----------
# mcc : 0.718814
# 15
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.720398
# 16
# Index(['X_long', 'Equides', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.714718
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Mars', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.723138
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Mars', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.723153
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Mars', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.731447
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Mars', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril'],
#       dtype='object')
# -----------
# mcc : 0.724941
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Mars',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.704679
# 16
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.725115
# 17
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.741376
# 18
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Bio_Pre_Qsec', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.713343
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.715481
# 18
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'Rugosite_Moyenne', 'IR_sd', 'RV_Min',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.724675
# 19
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'Rugosite_Moyenne', 'IR_sd', 'RV_Min',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin', 'Vap_Avril'],
#       dtype='object')
# -----------
# mcc : 0.715375
# 18
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin', 'Tmin_Dec'],
#       dtype='object')
# -----------
# mcc : 0.715835
# 19
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_Med', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin', 'Tmin_Dec'],
#       dtype='object')
# -----------
# mcc : 0.721643
# 19
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'RV_Min', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Mars', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin', 'Tmin_Dec'],
#       dtype='object')
# -----------
# mcc : 0.709921
# 17
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Geom_maj', 'IR_sd', 'RV_Min', 'RV_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.717009
# 16
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_sd', 'RV_Min', 'RV_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.727500
# 17
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj',
#        'IR_Max', 'IR_sd', 'RV_Min', 'RV_sd', 'Bio_Tint', 'Prec_Avril',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril',
#        'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.729439
# 18
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'VarT_tri_TempN', 'Geom_maj', 'IR_Max', 'IR_sd', 'RV_Min', 'RV_sd',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.714737
# 18
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_sd', 'RV_Min', 'RV_sd', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.722748
# 19
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_Max', 'IR_sd', 'RV_Min', 'RV_sd',
#        'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.722900
# 20
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Geom_maj', 'IR_Max', 'IR_sd',
#        'RV_Min', 'RV_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.726719
# 20
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Geom_maj', 'IR_Max', 'IR_sd', 'RV_Min', 'RV_sd',
#        'Bio_Tint', 'Bio_Pre_sec', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# mcc : 0.715243
# 18
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'VarT_tri_TempN', 'Geom_maj', 'IR_sd', 'RV_Min', 'RV_sd', 'Bio_Tint',
#        'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Avril', 'Tmin_Juin'],
#       dtype='object')
# -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-1a59a7eaba69> in <module>
# ----> 1 explor_mcc(Fs_mcc,0.645246,algo)
#
# <ipython-input-21-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-21-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      11     neighbor[i] = not fs[i]
#      12     if (neighbor not in explored_models_mcc) :
# ---> 13       score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
#      14       mean_score_mcc = np.mean(score_mcc)
#      15       explored_models_mcc.append(neighbor)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265     # independent, and that it is pickle-able.
#     266     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267     results = parallel(
#     268         delayed(_fit_and_score)(
#     269             clone(estimator),
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                     return self.__get_result()
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#     441                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
max(scores_mcc)
# Out:
# 0.7539224064765371

# %%
XN=X[['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Geom_maj','IR_sd', 'Bio_Tint', 'Prec_Avril', 'Prec_Juill', 'Prec_Aout',
       'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Avril', 'Tmin_Mai']]

# %%
XN
# Out:
#         X_long  Min_IRM  VarT_ann_TempJ  VarT_cy_TempJ  Geom_maj      IR_sd  \
# 0   -15.911420     2690              30             53         1   0.899761
# 1   -13.188370     3350              74             87         1   0.397748
# 2   -13.188370     3350              74             87         1   0.397748
# 3   -13.185620     2930              74             85         6   1.639937
# 4   -13.167180     2350              66             77         8   3.913587
# ..         ...      ...             ...            ...       ...        ...
# 249  -5.366667      880              92             94         6   2.176535
# 250  -5.816667     1400              94             95         6   1.735360
# 251  -5.366667     1080              91             93         5   3.989664
# 252  -5.558611      620               0              0         1  12.156531
# 253  -5.483333      990              91             92         9  19.463408
#
#       Bio_Tint  Prec_Avril  Prec_Juill  Prec_Aout  Tmax_Janv  Tmax_Avril  \
# 0    12.000000           1           1          3       21.5   22.600000
# 1    17.700001           1           0          0       21.9   24.600000
# 2    17.700001           1           0          0       21.9   24.600000
# 3    17.400001           1           0          0       21.9   24.600000
# 4    17.500000           1           0          0       22.0   24.700001
# ..         ...         ...         ...        ...        ...         ...
# 249  18.300001          58           1          3       15.2   18.900000
# 250  17.699999          65           1          2       14.5   18.700001
# 251  18.200001          58           1          4       15.3   18.900000
# 252  18.299999          62           1          2       16.6   19.799999
# 253  17.700000          62           1          3       16.0   19.000000
#
#      Tmax_Sept  Tmin_Avril   Tmin_Mai
# 0    26.500000        15.6  16.200001
# 1    29.200001        14.7  15.700000
# 2    29.200001        14.7  15.700000
# 3    29.200001        15.0  16.000000
# 4    29.400000        15.2  16.100000
# ..         ...         ...        ...
# 249  25.700001        13.1  15.400000
# 250  25.700001        13.9  16.000000
# 251  25.600000        12.9  15.300000
# 252  25.500000        11.7  13.600000
# 253  24.799999        11.8  13.600000
#
# [254 rows x 15 columns]

# %%
classifiers = {
"Gradient_boosting": GradientBoostingClassifier(random_state=0)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XN, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XN, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XN, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XN, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XN, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XN, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XN, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XN, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XN, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XN, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XN, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# Gradient_boosting
# Accuracy: [0.88235294 0.88235294 0.82352941 0.92156863 0.86      ]
# moy_accuracy: 0.873961
# -------------------------------------------------
# sensibilité : [0.80645161 0.86363636 0.76666667 0.95       0.83333333]
# moy_sensibilité: 0.844018
# -------------------------------------------------
# spécificité : [1.         0.89655172 0.9047619  0.90322581 0.88461538]
# moy_spécificité: 0.917831
# -------------------------------------------------
# MCC : [0.78762135 0.76018809 0.6610182  0.84110359 0.7196808 ]
# MCC: 0.753922
# -------------------------------------------------
# precision-po: [1.         0.86363636 0.92       0.86363636 0.86956522]
# moy_precision-po: 0.903368
# -------------------------------------------------
# precision-ne : [0.76923077 0.89655172 0.73076923 0.96551724 0.85185185]
# moy_precision-ne: 0.842784
# -------------------------------------------------
# AUC : [0.88548387 0.90360502 0.83333333 0.92419355 0.8525641 ]
# moy_AUC: 0.879836
# -------------------------------------------------
# VN : [20 26 19 28 23]
# VP : [25 19 23 19 20]
# FP : [0 3 2 3 3]
# FN : [6 3 7 1 4]
# -------------------------------------------------
# -------------------------------------------------
