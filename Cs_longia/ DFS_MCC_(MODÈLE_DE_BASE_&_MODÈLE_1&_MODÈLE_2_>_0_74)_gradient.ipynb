# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/10-2022--12-2022/blob/main/Cs_longia/%20DFS_MCC_(MOD%C3%88LE_DE_BASE_%26_MOD%C3%88LE_1%26_MOD%C3%88LE_2_%3E_0_74)_gradient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # -----

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
Cl1 = '/content/cs-longia.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
data
# Out:
#      Cs_longia     X_long      Y_lat    Bovins    Volaille   Caprins  \
# 0            1 -15.911420  23.794740  0.000000    0.000000  0.000000
# 1            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 2            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 3            0 -13.185620  27.157940  0.000000    0.000000  0.000000
# 4            0 -13.167180  27.157730  0.000000    0.000000  0.000000
# ..         ...        ...        ...       ...         ...       ...
# 249          1  -5.366667  35.766667  8.495770  105.550156  8.691405
# 250          1  -5.816667  35.783333  0.000000    0.000000  0.000000
# 251          1  -5.366667  35.833333  7.411978  111.459663  7.364459
# 252          1  -5.558611  35.841944  5.696193    5.641273  0.602672
# 253          1  -5.483333  35.900000  6.839514   15.082421  0.782080
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.269410          0        100  ...        5.1         5.6
# 4     0.000000  0.379107          0        100  ...        5.0         5.2
# ..         ...       ...        ...        ...  ...        ...         ...
# 249  15.116930  0.698221          0          0  ...        4.6         4.3
# 250   0.000000  1.725019          0          0  ...        4.6         4.1
# 251  15.054404  0.991284          0          0  ...        4.5         4.3
# 252   4.306276  0.000000          0          0  ...        4.6         4.0
# 253   6.042903  0.595441          0          0  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 226 columns]

# %%
data["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cs_longia']
y = data.Cs_longia

# %%
X
# Out:
#         X_long      Y_lat    Bovins    Volaille   Caprins      Ovins  \
# 0   -15.911420  23.794740  0.000000    0.000000  0.000000   0.000000
# 1   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 2   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 3   -13.185620  27.157940  0.000000    0.000000  0.000000   0.000000
# 4   -13.167180  27.157730  0.000000    0.000000  0.000000   0.000000
# ..         ...        ...       ...         ...       ...        ...
# 249  -5.366667  35.766667  8.495770  105.550156  8.691405  15.116930
# 250  -5.816667  35.783333  0.000000    0.000000  0.000000   0.000000
# 251  -5.366667  35.833333  7.411978  111.459663  7.364459  15.054404
# 252  -5.558611  35.841944  5.696193    5.641273  0.602672   4.306276
# 253  -5.483333  35.900000  6.839514   15.082421  0.782080   6.042903
#
#       Equides  Coniferes  ZoneAride  ZonePel  ...  Vent_Mars  Vent_Avril  \
# 0    0.624435          0         97        3  ...        6.1         6.9
# 1    0.040295          0        100        0  ...        4.8         5.6
# 2    0.040295          0        100        0  ...        4.8         5.6
# 3    0.269410          0        100        0  ...        5.1         5.6
# 4    0.379107          0        100        0  ...        5.0         5.2
# ..        ...        ...        ...      ...  ...        ...         ...
# 249  0.698221          0          0        0  ...        4.6         4.3
# 250  1.725019          0          0        0  ...        4.6         4.1
# 251  0.991284          0          0        0  ...        4.5         4.3
# 252  0.000000          0          0       58  ...        4.6         4.0
# 253  0.595441          0          0        5  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 225 columns]

# %% [markdown]
# # ------

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred) 
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_pos
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %%
lst= ['Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint','Prec_Juill', 'Tmax_Janv', 'Tmax_Avril']

# %%
X1=X[lst]

# %%
classifiers = {
"Gradient_boosting": GradientBoostingClassifier(random_state=0)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  X1, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  X1, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X1, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X1, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, X1, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, X1, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  X1, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  X1, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  X1, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  X1, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  X1, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# Gradient_boosting
# Accuracy: [0.78431373 0.80392157 0.74509804 0.78431373 0.78      ]
# moy_accuracy: 0.779529
# -------------------------------------------------
# sensibilité : [0.70967742 0.86363636 0.66666667 0.8        0.83333333]
# moy_sensibilité: 0.774663
# -------------------------------------------------
# spécificité : [0.9        0.75862069 0.85714286 0.77419355 0.73076923]
# moy_spécificité: 0.804145
# -------------------------------------------------
# MCC : [0.59635993 0.61648638 0.51808466 0.56339271 0.56546349]
# MCC: 0.571957
# -------------------------------------------------
# precision-po: [0.91666667 0.73076923 0.86956522 0.69565217 0.74074074]
# moy_precision-po: 0.790679
# -------------------------------------------------
# precision-ne : [0.66666667 0.88       0.64285714 0.85714286 0.82608696]
# moy_precision-ne: 0.774551
# -------------------------------------------------
# AUC : [0.85241935 0.85658307 0.77301587 0.87419355 0.8349359 ]
# moy_AUC: 0.838230
# -------------------------------------------------
# VN : [18 22 18 24 19]
# VP : [22 19 20 16 20]
# FP : [2 7 3 7 7]
# FN : [ 9  3 10  4  4]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # DFS

# %%
clmns=X.columns

# %%
clmns
# Out:
# Index(['X_long', 'Y_lat', 'Bovins', 'Volaille', 'Caprins', 'Ovins', 'Equides',
#        'Coniferes', 'ZoneAride', 'ZonePel',
#        ...
#        'Vent_Mars', 'Vent_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Juill',
#        'Vent_Aout', 'Vent_Sept', 'Vent_Oct', 'Vent_Nov', 'Vent_Dec'],
#       dtype='object', length=225)

# %%
def transform(X, fs) :
  X_ = X.copy()
  for i in range(len(fs)) :
    if fs[i] == False :
      X_.drop([clmns[i]], axis=1, inplace=True)
  return X_

# %%
def Retransform (lst):
  Fs=[]      
  for i in range(225):
    if clmns[i] in lst :
       Fs.append(True)
    else :
       Fs.append(False)
  return Fs

# %%
Fs_mcc = Retransform (lst)

# %%
Fs_mcc
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
transform(X,Fs_mcc)
# Out:
#      Min_IRM  VarT_cy_TempJ      IR_sd   Bio_Tint  Prec_Juill  Tmax_Janv  \
# 0       2690             53   0.899761  12.000000           1       21.5
# 1       3350             87   0.397748  17.700001           0       21.9
# 2       3350             87   0.397748  17.700001           0       21.9
# 3       2930             85   1.639937  17.400001           0       21.9
# 4       2350             77   3.913587  17.500000           0       22.0
# ..       ...            ...        ...        ...         ...        ...
# 249      880             94   2.176535  18.300001           1       15.2
# 250     1400             95   1.735360  17.699999           1       14.5
# 251     1080             93   3.989664  18.200001           1       15.3
# 252      620              0  12.156531  18.299999           1       16.6
# 253      990             92  19.463408  17.700000           1       16.0
#
#      Tmax_Avril
# 0     22.600000
# 1     24.600000
# 2     24.600000
# 3     24.600000
# 4     24.700001
# ..          ...
# 249   18.900000
# 250   18.700001
# 251   18.900000
# 252   19.799999
# 253   19.000000
#
# [254 rows x 7 columns]

# %%
classifiers = {
"Gradient_boosting": GradientBoostingClassifier(random_state=0)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, transform(X,Fs_mcc), y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, transform(X,Fs_mcc), y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, transform(X,Fs_mcc), y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, transform(X,Fs_mcc), y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  transform(X,Fs_mcc), y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('moy_MCC: %f' %mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# Gradient_boosting
# Accuracy: [0.78431373 0.80392157 0.74509804 0.78431373 0.78      ]
# moy_accuracy: 0.779529
# -------------------------------------------------
# sensibilité : [0.70967742 0.86363636 0.66666667 0.8        0.83333333]
# moy_sensibilité: 0.774663
# -------------------------------------------------
# spécificité : [0.9        0.75862069 0.85714286 0.77419355 0.73076923]
# moy_spécificité: 0.804145
# -------------------------------------------------
# MCC : [0.59635993 0.61648638 0.51808466 0.56339271 0.56546349]
# moy_MCC: 0.571957
# -------------------------------------------------
# precision-po: [0.91666667 0.73076923 0.86956522 0.69565217 0.74074074]
# moy_precision-po: 0.790679
# -------------------------------------------------
# precision-ne : [0.66666667 0.88       0.64285714 0.85714286 0.82608696]
# moy_precision-ne: 0.774551
# -------------------------------------------------
# AUC : [0.85241935 0.85658307 0.77301587 0.87419355 0.8349359 ]
# moy_AUC: 0.838230
# -------------------------------------------------
# VN : [18 22 18 24 19]
# VP : [22 19 20 16 20]
# FP : [2 7 3 7 7]
# FN : [ 9  3 10  4  4]
# -------------------------------------------------
# -------------------------------------------------

# %%
algo= GradientBoostingClassifier(random_state=0)

# %% [markdown]
# #dfs mcc

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)
explored_models_mcc = []
scores_mcc = []
models_mm_mcc=[]
def explor_mcc(fs, mcc, algo) :
  if (sum(fs) < 5 or sum(fs) > 225) :
    return
  explored_models_mcc.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models_mcc) :
      score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
      mean_score_mcc = np.mean(score_mcc)
      explored_models_mcc.append(neighbor)
      if (mean_score_mcc  > mcc) :
        models_mm_mcc.append(neighbor)
        print("mcc : %f" % mean_score_mcc)
        print(len(transform(X,neighbor).columns))
        print(transform(X,neighbor).columns)
        print("-----------")
        scores_mcc.append(mean_score_mcc)
        explor_mcc(neighbor, mean_score_mcc, algo)

# %%
explor_mcc(Fs_mcc,0.571957,algo)
# Out:
# mcc : 0.602843
# 8
# Index(['X_long', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.613411
# 9
# Index(['X_long', 'Y_lat', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.621824
# 10
# Index(['X_long', 'Y_lat', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd',
#        'Bio_Tint', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.625804
# 11
# Index(['X_long', 'Y_lat', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd',
#        'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.632007
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ',
#        'IR_sd', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.643729
# 12
# Index(['X_long', 'Y_lat', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd',
#        'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Mai'],
#       dtype='object')
# -----------
# mcc : 0.666707
# 13
# Index(['X_long', 'Y_lat', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd',
#        'Bio_Tint', 'Bio_Pre_Qsec', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai'],
#       dtype='object')
# -----------
# mcc : 0.650004
# 13
# Index(['X_long', 'Y_lat', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd',
#        'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Rad_Nov', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai'],
#       dtype='object')
# -----------
# mcc : 0.657965
# 14
# Index(['X_long', 'Y_lat', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Rad_Nov', 'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai'],
#       dtype='object')
# -----------
# mcc : 0.668579
# 13
# Index(['X_long', 'Y_lat', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd',
#        'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.672306
# 12
# Index(['X_long', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.690943
# 13
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd',
#        'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.713132
# 14
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd',
#        'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.696191
# 14
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd',
#        'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Nov', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.696293
# 15
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Nov', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.697293
# 14
# Index(['X_long', 'ZonePel', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Nov', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.697329
# 15
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd',
#        'Bio_Tint', 'Bio_Tfr_Moy', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Nov', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.723226
# 12
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd',
#        'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.731265
# 11
# Index(['X_long', 'ZonePel', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.747407
# 12
# Index(['X_long', 'ZonePel', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.725365
# 13
# Index(['X_long', 'ZonePel', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.697034
# 13
# Index(['X_long', 'Pl_herb', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd',
#        'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.699683
# 14
# Index(['X_long', 'Pl_herb', 'VegInond', 'Min_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.708096
# 13
# Index(['X_long', 'Pl_herb', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.712937
# 14
# Index(['X_long', 'Pl_herb', 'Min_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'Bio_Tint', 'Bio_Pre_sec', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.690943
# 11
# Index(['X_long', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.691200
# 12
# Index(['X_long', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.692557
# 13
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'IR_sd',
#        'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.705160
# 14
# Index(['X_long', 'ZoneAride', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.705558
# 15
# Index(['X_long', 'ZoneAride', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.693668
# 14
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.697280
# 15
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Var_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.707756
# 14
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Var_TempN',
#        'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.698359
# 14
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ', 'Var_TempN',
#        'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.708172
# 15
# Index(['X_long', 'ZonePel', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ',
#        'Var_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.711858
# 16
# Index(['X_long', 'ZonePel', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ',
#        'Var_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_sec',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.713319
# 17
# Index(['X_long', 'ZonePel', 'Lesfeuillus', 'VegInond', 'Min_IRM',
#        'VarT_cy_TempJ', 'Var_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_sec', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.714709
# 18
# Index(['X_long', 'ZonePel', 'Lesfeuillus', 'VegInond', 'Min_IRM',
#        'VarT_cy_TempJ', 'Var_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_sec', 'Bio_Pre_Qch', 'Prec_Juin', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.711733
# 15
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_bi_TempJ', 'VarT_cy_TempJ',
#        'Var_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.712345
# 16
# Index(['X_long', 'Lesfeuillus', 'VegInond', 'Min_IRM', 'VarT_bi_TempJ',
#        'VarT_cy_TempJ', 'Var_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.719605
# 17
# Index(['X_long', 'Lesfeuillus', 'VegInond', 'Min_IRM', 'VarT_bi_TempJ',
#        'VarT_cy_TempJ', 'Var_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_sec', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.706045
# 15
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ', 'Var_TempN',
#        'Min_EVI', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.711171
# 16
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ', 'Var_TempN',
#        'Min_EVI', 'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.711810
# 15
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ', 'Var_TempN',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.721523
# 15
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ', 'Var_TempN',
#        'Geom_Shan', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.698890
# 13
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ', 'Var_TempN',
#        'IR_sd', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.713133
# 15
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ', 'Var_TempN',
#        'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmin_Mars', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.707903
# 15
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ', 'Var_TempN',
#        'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmin_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.708760
# 16
# Index(['X_long', 'Lesfeuillus', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ',
#        'Var_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmin_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.715323
# 17
# Index(['X_long', 'Lesfeuillus', 'VegInond', 'Min_IRM', 'VarT_cy_TempJ',
#        'VarT_tri_TempN', 'Var_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmin_Avril',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.708083
# 16
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ', 'Var_TempN',
#        'Geom_maj', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmin_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.697967
# 16
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Var_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.705578
# 17
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Var_TempN', 'IR_sd', 'RV_Moy',
#        'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.712125
# 18
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Var_TempN', 'IR_sd', 'RV_Max',
#        'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.709097
# 17
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Var_TempN', 'Geom_maj', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.706915
# 17
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Var_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.696791
# 15
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.699766
# 16
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.701191
# 17
# Index(['X_long', 'Lesfeuillus', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.705023
# 18
# Index(['X_long', 'Lesfeuillus', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Mai',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.711795
# 19
# Index(['X_long', 'Lesfeuillus', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_sec',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Mai', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.719384
# 20
# Index(['X_long', 'Lesfeuillus', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'IR_Max', 'IR_sd', 'RV_Moy',
#        'Bio_Tint', 'Bio_Pre_sec', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Mai', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.715339
# 18
# Index(['X_long', 'Lesfeuillus', 'VegInond', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Vent_Mai',
#        'Vent_Juin', 'Vent_Nov'],
#       dtype='object')
# -----------
# mcc : 0.716570
# 17
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Vent_Mai', 'Vent_Juin',
#        'Vent_Nov'],
#       dtype='object')
# -----------
# mcc : 0.706304
# 17
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_sec', 'Bio_Pre_Qch',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.714932
# 18
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_sec', 'Bio_Pre_Qsec',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.720310
# 19
# Index(['X_long', 'ZoneAride', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempJ', 'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_sec',
#        'Bio_Pre_Qsec', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.728342
# 17
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'IR_Max',
#        'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_sec', 'Bio_Pre_Qsec',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.715299
# 17
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ', 'IR_Max', 'IR_sd',
#        'RV_Moy', 'Bio_Tint', 'Bio_Pre_sec', 'Bio_Pre_Qsec', 'Bio_Pre_Qch',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.722660
# 18
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_cy_TempJ', 'IR_Max', 'IR_sd',
#        'RV_Moy', 'Bio_Tint', 'Bio_Pre_sec', 'Bio_Pre_Qsec', 'Bio_Pre_Qch',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Mars',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.741416
# 17
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'IR_Max', 'IR_sd',
#        'RV_Moy', 'Bio_Tint', 'Bio_Pre_sec', 'Bio_Pre_Qsec', 'Bio_Pre_Qch',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.732983
# 17
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qsec', 'Bio_Pre_Qch',
#        'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.723849
# 19
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_sec', 'Bio_Pre_Qsec',
#        'Bio_Pre_Qch', 'Prec_Avril', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmax_Sept', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.718976
# 19
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_sec', 'Bio_Pre_Qsec',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmax_Nov', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.719177
# 20
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'VarT_tri_TempN', 'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_sec', 'Bio_Pre_Qsec', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmax_Nov', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.720084
# 21
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'IR_Max', 'IR_sd', 'RV_Moy',
#        'Bio_Tint', 'Bio_Pre_sec', 'Bio_Pre_Qsec', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmax_Nov', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.720911
# 21
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'Var_TempJ', 'VarT_tri_TempN', 'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_sec', 'Bio_Pre_Qsec', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmax_Nov', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.702596
# 15
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.709480
# 16
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Prec_Juin', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.723849
# 16
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Mars', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.739356
# 17
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Mars', 'Tmin_Avril', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.706667
# 16
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmax_Sept', 'Vap_Nov', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.704999
# 17
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_Max', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juin', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.698968
# 15
# Index(['X_long', 'Lesfeuillus', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Nov'],
#       dtype='object')
# -----------
# mcc : 0.705908
# 14
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'IR_sd',
#        'RV_Moy', 'Bio_Tint', 'Bio_Pre_sec', 'Bio_Pre_Qch', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.693167
# 14
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'IR_sd',
#        'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juin', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.698045
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'VarT_tri_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch',
#        'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Vent_Mai',
#        'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.703089
# 16
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'VarT_tri_TempN', 'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Ann',
#        'Bio_Pre_Qch', 'Prec_Juin', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.696497
# 15
# Index(['X_long', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'IR_sd',
#        'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juin', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Mars', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.698373
# 16
# Index(['X_long', 'ZoneAride', 'Min_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ',
#        'IR_sd', 'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juin', 'Prec_Juill',
#        'Tmax_Janv', 'Tmax_Mars', 'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.697106
# 13
# Index(['X_long', 'Min_IRM', 'VarT_cy_TempJ', 'VarT_tri_TempN', 'IR_sd',
#        'RV_Moy', 'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.691688
# 13
# Index(['X_long', 'Min_IRM', 'VarT_cy_TempJ', 'Min_EVI', 'IR_sd', 'RV_Moy',
#        'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.691810
# 13
# Index(['X_long', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmin_Juin',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.692955
# 14
# Index(['X_long', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Tmin_Juin',
#        'Vent_Mars', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.696276
# 13
# Index(['X_long', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'RV_Moy', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril', 'Vent_Fev',
#        'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.697422
# 14
# Index(['X_long', 'ZoneAride', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'RV_Moy',
#        'Bio_Tint', 'Bio_Pre_Qch', 'Prec_Juill', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Fev', 'Vent_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-9179fcc02116> in <module>
# ----> 1 explor_mcc(Fs_mcc,0.571957,algo)
#
# <ipython-input-22-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-22-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-22-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-22-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-22-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-22-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-22-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-22-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-22-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-22-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-22-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      21         print("-----------")
#      22         scores_mcc.append(mean_score_mcc)
# ---> 23         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-22-df28736d3d5b> in explor_mcc(fs, mcc, algo)
#      11     neighbor[i] = not fs[i]
#      12     if (neighbor not in explored_models_mcc) :
# ---> 13       score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
#      14       mean_score_mcc = np.mean(score_mcc)
#      15       explored_models_mcc.append(neighbor)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265     # independent, and that it is pickle-able.
#     266     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267     results = parallel(
#     268         delayed(_fit_and_score)(
#     269             clone(estimator),
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                     return self.__get_result()
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#     441                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
max(scores_mcc)
# Out:
# 0.7474072145622772

# %%
XN=X[['X_long', 'ZonePel', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint',
       'Bio_Pre_Qch', 'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril',
       'Vent_Juin']]

# %%
XN
# Out:
#         X_long  ZonePel  Min_IRM  VarT_cy_TempJ      IR_sd   Bio_Tint  \
# 0   -15.911420        3     2690             53   0.899761  12.000000
# 1   -13.188370        0     3350             87   0.397748  17.700001
# 2   -13.188370        0     3350             87   0.397748  17.700001
# 3   -13.185620        0     2930             85   1.639937  17.400001
# 4   -13.167180        0     2350             77   3.913587  17.500000
# ..         ...      ...      ...            ...        ...        ...
# 249  -5.366667        0      880             94   2.176535  18.300001
# 250  -5.816667        0     1400             95   1.735360  17.699999
# 251  -5.366667        0     1080             93   3.989664  18.200001
# 252  -5.558611       58      620              0  12.156531  18.299999
# 253  -5.483333        5      990             92  19.463408  17.700000
#
#      Bio_Pre_Qch  Prec_Juill  Prec_Aout  Tmax_Janv  Tmax_Avril  Vent_Juin
# 0             21           1          3       21.5   22.600000        7.1
# 1              1           0          0       21.9   24.600000        6.4
# 2              1           0          0       21.9   24.600000        6.4
# 3              0           0          0       21.9   24.600000        6.2
# 4              1           0          0       22.0   24.700001        5.7
# ..           ...         ...        ...        ...         ...        ...
# 249           19           1          3       15.2   18.900000        3.9
# 250           22           1          2       14.5   18.700001        3.7
# 251           20           1          4       15.3   18.900000        4.0
# 252           18           1          2       16.6   19.799999        4.1
# 253           19           1          3       16.0   19.000000        3.8
#
# [254 rows x 12 columns]

# %%
classifiers = {
"Gradient_boosting": GradientBoostingClassifier(random_state=0)
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  XN, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  XN, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, XN, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, XN, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, XN, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, XN, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  XN, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  XN, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  XN, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  XN, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  XN, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# Gradient_boosting
# Accuracy: [0.8627451  0.90196078 0.84313725 0.90196078 0.86      ]
# moy_accuracy: 0.873961
# -------------------------------------------------
# sensibilité : [0.83870968 0.90909091 0.8        0.9        0.83333333]
# moy_sensibilité: 0.856227
# -------------------------------------------------
# spécificité : [0.9        0.89655172 0.9047619  0.90322581 0.88461538]
# moy_spécificité: 0.897831
# -------------------------------------------------
# MCC : [0.72481421 0.80188086 0.6938347  0.7968255  0.7196808 ]
# MCC: 0.747407
# -------------------------------------------------
# precision-po: [0.92857143 0.86956522 0.92307692 0.85714286 0.86956522]
# moy_precision-po: 0.889584
# -------------------------------------------------
# precision-ne : [0.7826087  0.92857143 0.76       0.93333333 0.85185185]
# moy_precision-ne: 0.851273
# -------------------------------------------------
# AUC : [0.85322581 0.92084639 0.82222222 0.91774194 0.84695513]
# moy_AUC: 0.872198
# -------------------------------------------------
# VN : [18 26 19 28 23]
# VP : [26 20 24 18 20]
# FP : [2 3 2 3 3]
# FN : [5 2 6 2 4]
# -------------------------------------------------
# -------------------------------------------------

# %%
XN.columns
# Out:
# Index(['X_long', 'ZonePel', 'Min_IRM', 'VarT_cy_TempJ', 'IR_sd', 'Bio_Tint',
#        'Bio_Pre_Qch', 'Prec_Juill', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Juin'],
#       dtype='object')
