# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/10-2022--12-2022/blob/main/Cs_longia/%20test%20DFS%20-%20WEKA%20RESULTATS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
Cl1 = '/content/cs-longia.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
data
# Out:
#      Cs_longia     X_long      Y_lat    Bovins    Volaille   Caprins  \
# 0            1 -15.911420  23.794740  0.000000    0.000000  0.000000
# 1            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 2            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 3            0 -13.185620  27.157940  0.000000    0.000000  0.000000
# 4            0 -13.167180  27.157730  0.000000    0.000000  0.000000
# ..         ...        ...        ...       ...         ...       ...
# 249          1  -5.366667  35.766667  8.495770  105.550156  8.691405
# 250          1  -5.816667  35.783333  0.000000    0.000000  0.000000
# 251          1  -5.366667  35.833333  7.411978  111.459663  7.364459
# 252          1  -5.558611  35.841944  5.696193    5.641273  0.602672
# 253          1  -5.483333  35.900000  6.839514   15.082421  0.782080
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.269410          0        100  ...        5.1         5.6
# 4     0.000000  0.379107          0        100  ...        5.0         5.2
# ..         ...       ...        ...        ...  ...        ...         ...
# 249  15.116930  0.698221          0          0  ...        4.6         4.3
# 250   0.000000  1.725019          0          0  ...        4.6         4.1
# 251  15.054404  0.991284          0          0  ...        4.5         4.3
# 252   4.306276  0.000000          0          0  ...        4.6         4.0
# 253   6.042903  0.595441          0          0  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 226 columns]

# %%
data["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cs_longia']
y = data.Cs_longia

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred)
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_pos
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %%
X
# Out:
#         X_long      Y_lat    Bovins    Volaille   Caprins      Ovins  \
# 0   -15.911420  23.794740  0.000000    0.000000  0.000000   0.000000
# 1   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 2   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 3   -13.185620  27.157940  0.000000    0.000000  0.000000   0.000000
# 4   -13.167180  27.157730  0.000000    0.000000  0.000000   0.000000
# ..         ...        ...       ...         ...       ...        ...
# 249  -5.366667  35.766667  8.495770  105.550156  8.691405  15.116930
# 250  -5.816667  35.783333  0.000000    0.000000  0.000000   0.000000
# 251  -5.366667  35.833333  7.411978  111.459663  7.364459  15.054404
# 252  -5.558611  35.841944  5.696193    5.641273  0.602672   4.306276
# 253  -5.483333  35.900000  6.839514   15.082421  0.782080   6.042903
#
#       Equides  Coniferes  ZoneAride  ZonePel  ...  Vent_Mars  Vent_Avril  \
# 0    0.624435          0         97        3  ...        6.1         6.9
# 1    0.040295          0        100        0  ...        4.8         5.6
# 2    0.040295          0        100        0  ...        4.8         5.6
# 3    0.269410          0        100        0  ...        5.1         5.6
# 4    0.379107          0        100        0  ...        5.0         5.2
# ..        ...        ...        ...      ...  ...        ...         ...
# 249  0.698221          0          0        0  ...        4.6         4.3
# 250  1.725019          0          0        0  ...        4.6         4.1
# 251  0.991284          0          0        0  ...        4.5         4.3
# 252  0.000000          0          0       58  ...        4.6         4.0
# 253  0.595441          0          0        5  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 225 columns]

# %%
X3={"Bovins","Ph1_EVI","Var_EVI","Rad_Mai","Tmax_Avril"}

# %%
classifiers = {
"Gradient_boosting": GradientBoostingClassifier(random_state=0)
}
cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  X[X3], y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  X[X3], y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X[X3], y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X[X3], y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, X[X3], y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, X[X3], y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  X[X3], y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  X[X3], y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  X[X3], y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  X[X3], y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  X[X3], y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# Gradient_boosting
# Accuracy: [0.7254902  0.66666667 0.68627451 0.84313725 0.72      ]
# moy_accuracy: 0.728314
# -------------------------------------------------
# sensibilité : [0.70967742 0.81818182 0.53333333 0.8        0.66666667]
# moy_sensibilité: 0.705572
# -------------------------------------------------
# spécificité : [0.75       0.55172414 0.9047619  0.87096774 0.76923077]
# moy_spécificité: 0.769337
# -------------------------------------------------
# MCC : [0.44963645 0.37523714 0.45117558 0.67096774 0.43871881]
# MCC: 0.477147
# -------------------------------------------------
# precision-po: [0.81481481 0.58064516 0.88888889 0.8        0.72727273]
# moy_precision-po: 0.762324
# -------------------------------------------------
# precision-ne : [0.625      0.8        0.57575758 0.87096774 0.71428571]
# moy_precision-ne: 0.717202
# -------------------------------------------------
# AUC : [0.76693548 0.78761755 0.76825397 0.89516129 0.71634615]
# moy_AUC: 0.786863
# -------------------------------------------------
# VN : [15 16 19 27 20]
# VP : [22 18 16 16 16]
# FP : [ 5 13  2  4  6]
# FN : [ 9  4 14  4  8]
# -------------------------------------------------
# -------------------------------------------------

# %%
algo=GradientBoostingClassifier(random_state=0)

# %%
clmns=X.columns
def transform(X, fs) :
  X_ = X.copy()
  for i in range(len(fs)) :
    if fs[i] == False :
      X_.drop([clmns[i]], axis=1, inplace=True)
  return X_
def Retransform (lst):
  Fs=[]      
  for i in range(225):
    if clmns[i] in lst :
       Fs.append(True)
    else :
       Fs.append(False)
  return Fs
Fs_mcc = Retransform (X3)
cv = KFold(n_splits=5, random_state=1, shuffle=True)
explored_models_mcc = []
scores_mcc = []
models_mm_mcc=[]
var_mcc=[]
def explor_mcc(fs, mcc, algo) :
  if (sum(fs) > 225) :
    return
  explored_models_mcc.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models_mcc) :
      score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
      mean_score_mcc = np.mean(score_mcc)
      explored_models_mcc.append(neighbor)
      if (mean_score_mcc  > mcc) :
        models_mm_mcc.append(neighbor)
        print("mcc : %f" % mean_score_mcc)
        print(len(transform(X,neighbor).columns))
        print(transform(X,neighbor).columns)
        print("-----------")
        scores_mcc.append(mean_score_mcc)
        var_mcc.append(transform(X,neighbor))
        explor_mcc(neighbor, mean_score_mcc, algo)

# %%
explor_mcc(Fs_mcc,0.477147,algo)
# Out:
# mcc : 0.503507
# 6
# Index(['Bovins', 'VegCul', 'Ph1_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'], dtype='object')
# -----------
# mcc : 0.518515
# 7
# Index(['Bovins', 'VegCul', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.518892
# 8
# Index(['Bovins', 'Autres', 'VegCul', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.531755
# 9
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.535523
# 10
# Index(['Bovins', 'Volaille', 'ZonePel', 'Autres', 'VegCul', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.539443
# 9
# Index(['Bovins', 'Volaille', 'ZonePel', 'Autres', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.552041
# 11
# Index(['Bovins', 'Volaille', 'ZonePel', 'Autres', 'VegCul', 'ZoneUrbaine',
#        'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.554096
# 12
# Index(['Bovins', 'Volaille', 'ZonePel', 'Autres', 'VegCul', 'ZoneUrbaine',
#        'Var_IRM', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.556827
# 11
# Index(['Bovins', 'Volaille', 'ZonePel', 'Autres', 'VegCul', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril', 'Tmin_Aout'],
#       dtype='object')
# -----------
# mcc : 0.569348
# 12
# Index(['Bovins', 'Volaille', 'ZonePel', 'Autres', 'VegCul', 'Var_IRM',
#        'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril', 'Tmin_Aout'],
#       dtype='object')
# -----------
# mcc : 0.532476
# 10
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VarT_tri_EVI', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.536268
# 11
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Ph3_IRM', 'VarT_tri_EVI',
#        'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.539676
# 11
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VarT_bi_TempJ',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.542880
# 12
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'VarT_bi_TempJ',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.555238
# 13
# Index(['Bovins', 'ZonePel', 'Lesfeuillus', 'Autres', 'VegCul', 'VegInond',
#        'VarT_bi_TempJ', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.547567
# 13
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'VegInond',
#        'VarT_bi_TempJ', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.548759
# 14
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'VegInond',
#        'Amp3_IRM', 'VarT_bi_TempJ', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.549495
# 14
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'VegInond',
#        'VarT_bi_TempJ', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.558574
# 15
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'VegInond',
#        'VarT_bi_TempJ', 'VarT_tri_NDVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.563335
# 16
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'VarT_bi_TempJ', 'VarT_tri_NDVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.577388
# 17
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'VarT_bi_TempJ', 'VarT_tri_NDVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Sept', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.563252
# 16
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'VegInond',
#        'ZoneUrbaine', 'VarT_bi_TempJ', 'VarT_tri_NDVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.565637
# 15
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'ZoneUrbaine',
#        'VarT_bi_TempJ', 'VarT_tri_NDVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.565112
# 16
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'VegInond',
#        'VarT_bi_TempJ', 'VarT_tri_NDVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Bio_Tint', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.553643
# 13
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'VarT_bi_TempJ',
#        'VarT_tri_TempJ', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.544211
# 13
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'VarT_bi_TempJ',
#        'Max_TempN', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.555619
# 14
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'VarT_bi_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.558844
# 15
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'VarT_bi_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'IPT_Med', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.533498
# 11
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VarT_bi_NDVI', 'VarT_tri_EVI',
#        'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.539006
# 12
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.549816
# 13
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'VegInond',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.541754
# 13
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'Var_IRM',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.551955
# 14
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'Var_IRM',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Bio_Tch_Moy', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.559320
# 14
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'Var_IRM',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Prec_Fev', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.544776
# 14
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'Var_IRM',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Prec_Nov', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.553232
# 13
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'VarT_tri_TempJ',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.534018
# 12
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.543033
# 13
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Autres', 'VegCul', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.545969
# 14
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Lesfeuillus', 'Autres', 'VegCul',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.565399
# 15
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Lesfeuillus', 'Autres', 'VegCul',
#        'VarT_tri_IRM', 'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.546927
# 14
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Autres', 'VegCul', 'VegInond',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.548242
# 15
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Autres', 'VegCul', 'VegInond',
#        'VarT_tri_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI',
#        'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.548418
# 16
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'VarT_tri_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.549845
# 17
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Lesfeuillus', 'Caduc', 'Autres',
#        'VegCul', 'VegInond', 'VarT_tri_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.555869
# 16
# Index(['Bovins', 'ZonePel', 'Lesfeuillus', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'VarT_tri_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.551273
# 17
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'Var_IRM', 'VarT_tri_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.548768
# 17
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'VarT_tri_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.549739
# 18
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.560620
# 19
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Lesfeuillus', 'Caduc', 'Autres',
#        'VegCul', 'VegInond', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Prec_Nov', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.560718
# 18
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Lesfeuillus', 'Autres', 'VegCul',
#        'VegInond', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.569400
# 19
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Lesfeuillus', 'Autres', 'VegCul',
#        'VegInond', 'Var_IRM', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Prec_Nov', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.577169
# 18
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Lesfeuillus', 'Autres', 'VegCul',
#        'Var_IRM', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.552487
# 17
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'Min_TempJ', 'VarT_tri_TempN', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.551262
# 17
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.562413
# 18
# Index(['Bovins', 'Caprins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres',
#        'VegCul', 'VegInond', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.564491
# 17
# Index(['Bovins', 'Caprins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres',
#        'VegCul', 'VegInond', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'Ph1_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.566992
# 18
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'VarT_tri_TempJ', 'Min_TempJ', 'VarT_tri_TempN',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Prec_Nov', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.560715
# 18
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'VarT_cy_TempJ', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.561575
# 19
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'VarT_cy_TempJ', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Oct', 'Prec_Nov',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.575923
# 18
# Index(['Bovins', 'ZoneAride', 'Caduc', 'Autres', 'VegCul', 'VegInond',
#        'VarT_cy_TempJ', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Oct', 'Prec_Nov',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.571436
# 18
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Oct', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.573068
# 20
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'VarT_cy_TempJ', 'Min_TempJ', 'VarT_tri_TempN', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Aout',
#        'Prec_Oct', 'Prec_Nov', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.546927
# 14
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Autres', 'VegCul', 'Var_IRM',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.549845
# 15
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Autres', 'VegCul', 'Var_IRM',
#        'VarT_tri_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI',
#        'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.549869
# 16
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Autres', 'VegCul', 'Var_IRM',
#        'VarT_tri_TempN', 'Amp2_NDVI', 'Amp3_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.560215
# 14
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Autres', 'VegCul', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Prec_Dec', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.538182
# 11
# Index(['Bovins', 'Autres', 'VegCul', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.541557
# 12
# Index(['Bovins', 'Autres', 'VegCul', 'VarT_bi_IRM', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.550578
# 13
# Index(['Bovins', 'Autres', 'VegCul', 'VarT_bi_IRM', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril', 'Vent_Juin'],
#       dtype='object')
# -----------
# mcc : 0.545203
# 12
# Index(['Bovins', 'Autres', 'VegCul', 'VarT_tri_IRM', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.545344
# 13
# Index(['Bovins', 'Autres', 'VegCul', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.566095
# 14
# Index(['Bovins', 'Autres', 'VegCul', 'ZoneUrbaine', 'VarT_tri_IRM', 'Var_IRM',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.545525
# 14
# Index(['Bovins', 'Autres', 'VegCul', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Bio_Tfr_Moy', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.539743
# 12
# Index(['Bovins', 'Autres', 'VegCul', 'VarT_Cy_IRM', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.546445
# 13
# Index(['Bovins', 'Lesfeuillus', 'Autres', 'VegCul', 'VarT_Cy_IRM', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.540404
# 13
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.564316
# 14
# Index(['Bovins', 'ZonePel', 'Lesfeuillus', 'Autres', 'VegCul', 'Amp3_IRM',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.550177
# 14
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'Amp3_IRM',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.562296
# 15
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'VegInond',
#        'Amp3_IRM', 'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.580768
# 14
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'Var_IRM',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.570864
# 14
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'VarT_bi_TempJ',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.554281
# 14
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Bio_Tfr_Moy', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.559119
# 15
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'Amp3_IRM',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Bio_Tfr_Moy', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.571195
# 16
# Index(['Bovins', 'ZonePel', 'Lesfeuillus', 'Autres', 'VegCul', 'VegInond',
#        'Amp3_IRM', 'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Bio_Tfr_Moy', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.566999
# 15
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'VarT_tri_TempJ',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Bio_Tfr_Moy', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.541286
# 14
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.545769
# 15
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.546866
# 15
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Bio_Tint', 'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.547510
# 16
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'Var_IRM',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Bio_Tint', 'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.552116
# 17
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'Amp3_IRM', 'Var_IRM',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Bio_Tint', 'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.553616
# 18
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'Amp3_IRM', 'Var_IRM',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Bio_Tint', 'Prec_Juin', 'Prec_Dec', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.556089
# 19
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'Var_IRM', 'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI',
#        'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Bio_Tint', 'Prec_Juin', 'Prec_Dec',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.568625
# 17
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'Amp3_IRM',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Bio_Tint', 'Prec_Juin', 'Prec_Dec', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.548503
# 16
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'VarT_bi_TempJ',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Bio_Tint', 'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.555295
# 17
# Index(['Bovins', 'ZonePel', 'Lesfeuillus', 'Autres', 'VegCul', 'Amp3_IRM',
#        'VarT_bi_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Bio_Tint', 'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.549668
# 17
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'Amp3_IRM',
#        'VarT_bi_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Bio_Tint', 'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.555078
# 18
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'Amp3_IRM', 'VarT_bi_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Bio_Tint',
#        'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.560704
# 19
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'Amp3_IRM', 'VarT_bi_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Bio_Tint',
#        'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.567624
# 20
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'Amp3_IRM', 'VarT_bi_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Bio_Tint',
#        'Prec_Juin', 'Prec_Dec', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.576404
# 21
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'VegInond', 'Amp3_IRM', 'Var_IRM', 'VarT_bi_TempJ', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Bio_Tint', 'Prec_Juin', 'Prec_Dec', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.571151
# 17
# Index(['Bovins', 'ZoneAride', 'ZonePel', 'Caduc', 'Autres', 'VegCul',
#        'Amp3_IRM', 'VarT_bi_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Bio_Tint', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.553380
# 16
# Index(['Bovins', 'ZonePel', 'Caduc', 'Autres', 'VegCul', 'Amp3_IRM',
#        'VarT_bi_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Bio_Tint', 'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.553573
# 15
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'VarT_bi_TempJ',
#        'Amp2_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Bio_Tint', 'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.561829
# 16
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'Amp3_IRM',
#        'VarT_bi_TempJ', 'Amp2_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Bio_Tint', 'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.548295
# 16
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Bio_Tint', 'Prec_Juin', 'Rad_Mai', 'Tmax_Avril', 'Tmin_Sept'],
#       dtype='object')
# -----------
# mcc : 0.542601
# 14
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'Amp2_NDVI',
#        'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI',
#        'Prec_Nov', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.543720
# 15
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'VarT_tri_TempJ',
#        'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI',
#        'Var_EVI', 'Prec_Nov', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.555072
# 16
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'VegInond', 'Amp3_IRM',
#        'VarT_tri_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI',
#        'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.549319
# 16
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'VarT_tri_TempJ',
#        'Ph1_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.550589
# 17
# Index(['Bovins', 'ZonePel', 'Lesfeuillus', 'Autres', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_TempJ', 'Ph1_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.550272
# 17
# Index(['Bovins', 'ZonePel', 'Autres', 'VegCul', 'Amp3_IRM', 'VarT_bi_TempJ',
#        'VarT_tri_TempJ', 'Ph1_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.550926
# 16
# Index(['Bovins', 'Autres', 'VegCul', 'Amp3_IRM', 'VarT_bi_TempJ',
#        'VarT_tri_TempJ', 'Ph1_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.555529
# 17
# Index(['Bovins', 'Caduc', 'Autres', 'VegCul', 'Amp3_IRM', 'VarT_bi_TempJ',
#        'VarT_tri_TempJ', 'Ph1_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.565841
# 16
# Index(['Bovins', 'Caduc', 'Autres', 'VegCul', 'Amp3_IRM', 'VarT_bi_TempJ',
#        'Ph1_TempJ', 'Amp2_NDVI', 'VarT_bi_NDVI', 'VarT_tri_EVI', 'Ph1_EVI',
#        'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# mcc : 0.556365
# 18
# Index(['Bovins', 'Caduc', 'Autres', 'VegCul', 'Amp3_IRM', 'VarT_bi_TempJ',
#        'VarT_tri_TempJ', 'Ph1_TempJ', 'Var_TempN', 'Amp2_NDVI', 'VarT_bi_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Ph2_EVI', 'Var_EVI', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-a781d9e61f38> in <module>
# ----> 1 explor_mcc(Fs_mcc,0.477147,algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      39         scores_mcc.append(mean_score_mcc)
#      40         var_mcc.append(transform(X,neighbor))
# ---> 41         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-13-345ebaba4c98> in explor_mcc(fs, mcc, algo)
#      28     neighbor[i] = not fs[i]
#      29     if (neighbor not in explored_models_mcc) :
# ---> 30       score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
#      31       mean_score_mcc = np.mean(score_mcc)
#      32       explored_models_mcc.append(neighbor)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265     # independent, and that it is pickle-able.
#     266     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267     results = parallel(
#     268         delayed(_fit_and_score)(
#     269             clone(estimator),
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                     return self.__get_result()
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#     441                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
max(scores_mcc)
# Out:
# 0.5807679646937974
