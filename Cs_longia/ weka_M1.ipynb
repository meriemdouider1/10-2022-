# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/10-2022--12-2022/blob/main/Cs_longia/%20weka_M1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ---

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
Cl1 = '/content/cs-longia.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
data
# Out:
#      Cs_longia     X_long      Y_lat    Bovins    Volaille   Caprins  \
# 0            1 -15.911420  23.794740  0.000000    0.000000  0.000000
# 1            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 2            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 3            0 -13.185620  27.157940  0.000000    0.000000  0.000000
# 4            0 -13.167180  27.157730  0.000000    0.000000  0.000000
# ..         ...        ...        ...       ...         ...       ...
# 249          1  -5.366667  35.766667  8.495770  105.550156  8.691405
# 250          1  -5.816667  35.783333  0.000000    0.000000  0.000000
# 251          1  -5.366667  35.833333  7.411978  111.459663  7.364459
# 252          1  -5.558611  35.841944  5.696193    5.641273  0.602672
# 253          1  -5.483333  35.900000  6.839514   15.082421  0.782080
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.269410          0        100  ...        5.1         5.6
# 4     0.000000  0.379107          0        100  ...        5.0         5.2
# ..         ...       ...        ...        ...  ...        ...         ...
# 249  15.116930  0.698221          0          0  ...        4.6         4.3
# 250   0.000000  1.725019          0          0  ...        4.6         4.1
# 251  15.054404  0.991284          0          0  ...        4.5         4.3
# 252   4.306276  0.000000          0          0  ...        4.6         4.0
# 253   6.042903  0.595441          0          0  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 226 columns]

# %%
data["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cs_longia']
y = data.Cs_longia

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred)
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_pos
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %%
lst=["Min_IRM", "Var_EVI" , "Bio_Pre_Qhum" , "Rad_Juin" , "Tmax_Avril"]

# %%
from sklearn.ensemble import BaggingClassifier

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)

# %%
classifiers = {
"Random_subspace": BaggingClassifier(bootstrap=False,random_state=0)
}
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  X[lst], y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  X[lst], y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X[lst], y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X[lst], y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, X[lst], y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, X[lst], y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  X[lst], y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  X[lst], y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  X[lst], y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  X[lst], y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  X[lst], y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# Random_subspace
# Accuracy: [0.62745098 0.64705882 0.62745098 0.66666667 0.66      ]
# moy_accuracy: 0.645725
# -------------------------------------------------
# sensibilité : [0.61290323 0.72727273 0.5        0.85       0.58333333]
# moy_sensibilité: 0.654702
# -------------------------------------------------
# spécificité : [0.65       0.5862069  0.80952381 0.5483871  0.73076923]
# moy_spécificité: 0.664977
# -------------------------------------------------
# MCC : [0.25676456 0.3120159  0.31507399 0.3983871  0.31794729]
# MCC: 0.320038
# -------------------------------------------------
# precision-po: [0.73076923 0.57142857 0.78947368 0.5483871  0.66666667]
# moy_precision-po: 0.661345
# -------------------------------------------------
# precision-ne : [0.52       0.73913043 0.53125    0.85       0.65517241]
# moy_precision-ne: 0.659111
# -------------------------------------------------
# AUC : [0.66774194 0.70062696 0.68492063 0.74193548 0.6963141 ]
# moy_AUC: 0.698308
# -------------------------------------------------
# VN : [13 17 17 17 19]
# VP : [19 16 15 17 14]
# FP : [ 7 12  4 14  7]
# FN : [12  6 15  3 10]
# -------------------------------------------------
# -------------------------------------------------

# %%
clmns=X.columns
def transform(X, fs) :
  X_ = X.copy()
  for i in range(len(fs)) :
    if fs[i] == False :
      X_.drop([clmns[i]], axis=1, inplace=True)
  return X_
def Retransform (lst):
  Fs=[]      
  for i in range(225):
    if clmns[i] in lst :
       Fs.append(True)
    else :
       Fs.append(False)
  return Fs

# %%
Fs_acc = Retransform (lst)
cv = KFold(n_splits=5, random_state=1, shuffle=True)

# %%
explored_models_acc = []
models_mm_acc=[]
var_acc=[]
scores_acc=[]

# %%
def explor_acc(fs, acc, algo) :
  if (sum(fs) > 225) :
    return
  explored_models_acc.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models_acc) :
      score_acc = cross_val_score(algo, transform(X, neighbor) , y, scoring='accuracy', cv=cv, n_jobs=-1)
      mean_score_acc = np.mean(score_acc)
      explored_models_acc.append(neighbor)
      if (mean_score_acc  > acc) :
        models_mm_acc.append(neighbor)
        print("acc : %f" % mean_score_acc)
        print(len(transform(X,neighbor).columns))
        print(transform(X,neighbor).columns)
        print("-----------")
        scores_acc.append(mean_score_acc)
        var_acc.append(transform(X,neighbor))
        explor_acc(neighbor, mean_score_acc, algo)

# %%
algo=BaggingClassifier(bootstrap=False,random_state=0)

# %%
explor_acc(Fs_acc,0.645725,algo)
# Out:
# acc : 0.689098
# 6
# Index(['X_long', 'Min_IRM', 'Var_EVI', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.704941
# 7
# Index(['X_long', 'Bovins', 'Min_IRM', 'Var_EVI', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.708941
# 8
# Index(['X_long', 'Bovins', 'Volaille', 'Min_IRM', 'Var_EVI', 'Bio_Pre_Qhum',
#        'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.712784
# 9
# Index(['X_long', 'Bovins', 'Volaille', 'Min_IRM', 'VarT_ann_TempN', 'Var_EVI',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.732314
# 10
# Index(['X_long', 'Bovins', 'Volaille', 'Min_IRM', 'Ph1_IRM', 'VarT_ann_TempN',
#        'Var_EVI', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.724549
# 10
# Index(['X_long', 'Bovins', 'Volaille', 'Min_IRM', 'Ph3_IRM', 'VarT_ann_TempN',
#        'Var_EVI', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.728392
# 11
# Index(['X_long', 'Bovins', 'Volaille', 'Coniferes', 'Min_IRM', 'Ph3_IRM',
#        'VarT_ann_TempN', 'Var_EVI', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.732471
# 12
# Index(['X_long', 'Bovins', 'Volaille', 'Coniferes', 'Min_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Var_EVI', 'Bio_Pre_Qhum',
#        'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.736392
# 13
# Index(['X_long', 'Bovins', 'Volaille', 'Coniferes', 'Min_IRM', 'Ph3_IRM',
#        'VarT_bi_TempJ', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Var_EVI',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.744314
# 11
# Index(['X_long', 'Bovins', 'Volaille', 'Coniferes', 'Min_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'Var_EVI', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.748157
# 13
# Index(['X_long', 'Bovins', 'Volaille', 'Coniferes', 'Min_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Var_EVI', 'Substratum',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.736157
# 13
# Index(['X_long', 'Bovins', 'Volaille', 'Coniferes', 'Min_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.744157
# 14
# Index(['X_long', 'Bovins', 'Volaille', 'Coniferes', 'Min_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.748157
# 15
# Index(['X_long', 'Bovins', 'Volaille', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.748235
# 14
# Index(['X_long', 'Bovins', 'Volaille', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.748392
# 15
# Index(['X_long', 'Bovins', 'Volaille', 'Autres', 'Moy_IRM', 'Min_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.752000
# 15
# Index(['X_long', 'Bovins', 'Volaille', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Var_TempN', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.748314
# 15
# Index(['X_long', 'Bovins', 'Volaille', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.756235
# 14
# Index(['X_long', 'Bovins', 'Volaille', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.755922
# 16
# Index(['X_long', 'Bovins', 'Volaille', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.760000
# 17
# Index(['X_long', 'Bovins', 'Volaille', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.763922
# 16
# Index(['X_long', 'Bovins', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.771686
# 17
# Index(['X_long', 'Bovins', 'Ovins', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.771843
# 18
# Index(['X_long', 'Bovins', 'Caprins', 'Ovins', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.775765
# 18
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783529
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783686
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Pl_herb', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787608
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Pl_herb', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'Var_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791451
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Var_TempN', 'VarT_tri_NDVI', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791451
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Prec_Aout', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787529
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Rad_Juin', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779608
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779608
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'VarT_bi_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787451
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Max_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779765
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Tmin_Aout'],
#       dtype='object')
# -----------
# acc : 0.779686
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.779765
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.783529
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'Var_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill',
#        'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.787608
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'Var_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791529
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'Var_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'VarT_cy_NDVI', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791529
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'Var_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Isoth', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779765
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.791451
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Lesfeuillus', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.783608
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.787608
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'Var_IRM', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.783686
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_bi_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.783529
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.783608
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'VarT_tri_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.783529
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Pente_sd', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.783608
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Janv', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.783686
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Rad_Nov', 'Tmax_Avril', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.791529
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.779529
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmax_Oct', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783451
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Tj_Moy', 'Bio_Pre_Qhum',
#        'Rad_Juin', 'Tmax_Avril', 'Tmax_Oct', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783608
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Bio_Tj_Moy', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril',
#        'Tmax_Oct', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783608
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_ann_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Tj_Moy',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmax_Oct', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.771765
# 18
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.771843
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.775765
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Amp2_NDVI', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779765
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.775843
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_cy_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.771843
# 18
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779451
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Pl_herb', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779608
# 18
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Pl_herb', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.775686
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'ZoneUrbaine', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.771765
# 18
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779608
# 19
# Index(['X_long', 'Bovins', 'Volaille', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.775686
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Pl_herb', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779686
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Lesfeuillus', 'Caduc', 'Pl_herb',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779686
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'VegInond', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.771843
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'ZoneUrbaine', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779686
# 18
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'ZoneUrbaine', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.775765
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779686
# 18
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempN', 'Max_TempN', 'VarT_tri_NDVI', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779765
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Amp1_NDVI',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779608
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Min_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779686
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Var_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783529
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'VarT_tri_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779686
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779765
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783686
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783686
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Tmin_Aout'],
#       dtype='object')
# -----------
# acc : 0.783686
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Lesfeuillus', 'Caduc', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787529
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Lesfeuillus', 'Caduc', 'Pl_herb',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787529
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Lesfeuillus', 'Caduc', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787608
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Lesfeuillus', 'Caduc', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Var_TempN', 'VarT_tri_NDVI', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783608
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'Var_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787608
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'Var_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787451
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Pl_herb', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'Var_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791373
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'VegInond', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'Var_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783608
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783529
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783608
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Vap_Aout'],
#       dtype='object')
# -----------
# acc : 0.779765
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Prec_Dec', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787608
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Prec_Dec', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783686
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmax_Oct', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791451
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Tint',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmax_Oct',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783608
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum',
#        'Rad_Juin', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787529
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791451
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill', 'Vap_Aout'],
#       dtype='object')
# -----------
# acc : 0.791608
# 21
# Index(['X_long', 'Bovins', 'Volaille', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill', 'Vap_Aout'],
#       dtype='object')
# -----------
# acc : 0.799373
# 22
# Index(['X_long', 'Bovins', 'Volaille', 'Ovins', 'Lesfeuillus', 'Caduc',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill',
#        'Vap_Aout'],
#       dtype='object')
# -----------
# acc : 0.795451
# 20
# Index(['X_long', 'Bovins', 'Volaille', 'Ovins', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill', 'Vap_Aout'],
#       dtype='object')
# -----------
# acc : 0.795451
# 22
# Index(['X_long', 'Bovins', 'Volaille', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Moy_EVI', 'Var_EVI', 'Bio_Pre_Qhum', 'Prec_Dec',
#        'Rad_Juin', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill', 'Vap_Aout'],
#       dtype='object')
# -----------
# acc : 0.775608
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779686
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'Var_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.775686
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Ph3_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779608
# 18
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_unif', 'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.775608
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779765
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.775765
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779765
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Equides', 'ZonePel', 'Caduc', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783686
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZonePel', 'Caduc', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787529
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Caduc',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787608
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Caduc',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791451
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Caduc',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791529
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Caduc',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'Var_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791529
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Caduc',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'Var_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Var_EVI', 'Geom_Shan',
#        'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791451
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Caduc',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_TempJ', 'VarT_cy_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791529
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Caduc',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_TempJ', 'VarT_cy_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791608
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Caduc',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Ph3_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.775843
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779608
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783608
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZonePel', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787608
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZonePel', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'VarT_tri_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783686
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZonePel', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Janv', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787529
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZonePel', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779686
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783529
# 21
# Index(['X_long', 'Bovins', 'ZonePel', 'Lesfeuillus', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787529
# 22
# Index(['X_long', 'Bovins', 'ZoneAride', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787529
# 23
# Index(['X_long', 'Bovins', 'ZoneAride', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'ZoneUrbaine', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787608
# 20
# Index(['X_long', 'Bovins', 'Lesfeuillus', 'VegInond', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783686
# 22
# Index(['X_long', 'Bovins', 'ZonePel', 'Lesfeuillus', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill',
#        'Tmin_Aout'],
#       dtype='object')
# -----------
# acc : 0.787529
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'ZoneUrbaine', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787608
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'Var_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783608
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783686
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'Amp1_TempN', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791529
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'VarT_tri_NDVI',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787608
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783608
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Rad_Nov', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783686
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_cy_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Rad_Nov', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783608
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ',
#        'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan',
#        'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787529
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Pl_herb',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791373
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Caduc',
#        'Pl_herb', 'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin',
#        'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791451
# 26
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Caduc',
#        'Pl_herb', 'VegInond', 'ZoneUrbaine', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791373
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempN',
#        'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791451
# 24
# ...
# -----------
# acc : 0.775765
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779686
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779765
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Tj_Moy', 'Isoth',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787529
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Tj_Moy', 'Isoth',
#        'Bio_Pre_Qhum', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779765
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum',
#        'Prec_Janv', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783608
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Pre_Qhum',
#        'Prec_Janv', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787608
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Bio_Tj_Moy',
#        'Bio_Pre_Qhum', 'Prec_Janv', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779765
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.791529
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmax_Sept', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783608
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Caduc', 'Moy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Moy_EVI', 'VarT_tri_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmax_Sept',
#        'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779686
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'VarT_tri_TempN',
#        'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783451
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Pente_sd', 'Isoth',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779686
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Prec_Dec', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779608
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Rad_Nov', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.783686
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Rad_Nov', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787529
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'Var_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Rad_Nov', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787608
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'Var_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.787608
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmax_Oct', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.775843
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmax_Nov', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779608
# 21
# Index(['X_long', 'Bovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI', 'Var_EVI',
#        'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum', 'Prec_Oct',
#        'Rad_Juin', 'Tmax_Avril', 'Tmax_Nov', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.779529
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Caduc', 'Moy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN', 'Max_TempN', 'Moy_EVI',
#        'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth', 'Bio_Pre_Qhum',
#        'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill', 'Tmin_Aout'],
#       dtype='object')
# -----------
# acc : 0.779765
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Lesfeuillus', 'Caduc', 'Moy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_tri_TempJ', 'VarT_ann_TempN',
#        'Max_TempN', 'Moy_EVI', 'Var_EVI', 'Geom_Shan', 'Geom_unif', 'Isoth',
#        'Bio_Pre_Qhum', 'Prec_Oct', 'Rad_Juin', 'Tmax_Avril', 'Tmin_Juill',
#        'Tmin_Aout'],
#       dtype='object')
# -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c3c31e32f8c6> in <module>
# ----> 1 explor_acc(Fs_acc,0.645725,algo)
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-14-83800041fae5> in explor_acc(fs, acc, algo)
#       7     neighbor[i] = not fs[i]
#       8     if (neighbor not in explored_models_acc) :
# ----> 9       score_acc = cross_val_score(algo, transform(X, neighbor) , y, scoring='accuracy', cv=cv, n_jobs=-1)
#      10       mean_score_acc = np.mean(score_acc)
#      11       explored_models_acc.append(neighbor)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265     # independent, and that it is pickle-able.
#     266     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267     results = parallel(
#     268         delayed(_fit_and_score)(
#     269             clone(estimator),
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                     return self.__get_result()
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#     441                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
lst_var=[]
lst_nbv=[]
for i in range (len(var_acc)):
  pp=set(var_acc[i].columns)
  str = ','.join(pp)
  lst_var.append(str)
  lst_nbv.append(len(var_acc[i].columns))
df = pd.DataFrame({'var': lst_var,
     'nbv': lst_nbv,
     'score_acc': scores_acc
    })
df
df.to_excel("weka m1.xlsx")
