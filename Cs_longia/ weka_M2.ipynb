# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/10-2022--12-2022/blob/main/Cs_longia/%20weka_M2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ---

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
Cl1 = '/content/cs-longia.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
data
# Out:
#      Cs_longia     X_long      Y_lat    Bovins    Volaille   Caprins  \
# 0            1 -15.911420  23.794740  0.000000    0.000000  0.000000
# 1            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 2            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 3            0 -13.185620  27.157940  0.000000    0.000000  0.000000
# 4            0 -13.167180  27.157730  0.000000    0.000000  0.000000
# ..         ...        ...        ...       ...         ...       ...
# 249          1  -5.366667  35.766667  8.495770  105.550156  8.691405
# 250          1  -5.816667  35.783333  0.000000    0.000000  0.000000
# 251          1  -5.366667  35.833333  7.411978  111.459663  7.364459
# 252          1  -5.558611  35.841944  5.696193    5.641273  0.602672
# 253          1  -5.483333  35.900000  6.839514   15.082421  0.782080
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.269410          0        100  ...        5.1         5.6
# 4     0.000000  0.379107          0        100  ...        5.0         5.2
# ..         ...       ...        ...        ...  ...        ...         ...
# 249  15.116930  0.698221          0          0  ...        4.6         4.3
# 250   0.000000  1.725019          0          0  ...        4.6         4.1
# 251  15.054404  0.991284          0          0  ...        4.5         4.3
# 252   4.306276  0.000000          0          0  ...        4.6         4.0
# 253   6.042903  0.595441          0          0  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 226 columns]

# %%
data["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cs_longia']
y = data.Cs_longia

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred)
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_pos
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %%
lst= ["Min_IRM","Ph1_TempJ","Var_EVI","Tmax_Janv" ,"Tmax_Mai" ,"Tmax_Aout"]

# %%
from sklearn.ensemble import BaggingClassifier

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)

# %%
classifiers = {
"Random_subspace": BaggingClassifier(bootstrap=False,random_state=0)
}
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  X[lst], y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  X[lst], y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X[lst], y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X[lst], y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, X[lst], y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, X[lst], y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  X[lst], y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  X[lst], y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  X[lst], y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  X[lst], y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  X[lst], y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# Random_subspace
# Accuracy: [0.60784314 0.66666667 0.64705882 0.64705882 0.7       ]
# moy_accuracy: 0.653725
# -------------------------------------------------
# sensibilité : [0.58064516 0.72727273 0.53333333 0.6        0.70833333]
# moy_sensibilité: 0.629917
# -------------------------------------------------
# spécificité : [0.65       0.62068966 0.80952381 0.67741935 0.69230769]
# moy_spécificité: 0.689988
# -------------------------------------------------
# MCC : [0.22525971 0.34526705 0.34561106 0.27347792 0.40032038]
# MCC: 0.317987
# -------------------------------------------------
# precision-po: [0.72       0.59259259 0.8        0.54545455 0.68      ]
# moy_precision-po: 0.667609
# -------------------------------------------------
# precision-ne : [0.5        0.75       0.5483871  0.72413793 0.72      ]
# moy_precision-ne: 0.648505
# -------------------------------------------------
# AUC : [0.64274194 0.68808777 0.6515873  0.7233871  0.72035256]
# moy_AUC: 0.685231
# -------------------------------------------------
# VN : [13 18 17 21 18]
# VP : [18 16 16 12 17]
# FP : [ 7 11  4 10  8]
# FN : [13  6 14  8  7]
# -------------------------------------------------
# -------------------------------------------------

# %%
clmns=X.columns
def transform(X, fs) :
  X_ = X.copy()
  for i in range(len(fs)) :
    if fs[i] == False :
      X_.drop([clmns[i]], axis=1, inplace=True)
  return X_
def Retransform (lst):
  Fs=[]      
  for i in range(225):
    if clmns[i] in lst :
       Fs.append(True)
    else :
       Fs.append(False)
  return Fs

# %%
Fs_acc = Retransform (lst)
cv = KFold(n_splits=5, random_state=1, shuffle=True)

# %%
explored_models_acc = []
models_mm_acc=[]
var_acc=[]
scores_acc=[]

# %%
def explor_acc(fs, acc, algo) :
  if (sum(fs) > 225) :
    return
  explored_models_acc.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models_acc) :
      score_acc = cross_val_score(algo, transform(X, neighbor) , y, scoring='accuracy', cv=cv, n_jobs=-1)
      mean_score_acc = np.mean(score_acc)
      explored_models_acc.append(neighbor)
      if (mean_score_acc  > acc) :
        models_mm_acc.append(neighbor)
        print("acc : %f" % mean_score_acc)
        print(len(transform(X,neighbor).columns))
        print(transform(X,neighbor).columns)
        print("-----------")
        scores_acc.append(mean_score_acc)
        var_acc.append(transform(X,neighbor))
        explor_acc(neighbor, mean_score_acc, algo)

# %%
algo=BaggingClassifier(bootstrap=False,random_state=0)

# %%
explor_acc(Fs_acc,0.653725,algo)
# Out:
# acc : 0.661647
# 7
# Index(['Y_lat', 'Min_IRM', 'Ph1_TempJ', 'Var_EVI', 'Tmax_Janv', 'Tmax_Mai',
#        'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.677255
# 8
# Index(['Y_lat', 'Bovins', 'Min_IRM', 'Ph1_TempJ', 'Var_EVI', 'Tmax_Janv',
#        'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.681176
# 9
# Index(['Y_lat', 'Bovins', 'Autres', 'Min_IRM', 'Ph1_TempJ', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.692706
# 10
# Index(['Y_lat', 'Bovins', 'Autres', 'Min_IRM', 'Ph3_IRM', 'Ph1_TempJ',
#        'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.696627
# 9
# Index(['Bovins', 'Autres', 'Min_IRM', 'Ph3_IRM', 'Ph1_TempJ', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.704549
# 10
# Index(['X_long', 'Bovins', 'Autres', 'Min_IRM', 'Ph3_IRM', 'Ph1_TempJ',
#        'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.732000
# 11
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Min_IRM', 'Ph3_IRM',
#        'Ph1_TempJ', 'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.747765
# 12
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'Min_IRM', 'Ph3_IRM',
#        'Ph1_TempJ', 'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.751843
# 13
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'Min_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Ph1_TempJ', 'Var_EVI', 'Tmax_Janv', 'Tmax_Mai',
#        'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.755843
# 14
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'Min_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'Ph1_TempJ', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.755922
# 15
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'Ph1_TempJ',
#        'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.771608
# 16
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ',
#        'Ph1_TempJ', 'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.763765
# 14
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.767686
# 15
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'Var_IRM', 'VarT_ann_TempJ', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.763765
# 15
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_tri_NDVI',
#        'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.771608
# 16
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'Ph1_TempJ',
#        'VarT_tri_NDVI', 'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.771608
# 16
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.775529
# 17
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Autres', 'Amp3_IRM',
#        'VarT_bi_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Amp2_TempN', 'VarT_tri_NDVI', 'Var_EVI', 'Tmax_Janv', 'Tmax_Mai',
#        'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.775529
# 17
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Amp2_TempN', 'VarT_tri_NDVI', 'Var_EVI', 'Tmax_Janv', 'Tmax_Mai',
#        'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.775608
# 18
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Var_EVI', 'Tmax_Janv',
#        'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.783373
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'VegInond', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.783294
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'Var_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.783373
# 18
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'Var_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.790980
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'Var_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Nov'],
#       dtype='object')
# -----------
# acc : 0.791137
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'VegCul', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'Var_IRM', 'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI',
#        'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Nov'],
#       dtype='object')
# -----------
# acc : 0.810824
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'VegCul', 'VegInond', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'Var_IRM', 'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI',
#        'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Nov'],
#       dtype='object')
# -----------
# acc : 0.791216
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'VegCul', 'Amp3_IRM',
#        'VarT_ann_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'Var_IRM', 'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Nov'],
#       dtype='object')
# -----------
# acc : 0.795059
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'VegCul', 'Amp3_IRM',
#        'VarT_ann_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'Var_IRM', 'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv', 'Tmax_Mai',
#        'Tmax_Nov'],
#       dtype='object')
# -----------
# acc : 0.779608
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'VarT_cy_NDVI', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.775765
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Min_NDVI', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.779686
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_NDVI', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.779686
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Amp1_EVI', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.783529
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Var_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Amp1_EVI',
#        'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.783529
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Amp2_TempN', 'Ph1_TempN', 'VarT_tri_NDVI', 'Amp1_EVI',
#        'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.795373
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'VarT_tri_EVI', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.775765
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Min_EVI', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.791451
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.799216
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Var_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI',
#        'Var_EVI', 'Tmax_Janv', 'Tmax_Mai', 'Tmax_Aout'],
#       dtype='object')
# -----------
# acc : 0.795137
# 18
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.799059
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Amp2_TempN', 'VarT_tri_TempN', 'VarT_tri_NDVI', 'Max_EVI',
#        'Var_EVI', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.810824
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Max_TempJ', 'Amp2_TempN', 'VarT_tri_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.798902
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI',
#        'Pente_Moy', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.798980
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI',
#        'Var_EVI', 'Pente_Moy', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.802824
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.806745
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.806745
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'VegInond',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.802902
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'Amp2_TempJ', 'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.802980
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'Amp2_TempJ', 'VarT_ann_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.810745
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'Amp2_TempJ', 'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai', 'Tmax_Oct'],
#       dtype='object')
# -----------
# acc : 0.810745
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'Amp2_TempJ', 'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai', 'Vent_Mai'],
#       dtype='object')
# -----------
# acc : 0.810667
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'Amp2_TempJ', 'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai', 'Vent_Juin'],
#       dtype='object')
# -----------
# acc : 0.810745
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'Amp2_TempJ', 'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai', 'Vent_Juill'],
#       dtype='object')
# -----------
# acc : 0.806824
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Var_TempJ',
#        'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.814667
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Var_TempJ',
#        'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.806902
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.810902
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.806980
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Bio_Pre_sec',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.810902
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Prec_Aout',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.810667
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Var_TempJ',
#        'Amp2_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Max_EVI', 'Var_EVI',
#        'Pente_Moy', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.810745
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp2_IRM',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Var_TempJ',
#        'Amp2_TempN', 'VarT_tri_NDVI', 'Moy_EVI', 'Max_EVI', 'Var_EVI',
#        'Pente_Moy', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.810745
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Var_TempJ',
#        'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy',
#        'Bio_Pre_hum', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.814588
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Var_TempJ',
#        'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy',
#        'Prec_Janv', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.814588
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Var_TempJ',
#        'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Nov'],
#       dtype='object')
# -----------
# acc : 0.810667
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Var_TempJ',
#        'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy',
#        'Tmax_Janv', 'Tmax_Mai', 'Tmax_Dec'],
#       dtype='object')
# -----------
# acc : 0.810667
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Var_TempJ',
#        'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy',
#        'Tmax_Janv', 'Tmax_Mai', 'Vent_Janv'],
#       dtype='object')
# -----------
# acc : 0.802902
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN', 'Ph1_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.802902
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN', 'Var_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.806745
# 23
# Index(['X_long', 'Bovins', 'Volaille', 'Ovins', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'Var_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.806824
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN', 'Var_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Prec_Dec',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.814667
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'Lesfeuillus', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'Var_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy',
#        'Prec_Dec', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.814745
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'Lesfeuillus', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Min_TempJ', 'Var_TempJ',
#        'Amp2_TempN', 'Var_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI',
#        'Pente_Moy', 'Prec_Dec', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.810745
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN',
#        'VarT_tri_TempN', 'Var_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI',
#        'Pente_Moy', 'Prec_Dec', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.814667
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Amp3_IRM', 'VarT_bi_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Min_TempJ', 'Var_TempJ', 'Amp2_TempN', 'VarT_tri_TempN', 'Var_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Prec_Dec',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.802902
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Var_TempJ', 'Amp2_TempN', 'Amp2_NDVI',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.799059
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI',
#        'Var_EVI', 'Pente_Moy', 'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.799137
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph2_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI',
#        'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Bio_Pre_Saison', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.799294
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN', 'Moy_NDVI',
#        'VarT_tri_NDVI', 'Max_EVI', 'Var_EVI', 'Pente_Moy', 'Bio_Pre_Saison',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.799137
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Min_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI',
#        'Pente_Moy', 'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.799294
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'Bio_Pre_Saison', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.799373
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Ph3_EVI', 'Pente_Moy', 'Bio_Pre_Saison',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.803294
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Ph3_EVI', 'Pente_Moy', 'Bio_Pre_Saison',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.807137
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'Var_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Ph3_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.807137
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_bi_NDVI', 'VarT_tri_NDVI', 'Max_EVI', 'Ph3_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.807216
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph2_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ',
#        'Amp2_TempN', 'VarT_bi_NDVI', 'VarT_tri_NDVI', 'Max_EVI', 'Ph3_EVI',
#        'Pente_Moy', 'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.807216
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_bi_NDVI', 'VarT_tri_NDVI', 'VarT_ann_EVI', 'Max_EVI', 'Ph3_EVI',
#        'Pente_Moy', 'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.807216
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_bi_NDVI', 'VarT_tri_NDVI', 'Max_EVI', 'Ph3_EVI', 'Pente_Moy',
#        'Bio_Thum_Moy', 'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.810980
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_bi_NDVI', 'VarT_tri_NDVI', 'Max_EVI', 'Ph3_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Prec_Dec', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.807216
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'VarT_bi_EVI', 'Max_EVI', 'Ph3_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.803294
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Geom_maj', 'Pente_Moy', 'Bio_Pre_Saison',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.803294
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'Isoth', 'Bio_Pre_Saison',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.803294
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.803216
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'Bio_Pre_Saison', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.807216
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_cy_TempJ', 'Min_TempJ', 'Amp2_TempN',
#        'VarT_cy_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.799216
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.799294
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_bi_IRM', 'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI',
#        'Pente_Moy', 'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.803216
# 19
# Index(['X_long', 'Bovins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.811137
# 20
# Index(['X_long', 'Bovins', 'Caprins', 'Ovins', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.811059
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.811137
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Amp2_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.814980
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'ZonePel', 'Autres', 'Pl_herb', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.818980
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZonePel', 'Autres',
#        'Pl_herb', 'Amp3_IRM', 'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI',
#        'Pente_Moy', 'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.822980
# 20
# Index(['X_long', 'Ovins', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.823059
# 20
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy',
#        'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.830824
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempJ', 'VarT_tri_NDVI',
#        'Max_EVI', 'Pente_Moy', 'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.826980
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_ann_TempN', 'VarT_tri_NDVI',
#        'Max_EVI', 'Pente_Moy', 'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.834824
# 21
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'Autres', 'Pl_herb',
#        'Amp3_IRM', 'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempN', 'VarT_tri_NDVI',
#        'Max_EVI', 'Pente_Moy', 'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.822902
# 22
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZonePel', 'Autres',
#        'Pl_herb', 'VegCul', 'Amp3_IRM', 'VarT_tri_IRM', 'VarT_Cy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_tri_NDVI',
#        'Max_EVI', 'Pente_Moy', 'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.826980
# 23
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZonePel', 'Autres',
#        'Pl_herb', 'VegCul', 'Amp3_IRM', 'VarT_tri_IRM', 'VarT_Cy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'Bio_Pre_Saison', 'Prec_Aout',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.826980
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZonePel', 'Autres',
#        'Pl_herb', 'VegCul', 'Amp3_IRM', 'VarT_tri_IRM', 'VarT_Cy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_sd', 'Bio_Pre_Saison',
#        'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.830902
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZonePel', 'Autres',
#        'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM', 'VarT_tri_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_sd',
#        'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.830902
# 26
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM', 'VarT_tri_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_sd',
#        'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.838824
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'VarT_tri_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'VarT_cy_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_sd',
#        'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842667
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Autres', 'Pl_herb', 'VegCul', 'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_sd', 'Bio_Pre_Saison',
#        'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.830980
# 27
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM', 'VarT_tri_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'Amp2_TempJ',
#        'VarT_ann_TempJ', 'VarT_cy_TempN', 'VarT_tri_NDVI', 'Max_EVI',
#        'Pente_Moy', 'IR_sd', 'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.834824
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM', 'VarT_tri_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_sd', 'Bio_Pre_Saison',
#        'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.834824
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'Autres',
#        'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM', 'VarT_tri_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_sd', 'Bio_Pre_Saison',
#        'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.838588
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM', 'VarT_tri_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_sd', 'Prec_Aout',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.838667
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_sd',
#        'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842353
# 26
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Ret_eau', 'Pente_Moy',
#        'IR_sd', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842431
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Ret_eau', 'Pente_Moy',
#        'IR_sd', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.846431
# 27
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'Amp2_TempJ', 'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Ret_eau',
#        'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.850275
# 28
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'Amp2_TempJ', 'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Ret_eau',
#        'Geom_maj', 'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842431
# 27
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_tri_TempJ', 'VarT_tri_NDVI', 'Max_EVI',
#        'Ret_eau', 'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.846431
# 28
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Caduc', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Amp3_IRM', 'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_tri_TempJ', 'VarT_tri_NDVI',
#        'Max_EVI', 'Ret_eau', 'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842431
# 27
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Var_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Ret_eau',
#        'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842510
# 28
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Var_TempJ', 'Amp3_NDVI', 'VarT_tri_NDVI', 'Max_EVI',
#        'Ret_eau', 'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842510
# 28
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Var_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Ret_eau',
#        'Rugosite_Moyenne', 'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.850353
# 27
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Ret_eau',
#        'Rugosite_Moyenne', 'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842510
# 28
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Var_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Ret_eau',
#        'Pente_Moy', 'IR_sd', 'Prec_Avril', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.846431
# 27
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Ret_eau', 'Pente_Moy',
#        'IR_sd', 'Prec_Avril', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842510
# 27
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_tri_NDVI', 'VarT_bi_EVI', 'Max_EVI', 'Ret_eau',
#        'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.846431
# 28
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'VarT_tri_NDVI', 'VarT_bi_EVI',
#        'Max_EVI', 'Ret_eau', 'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842588
# 28
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_tri_NDVI', 'VarT_bi_EVI', 'Max_EVI', 'Ret_eau',
#        'Pente_Min', 'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.850353
# 27
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Ret_eau', 'Pente_Min',
#        'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842510
# 27
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Min_EVI', 'Max_EVI', 'Ret_eau',
#        'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.846510
# 28
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_bi_TempJ', 'VarT_tri_NDVI', 'Min_EVI',
#        'Max_EVI', 'Ret_eau', 'Pente_Moy', 'IR_sd', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842510
# 27
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'Autres', 'Arbrisseau', 'Pl_herb', 'VegCul', 'Amp3_IRM',
#        'VarT_tri_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Ret_eau', 'Sol_Sable',
# ...
#        'VarT_ann_TempJ', 'Var_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy',
#        'IR_Moy', 'IR_sd', 'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.838745
# 25
# Index(['X_long', 'Bovins', 'Caprins', 'Ovins', 'ZoneAride', 'ZonePel',
#        'Autres', 'VegCul', 'Amp3_IRM', 'VarT_ann_IRM', 'VarT_Cy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'Var_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_Moy', 'IR_sd',
#        'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.838824
# 24
# Index(['X_long', 'Caprins', 'Ovins', 'ZoneAride', 'ZonePel', 'Autres',
#        'VegCul', 'Amp3_IRM', 'VarT_ann_IRM', 'VarT_Cy_IRM', 'Min_IRM',
#        'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'Var_TempN', 'VarT_tri_NDVI',
#        'Max_EVI', 'Pente_Moy', 'IR_Moy', 'IR_sd', 'Bio_Pre_Saison',
#        'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.846667
# 24
# Index(['X_long', 'Bovins', 'Ovins', 'ZoneAride', 'ZonePel', 'Autres', 'VegCul',
#        'Amp3_IRM', 'VarT_ann_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'Var_TempN', 'VarT_tri_NDVI', 'Max_EVI',
#        'Pente_Moy', 'IR_Moy', 'IR_sd', 'Bio_Pre_Saison', 'Prec_Aout',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842745
# 24
# Index(['X_long', 'Bovins', 'Caprins', 'Ovins', 'ZonePel', 'Autres', 'VegCul',
#        'Amp3_IRM', 'VarT_ann_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM',
#        'Ph3_IRM', 'VarT_ann_TempJ', 'Var_TempN', 'VarT_tri_NDVI', 'Max_EVI',
#        'Pente_Moy', 'IR_Moy', 'IR_sd', 'Bio_Pre_Saison', 'Prec_Aout',
#        'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.854510
# 23
# Index(['X_long', 'Bovins', 'Caprins', 'Ovins', 'Autres', 'VegCul', 'Amp3_IRM',
#        'VarT_ann_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'VarT_ann_TempJ', 'Var_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy',
#        'IR_Moy', 'IR_sd', 'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842667
# 26
# Index(['X_long', 'Bovins', 'Caprins', 'Ovins', 'ZoneAride', 'ZonePel',
#        'Autres', 'VegCul', 'Amp3_IRM', 'VarT_ann_IRM', 'VarT_tri_IRM',
#        'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ',
#        'Var_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_Moy', 'IR_sd',
#        'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842745
# 26
# Index(['X_long', 'Bovins', 'Caprins', 'Ovins', 'ZoneAride', 'ZonePel',
#        'Autres', 'VegCul', 'Amp3_IRM', 'VarT_ann_IRM', 'VarT_Cy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'VarT_cy_TempN',
#        'Var_TempN', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_Moy', 'IR_sd',
#        'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.838824
# 26
# Index(['X_long', 'Bovins', 'Caprins', 'Ovins', 'ZoneAride', 'ZonePel',
#        'Autres', 'VegCul', 'Amp3_IRM', 'VarT_ann_IRM', 'VarT_Cy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'Var_TempN',
#        'VarT_tri_NDVI', 'VarT_bi_EVI', 'Max_EVI', 'Pente_Moy', 'IR_Moy',
#        'IR_sd', 'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842667
# 26
# Index(['X_long', 'Bovins', 'Caprins', 'Ovins', 'ZoneAride', 'ZonePel',
#        'Autres', 'VegCul', 'Amp3_IRM', 'VarT_ann_IRM', 'VarT_Cy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'Var_TempN',
#        'VarT_tri_NDVI', 'VarT_tri_EVI', 'Max_EVI', 'Pente_Moy', 'IR_Moy',
#        'IR_sd', 'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842745
# 26
# Index(['X_long', 'Bovins', 'Caprins', 'Ovins', 'ZoneAride', 'ZonePel',
#        'Autres', 'VegCul', 'Amp3_IRM', 'VarT_ann_IRM', 'VarT_Cy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'Var_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Geom_maj', 'Pente_Moy', 'IR_Moy', 'IR_sd',
#        'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.842667
# 26
# Index(['X_long', 'Bovins', 'Caprins', 'Ovins', 'ZoneAride', 'ZonePel',
#        'Autres', 'VegCul', 'Amp3_IRM', 'VarT_ann_IRM', 'VarT_Cy_IRM',
#        'Min_IRM', 'Ph1_IRM', 'Ph3_IRM', 'VarT_ann_TempJ', 'Var_TempN',
#        'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy', 'IR_Moy', 'IR_sd',
#        'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv', 'Tmax_Mai', 'Tmin_Juill'],
#       dtype='object')
# -----------
# acc : 0.834902
# 23
# Index(['X_long', 'Bovins', 'Caprins', 'Ovins', 'ZoneAride', 'ZonePel',
#        'Autres', 'Amp3_IRM', 'VarT_Cy_IRM', 'Min_IRM', 'Ph1_IRM', 'Ph3_IRM',
#        'Amp1_TempJ', 'VarT_ann_TempJ', 'VarT_tri_NDVI', 'Max_EVI', 'Pente_Moy',
#        'IR_Moy', 'IR_sd', 'Bio_Pre_Saison', 'Prec_Aout', 'Tmax_Janv',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-3e6d214c44a1> in <module>
# ----> 1 explor_acc(Fs_acc,0.653725,algo)
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-26-83800041fae5> in explor_acc(fs, acc, algo)
#       7     neighbor[i] = not fs[i]
#       8     if (neighbor not in explored_models_acc) :
# ----> 9       score_acc = cross_val_score(algo, transform(X, neighbor) , y, scoring='accuracy', cv=cv, n_jobs=-1)
#      10       mean_score_acc = np.mean(score_acc)
#      11       explored_models_acc.append(neighbor)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265     # independent, and that it is pickle-able.
#     266     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267     results = parallel(
#     268         delayed(_fit_and_score)(
#     269             clone(estimator),
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                     return self.__get_result()
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#     441                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
lst_var=[]
lst_nbv=[]
for i in range (len(var_acc)):
  pp=set(var_acc[i].columns)
  str = ','.join(pp)
  lst_var.append(str)
  lst_nbv.append(len(var_acc[i].columns))
df = pd.DataFrame({'var': lst_var,
     'nbv': lst_nbv,
     'score_acc': scores_acc
    })
df
df.to_excel("weka m2.xlsx")
