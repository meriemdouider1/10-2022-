# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/10-2022--12-2022/blob/main/Cs_longia/%20weka_m3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ---"AdaBoostClassifier"

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot
from sklearn.ensemble import AdaBoostClassifier

# %%
Cl1 = '/content/cs-longia.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
data
# Out:
#      Cs_longia     X_long      Y_lat    Bovins    Volaille   Caprins  \
# 0            1 -15.911420  23.794740  0.000000    0.000000  0.000000
# 1            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 2            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 3            0 -13.185620  27.157940  0.000000    0.000000  0.000000
# 4            0 -13.167180  27.157730  0.000000    0.000000  0.000000
# ..         ...        ...        ...       ...         ...       ...
# 249          1  -5.366667  35.766667  8.495770  105.550156  8.691405
# 250          1  -5.816667  35.783333  0.000000    0.000000  0.000000
# 251          1  -5.366667  35.833333  7.411978  111.459663  7.364459
# 252          1  -5.558611  35.841944  5.696193    5.641273  0.602672
# 253          1  -5.483333  35.900000  6.839514   15.082421  0.782080
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.269410          0        100  ...        5.1         5.6
# 4     0.000000  0.379107          0        100  ...        5.0         5.2
# ..         ...       ...        ...        ...  ...        ...         ...
# 249  15.116930  0.698221          0          0  ...        4.6         4.3
# 250   0.000000  1.725019          0          0  ...        4.6         4.1
# 251  15.054404  0.991284          0          0  ...        4.5         4.3
# 252   4.306276  0.000000          0          0  ...        4.6         4.0
# 253   6.042903  0.595441          0          0  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 226 columns]

# %%
data["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cs_longia']
y = data.Cs_longia

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred)
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_pos
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %%
lst=["Bovins", "Ph1_EVI", "Var_EVI", "Rad_Mai", "Tmax_Avril"]

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)

# %%
classifiers = {
"AdaBoost": AdaBoostClassifier(random_state=0)
}
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  X[lst], y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  X[lst], y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X[lst], y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X[lst], y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, X[lst], y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, X[lst], y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  X[lst], y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  X[lst], y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  X[lst], y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  X[lst], y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  X[lst], y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# AdaBoost
# Accuracy: [0.7254902  0.64705882 0.66666667 0.7254902  0.66      ]
# moy_accuracy: 0.684941
# -------------------------------------------------
# sensibilité : [0.67741935 0.86363636 0.5        0.7        0.58333333]
# moy_sensibilité: 0.664878
# -------------------------------------------------
# spécificité : [0.8        0.48275862 0.9047619  0.74193548 0.73076923]
# moy_spécificité: 0.732045
# -------------------------------------------------
# MCC : [0.46627184 0.36393013 0.42257713 0.43565668 0.31794729]
# MCC: 0.401277
# -------------------------------------------------
# precision-po: [0.84       0.55882353 0.88235294 0.63636364 0.66666667]
# moy_precision-po: 0.716841
# -------------------------------------------------
# precision-ne : [0.61538462 0.82352941 0.55882353 0.79310345 0.65517241]
# moy_precision-ne: 0.689203
# -------------------------------------------------
# AUC : [0.6983871  0.75626959 0.74047619 0.73387097 0.65224359]
# moy_AUC: 0.716249
# -------------------------------------------------
# VN : [16 14 19 23 19]
# VP : [21 19 15 14 14]
# FP : [ 4 15  2  8  7]
# FN : [10  3 15  6 10]
# -------------------------------------------------
# -------------------------------------------------

# %%
clmns=X.columns
def transform(X, fs) :
  X_ = X.copy()
  for i in range(len(fs)) :
    if fs[i] == False :
      X_.drop([clmns[i]], axis=1, inplace=True)
  return X_
def Retransform (lst):
  Fs=[]      
  for i in range(225):
    if clmns[i] in lst :
       Fs.append(True)
    else :
       Fs.append(False)
  return Fs

# %%
Fs_acc = Retransform (lst)
cv = KFold(n_splits=5, random_state=1, shuffle=True)

# %%
explored_models_acc = []
models_mm_acc=[]
var_acc=[]
scores_acc=[]

# %%
def explor_acc(fs, acc, algo) :
  if (sum(fs) > 225) :
    return
  explored_models_acc.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models_acc) :
      score_acc = cross_val_score(algo, transform(X, neighbor) , y, scoring='accuracy', cv=cv, n_jobs=-1)
      mean_score_acc = np.mean(score_acc)
      explored_models_acc.append(neighbor)
      if (mean_score_acc  > acc) :
        models_mm_acc.append(neighbor)
        print("acc : %f" % mean_score_acc)
        print(len(transform(X,neighbor).columns))
        print(transform(X,neighbor).columns)
        print("-----------")
        scores_acc.append(mean_score_acc)
        var_acc.append(transform(X,neighbor))
        explor_acc(neighbor, mean_score_acc, algo)

# %%
algo=AdaBoostClassifier(random_state=0)

# %%
explor_acc(Fs_acc,0.684941,algo)
# Out:
# acc : 0.712314
# 6
# Index(['Y_lat', 'Bovins', 'Ph1_EVI', 'Var_EVI', 'Rad_Mai', 'Tmax_Avril'], dtype='object')
# -----------
# acc : 0.712549
# 7
# Index(['Y_lat', 'Bovins', 'Ovins', 'Ph1_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.716471
# 8
# Index(['X_long', 'Y_lat', 'Bovins', 'Ovins', 'Ph1_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.720627
# 7
# Index(['X_long', 'Y_lat', 'Ovins', 'Ph1_EVI', 'Var_EVI', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.736314
# 8
# Index(['X_long', 'Y_lat', 'Ovins', 'ZoneAride', 'Ph1_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.744157
# 9
# Index(['X_long', 'Y_lat', 'Ovins', 'ZoneAride', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.748157
# 8
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.751922
# 9
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.760000
# 10
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.760078
# 11
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'Amp2_NDVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.767922
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'ZonePel', 'VegCul', 'Amp1_TempJ',
#        'Amp2_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.779686
# 13
# Index(['X_long', 'Y_lat', 'ZoneAride', 'ZonePel', 'Lesfeuillus', 'VegCul',
#        'Amp1_TempJ', 'Amp2_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.795373
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Lesfeuillus', 'VegCul', 'Amp1_TempJ',
#        'Amp2_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.783294
# 13
# Index(['X_long', 'Y_lat', 'ZoneAride', 'ZonePel', 'VegCul', 'Amp1_TempJ',
#        'Max_TempJ', 'Amp2_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.764000
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'Min_TempN',
#        'Amp2_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.763765
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'Amp2_NDVI',
#        'Ph1_EVI', 'Var_EVI', 'Sol_teneur', 'Elev_Max', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.767686
# 13
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'Amp2_NDVI',
#        'Ph1_EVI', 'Var_EVI', 'Sol_teneur', 'Elev_Max', 'Prec_Janv', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.763922
# 11
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'VarT_ann_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.767451
# 10
# Index(['X_long', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'VarT_ann_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.771373
# 11
# Index(['X_long', 'ZoneAride', 'VegCul', 'VarT_tri_IRM', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775373
# 12
# Index(['X_long', 'ZoneAride', 'ZonePel', 'VegCul', 'VarT_tri_IRM',
#        'Amp1_TempJ', 'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.779373
# 13
# Index(['X_long', 'ZoneAride', 'ZonePel', 'VegCul', 'VarT_tri_IRM',
#        'Amp1_TempJ', 'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'Prec_Aout', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.783373
# 12
# Index(['X_long', 'ZoneAride', 'VegCul', 'VarT_tri_IRM', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Prec_Aout',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.771608
# 12
# Index(['X_long', 'ZoneAride', 'VegCul', 'VarT_tri_IRM', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'IR_Moy', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775529
# 13
# Index(['X_long', 'ZoneAride', 'VegCul', 'VarT_tri_IRM', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum', 'Elev_Max',
#        'IR_Moy', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.771529
# 12
# Index(['X_long', 'ZoneAride', 'VegCul', 'VarT_tri_IRM', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Prec_Mai', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.767922
# 11
# Index(['X_long', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'VarT_ann_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Bio_Pre_sec', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.771843
# 12
# Index(['X_long', 'Volaille', 'ZoneAride', 'VegCul', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Bio_Pre_sec',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.779686
# 11
# Index(['X_long', 'Volaille', 'VegCul', 'Amp1_TempJ', 'VarT_ann_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'Bio_Pre_sec', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775765
# 13
# Index(['X_long', 'Volaille', 'ZoneAride', 'VegCul', 'Var_IRM', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Bio_Pre_sec',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.779608
# 14
# Index(['X_long', 'Volaille', 'ZoneAride', 'VegCul', 'Var_IRM', 'Amp1_TempJ',
#        'VarT_bi_TempN', 'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'Bio_Pre_sec', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775608
# 13
# Index(['X_long', 'Volaille', 'ZoneAride', 'VegCul', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'VarT_bi_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'Bio_Pre_sec', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.779529
# 14
# Index(['X_long', 'Volaille', 'ZoneAride', 'VegCul', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'VarT_bi_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'Geom_maj', 'Bio_Pre_sec', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.779608
# 15
# Index(['X_long', 'Volaille', 'ZoneAride', 'VegCul', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'VarT_bi_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'Geom_maj', 'Bio_Pre_sec', 'Rad_Mai', 'Tmax_Avril', 'Vap_Oct'],
#       dtype='object')
# -----------
# acc : 0.779765
# 16
# Index(['X_long', 'Volaille', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'Var_TempN',
#        'VarT_ann_EVI', 'VarT_bi_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'Geom_maj', 'Bio_Pre_sec', 'Rad_Mai', 'Tmax_Avril', 'Vap_Oct'],
#       dtype='object')
# -----------
# acc : 0.783686
# 17
# Index(['X_long', 'Volaille', 'ZoneAride', 'Lesfeuillus', 'VegCul',
#        'Amp1_TempJ', 'Var_TempN', 'VarT_ann_EVI', 'VarT_bi_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'Geom_maj', 'Bio_Pre_sec', 'Rad_Mai',
#        'Tmax_Avril', 'Vap_Oct'],
#       dtype='object')
# -----------
# acc : 0.787608
# 16
# Index(['X_long', 'Volaille', 'ZoneAride', 'Lesfeuillus', 'VegCul',
#        'Amp1_TempJ', 'Var_TempN', 'VarT_ann_EVI', 'VarT_bi_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'Bio_Pre_sec', 'Rad_Mai', 'Tmax_Avril',
#        'Vap_Oct'],
#       dtype='object')
# -----------
# acc : 0.775608
# 12
# Index(['X_long', 'ZoneAride', 'Pl_herb', 'VegCul', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Bio_Pre_sec',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.779608
# 13
# Index(['X_long', 'ZoneAride', 'ZonePel', 'Pl_herb', 'VegCul', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Bio_Pre_sec',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.783529
# 14
# Index(['X_long', 'ZoneAride', 'ZonePel', 'Pl_herb', 'VegCul', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Bio_Pre_sec',
#        'Prec_Juin', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.787529
# 12
# Index(['X_long', 'ZoneAride', 'VegCul', 'Max_IRM', 'Amp1_TempJ',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Bio_Pre_sec',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.768000
# 12
# Index(['X_long', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'Min_NDVI',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Bio_Pre_sec',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775843
# 13
# Index(['X_long', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'Min_NDVI',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Bio_Pre_sec',
#        'Prec_Sept', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775843
# 12
# Index(['X_long', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'VarT_ann_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Sol_Carbone_stock', 'Elev_Max', 'Bio_Pre_sec',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.783686
# 13
# Index(['X_long', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'VarT_ann_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Sol_Carbone_stock', 'Elev_Max', 'Geom_maj',
#        'Bio_Pre_sec', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775765
# 12
# Index(['X_long', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'VarT_ann_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Bio_Pre_sec', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.771765
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'VarT_bi_TempJ',
#        'VarT_ann_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775608
# 9
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'Ph1_EVI',
#        'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.787608
# 10
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'VarT_bi_TempN',
#        'Ph1_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.783373
# 10
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'Ph1_EVI',
#        'Elev_Max', 'Rad_Avril', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.795373
# 11
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'VarT_cy_TempJ',
#        'Ph1_EVI', 'Elev_Max', 'Rad_Avril', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.763922
# 11
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.767765
# 12
# Index(['X_long', 'Y_lat', 'Ovins', 'ZoneAride', 'VegCul', 'Amp1_TempJ',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.775765
# 13
# Index(['X_long', 'Y_lat', 'Ovins', 'ZoneAride', 'ZonePel', 'VegCul',
#        'Amp1_TempJ', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.779686
# 12
# Index(['X_long', 'Y_lat', 'Ovins', 'ZonePel', 'VegCul', 'Amp1_TempJ',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.767843
# 13
# Index(['X_long', 'Y_lat', 'Ovins', 'ZoneAride', 'Caduc', 'VegCul',
#        'Amp1_TempJ', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.771765
# 12
# Index(['X_long', 'Y_lat', 'Ovins', 'Caduc', 'VegCul', 'Amp1_TempJ', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.771922
# 13
# Index(['X_long', 'Y_lat', 'Ovins', 'Caduc', 'VegCul', 'Amp1_TempJ', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'Pente_sd', 'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.775843
# 14
# Index(['X_long', 'Y_lat', 'Ovins', 'ZonePel', 'Caduc', 'VegCul', 'Amp1_TempJ',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Pente_sd', 'Rad_Mai', 'Tmax_Avril',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.775843
# 14
# Index(['X_long', 'Y_lat', 'Ovins', 'Caduc', 'VegCul', 'VegInond', 'Amp1_TempJ',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Pente_sd', 'Rad_Mai', 'Tmax_Avril',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.775843
# 14
# Index(['X_long', 'Y_lat', 'Ovins', 'Caduc', 'VegCul', 'VarT_tri_IRM',
#        'Amp1_TempJ', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Pente_sd', 'Rad_Mai',
#        'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.775843
# 14
# Index(['X_long', 'Y_lat', 'Ovins', 'Caduc', 'VegCul', 'Var_IRM', 'Amp1_TempJ',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Pente_sd', 'Rad_Mai', 'Tmax_Avril',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.775843
# 14
# Index(['X_long', 'Y_lat', 'Ovins', 'Caduc', 'VegCul', 'Amp1_TempJ',
#        'VarT_bi_TempJ', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Pente_sd',
#        'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.775843
# 14
# Index(['X_long', 'Y_lat', 'Ovins', 'Caduc', 'VegCul', 'Amp1_TempJ',
#        'VarT_tri_TempJ', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Pente_sd',
#        'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.775843
# 14
# Index(['X_long', 'Y_lat', 'Ovins', 'Caduc', 'VegCul', 'Amp1_TempJ', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Elev_Max', 'Pente_sd', 'Rad_Mai',
#        'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.775765
# 13
# Index(['X_long', 'Y_lat', 'Ovins', 'ZoneAride', 'VegCul', 'Amp1_TempJ',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Prec_Oct', 'Rad_Mai', 'Tmax_Avril',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.779686
# 12
# Index(['X_long', 'Y_lat', 'Ovins', 'VegCul', 'Amp1_TempJ', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'Prec_Oct', 'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.775765
# 13
# Index(['X_long', 'Y_lat', 'Ovins', 'ZoneAride', 'VegCul', 'Amp1_TempJ',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mars', 'Rad_Mai', 'Tmax_Avril',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.779686
# 14
# Index(['X_long', 'Y_lat', 'Ovins', 'ZoneAride', 'VegCul', 'Amp1_TempJ',
#        'VarT_bi_TempJ', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mars',
#        'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.783765
# 15
# Index(['X_long', 'Y_lat', 'Ovins', 'ZoneAride', 'VegCul', 'Amp1_TempJ',
#        'VarT_bi_TempJ', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Prec_Avril',
#        'Rad_Mars', 'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.791608
# 16
# Index(['X_long', 'Y_lat', 'Ovins', 'ZoneAride', 'VegCul', 'Amp1_TempJ',
#        'VarT_bi_TempJ', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Prec_Avril',
#        'Prec_Juin', 'Rad_Mars', 'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.767843
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'VarT_bi_TempJ',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.771765
# 13
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'VarT_bi_TempJ',
#        'Amp2_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril',
#        'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.767843
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'VarT_tri_NDVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.771608
# 13
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Pl_herb', 'VegCul', 'Amp1_TempJ',
#        'VarT_tri_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai',
#        'Tmax_Avril', 'Tmax_Mai'],
#       dtype='object')
# -----------
# acc : 0.771686
# 14
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Pl_herb', 'VegCul', 'Amp1_TempJ',
#        'VarT_tri_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai',
#        'Tmax_Avril', 'Tmax_Mai', 'Vap_Avril'],
#       dtype='object')
# -----------
# acc : 0.775608
# 15
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Pl_herb', 'VegCul', 'Var_IRM',
#        'Amp1_TempJ', 'VarT_tri_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai', 'Vap_Avril'],
#       dtype='object')
# -----------
# acc : 0.775608
# 15
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Pl_herb', 'VegCul', 'Amp1_TempJ',
#        'VarT_tri_TempJ', 'VarT_tri_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai', 'Vap_Avril'],
#       dtype='object')
# -----------
# acc : 0.771765
# 13
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Pl_herb', 'VegCul', 'Amp1_TempJ',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai',
#        'Vap_Avril'],
#       dtype='object')
# -----------
# acc : 0.775686
# 14
# Index(['X_long', 'Y_lat', 'Coniferes', 'ZoneAride', 'Pl_herb', 'VegCul',
#        'Amp1_TempJ', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril',
#        'Tmax_Mai', 'Vap_Avril'],
#       dtype='object')
# -----------
# acc : 0.779608
# 15
# Index(['X_long', 'Y_lat', 'Coniferes', 'ZoneAride', 'ZonePel', 'Pl_herb',
#        'VegCul', 'Amp1_TempJ', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai',
#        'Tmax_Avril', 'Tmax_Mai', 'Vap_Avril'],
#       dtype='object')
# -----------
# acc : 0.779608
# 15
# Index(['X_long', 'Y_lat', 'Coniferes', 'ZoneAride', 'Pl_herb', 'VegCul',
#        'VegInond', 'Amp1_TempJ', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai',
#        'Tmax_Avril', 'Tmax_Mai', 'Vap_Avril'],
#       dtype='object')
# -----------
# acc : 0.779608
# 15
# Index(['X_long', 'Y_lat', 'Coniferes', 'ZoneAride', 'Pl_herb', 'VegCul',
#        'Amp1_TempJ', 'VarT_tri_TempJ', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'Rad_Mai', 'Tmax_Avril', 'Tmax_Mai', 'Vap_Avril'],
#       dtype='object')
# -----------
# acc : 0.763922
# 11
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp1_TempJ', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril', 'Vent_Nov'],
#       dtype='object')
# -----------
# acc : 0.771765
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Var_IRM', 'Amp1_TempJ',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril', 'Vent_Nov'],
#       dtype='object')
# -----------
# acc : 0.752157
# 10
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'VarT_tri_NDVI', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.756000
# 11
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp2_TempN', 'VarT_tri_NDVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.764000
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Amp2_TempN', 'VarT_tri_NDVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'Prec_Aout', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.759922
# 10
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Sol_Carbone_terreFine', 'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.763843
# 11
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'VarT_tri_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Sol_Carbone_terreFine', 'Elev_Max', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775608
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'VarT_tri_TempJ',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Var_EVI', 'Sol_Carbone_terreFine',
#        'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.767686
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'VarT_bi_TempN',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Var_EVI', 'Sol_Carbone_terreFine',
#        'Elev_Max', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.763922
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Ph3_NDVI', 'VarT_tri_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Sol_Carbone_terreFine', 'Elev_Max', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.767843
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'VarT_tri_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Sol_Carbone_terreFine', 'Elev_Max', 'IR_Med', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.760000
# 11
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Sol_Carbone_terreFine', 'Elev_Max', 'Prec_Mai', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.763922
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Caduc', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Sol_Carbone_terreFine', 'Elev_Max', 'Prec_Mai', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.767843
# 13
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Lesfeuillus', 'Caduc', 'VegCul',
#        'Ph1_EVI', 'Var_EVI', 'Sol_Carbone_terreFine', 'Elev_Max', 'Prec_Mai',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.771843
# 14
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Lesfeuillus', 'Caduc', 'VegCul',
#        'Ph1_EVI', 'Var_EVI', 'Prob_R', 'Sol_Carbone_terreFine', 'Elev_Max',
#        'Prec_Mai', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775765
# 13
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Caduc', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Prob_R', 'Sol_Carbone_terreFine', 'Elev_Max', 'Prec_Mai', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.779686
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Prob_R', 'Sol_Carbone_terreFine', 'Elev_Max', 'Prec_Mai', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.783529
# 13
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'VarT_bi_TempN', 'Ph1_EVI',
#        'Var_EVI', 'Prob_R', 'Sol_Carbone_terreFine', 'Elev_Max', 'Prec_Mai',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.779686
# 14
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Caduc', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Prob_R', 'Sol_Carbone_terreFine', 'Elev_Max', 'Prec_Mai', 'Prec_Aout',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.787529
# 15
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Lesfeuillus', 'Caduc', 'VegCul',
#        'Ph1_EVI', 'Var_EVI', 'Prob_R', 'Sol_Carbone_terreFine', 'Elev_Max',
#        'Prec_Mai', 'Prec_Aout', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.764000
# 13
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Caduc', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Sol_Carbone_terreFine', 'Elev_Max', 'Bio_Pre_Qhum', 'Prec_Mai',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.771843
# 14
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Caduc', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Sol_Carbone_terreFine', 'Elev_Max', 'Bio_Pre_Qhum', 'Prec_Mai',
#        'Rad_Mai', 'Rad_Oct', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.771765
# 14
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Caduc', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Sol_Carbone_terreFine', 'Elev_Max', 'Bio_Pre_Qhum', 'Prec_Mai',
#        'Rad_Mai', 'Rad_Dec', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775922
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Sol_Carbone_terreFine', 'Elev_Max', 'Bio_Pre_sec', 'Prec_Mai',
#        'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.771686
# 11
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Sol_Carbone_terreFine', 'Elev_Max', 'Prec_Nov', 'Rad_Mai',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.752078
# 10
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Ph1_EVI', 'Var_EVI',
#        'Elev_Max', 'IPT_Med', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.756000
# 11
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'VarT_cy_TempJ', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'IPT_Med', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.760000
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'VegCul', 'Moy_IRM', 'VarT_cy_TempJ',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'IPT_Med', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.763765
# 11
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Moy_IRM', 'VarT_cy_TempJ', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'IPT_Med', 'Rad_Mai', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.771451
# 12
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Moy_IRM', 'VarT_cy_TempJ', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'IPT_Med', 'Rad_Mai', 'Tmax_Mars', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775373
# 13
# Index(['X_long', 'Y_lat', 'ZoneAride', 'ZonePel', 'Moy_IRM', 'VarT_cy_TempJ',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'IPT_Med', 'Rad_Mai', 'Tmax_Mars',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.775373
# 14
# Index(['X_long', 'Y_lat', 'ZoneAride', 'ZonePel', 'Moy_IRM', 'VarT_cy_TempJ',
#        'Amp3_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'IPT_Med', 'Rad_Mai',
#        'Tmax_Mars', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.779294
# 13
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Moy_IRM', 'VarT_cy_TempJ', 'Amp3_NDVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'IPT_Med', 'Rad_Mai', 'Tmax_Mars',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.783216
# 14
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Moy_IRM', 'VarT_cy_TempJ', 'Amp3_NDVI',
#        'VarT_tri_EVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'IPT_Med', 'Rad_Mai',
#        'Tmax_Mars', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.779608
# 14
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Moy_IRM', 'VarT_cy_TempJ', 'Amp3_NDVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'IPT_Med', 'Prec_Fev', 'Rad_Mai',
#        'Tmax_Mars', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.779608
# 15
# Index(['X_long', 'Y_lat', 'Volaille', 'ZoneAride', 'Moy_IRM', 'VarT_cy_TempJ',
#        'Amp3_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'IPT_Med', 'Prec_Fev',
#        'Rad_Mai', 'Tmax_Mars', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.783529
# 16
# Index(['X_long', 'Y_lat', 'Volaille', 'ZoneAride', 'Lesfeuillus', 'Moy_IRM',
#        'VarT_cy_TempJ', 'Amp3_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'IPT_Med', 'Prec_Fev', 'Rad_Mai', 'Tmax_Mars', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.783529
# 17
# Index(['X_long', 'Y_lat', 'Volaille', 'ZoneAride', 'Lesfeuillus', 'Moy_IRM',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Amp3_NDVI', 'Ph1_EVI', 'Var_EVI',
#        'Elev_Max', 'IPT_Med', 'Prec_Fev', 'Rad_Mai', 'Tmax_Mars',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.787373
# 18
# Index(['X_long', 'Y_lat', 'Volaille', 'ZoneAride', 'ZonePel', 'Lesfeuillus',
#        'Moy_IRM', 'VarT_cy_TempJ', 'VarT_tri_TempN', 'Amp3_NDVI', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'IPT_Med', 'Prec_Fev', 'Rad_Mai', 'Tmax_Mars',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.791373
# 18
# Index(['X_long', 'Y_lat', 'Volaille', 'ZoneAride', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'VarT_cy_TempJ', 'VarT_tri_TempN', 'Amp3_NDVI', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'IPT_Med', 'Prec_Fev', 'Rad_Mai', 'Tmax_Mars',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.791373
# 18
# Index(['X_long', 'Y_lat', 'Volaille', 'ZoneAride', 'Lesfeuillus', 'Moy_IRM',
#        'Var_IRM', 'VarT_cy_TempJ', 'VarT_tri_TempN', 'Amp3_NDVI', 'Ph1_EVI',
#        'Var_EVI', 'Elev_Max', 'IPT_Med', 'Prec_Fev', 'Rad_Mai', 'Tmax_Mars',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.791373
# 18
# Index(['X_long', 'Y_lat', 'Volaille', 'ZoneAride', 'Lesfeuillus', 'Moy_IRM',
#        'VarT_tri_TempJ', 'VarT_cy_TempJ', 'VarT_tri_TempN', 'Amp3_NDVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'IPT_Med', 'Prec_Fev', 'Rad_Mai',
#        'Tmax_Mars', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.787451
# 18
# Index(['X_long', 'Y_lat', 'Volaille', 'ZoneAride', 'Lesfeuillus', 'Moy_IRM',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Amp3_NDVI', 'VarT_tri_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'IPT_Med', 'Prec_Fev', 'Rad_Mai',
#        'Tmax_Mars', 'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.791373
# 18
# Index(['X_long', 'Y_lat', 'Volaille', 'ZoneAride', 'Lesfeuillus', 'Moy_IRM',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Amp3_NDVI', 'Ph1_EVI', 'Var_EVI',
#        'Elev_Max', 'Geom_maj', 'IPT_Med', 'Prec_Fev', 'Rad_Mai', 'Tmax_Mars',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.787451
# 18
# Index(['X_long', 'Y_lat', 'Volaille', 'ZoneAride', 'Lesfeuillus', 'Moy_IRM',
#        'VarT_cy_TempJ', 'VarT_tri_TempN', 'Amp3_NDVI', 'Ph1_EVI', 'Var_EVI',
#        'Elev_Max', 'IPT_Med', 'Prec_Fev', 'Prec_Juin', 'Rad_Mai', 'Tmax_Mars',
#        'Tmax_Avril'],
#       dtype='object')
# -----------
# acc : 0.783608
# 17
# Index(['X_long', 'Y_lat', 'Volaille', 'ZoneAride', 'Lesfeuillus', 'Moy_IRM',
#        'VarT_cy_TempJ', 'Amp3_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'IPT_Med', 'Prec_Fev', 'Rad_Mai', 'Tmax_Mars', 'Tmax_Avril',
#        'Tmax_Oct'],
#       dtype='object')
# -----------
# acc : 0.787529
# 18
# Index(['X_long', 'Y_lat', 'Volaille', 'ZoneAride', 'Lesfeuillus', 'Moy_IRM',
#        'VarT_cy_TempJ', 'Amp3_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'IPT_Med', 'Prec_Fev', 'Rad_Mai', 'Tmax_Mars', 'Tmax_Avril', 'Tmax_Oct',
#        'Vent_Sept'],
#       dtype='object')
# -----------
# acc : 0.783216
# 14
# Index(['X_long', 'Y_lat', 'ZoneAride', 'Moy_IRM', 'VarT_cy_TempJ', 'Amp3_NDVI',
#        'Ph1_EVI', 'Var_EVI', 'Elev_Max', 'IPT_Med', 'Rad_Mai', 'Tmax_Mars',
#        'Tmax_Avril', 'Tmin_Sept'],
#       dtype='object')
# -----------
# acc : 0.779294
# 15
# Index(['X_long', 'Y_lat', 'ZoneAride', 'ZonePel', 'VegInond', 'Moy_IRM',
#        'VarT_cy_TempJ', 'Amp3_NDVI', 'Ph1_EVI', 'Var_EVI', 'Elev_Max',
#        'IPT_Med', 'Rad_Mai', 'Tmax_Mars', 'Tmax_Avril'],
#       dtype='object')
# -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-9a2ad7e31ad2> in <module>
# ----> 1 explor_acc(Fs_acc,0.684941,algo)
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-17-83800041fae5> in explor_acc(fs, acc, algo)
#       7     neighbor[i] = not fs[i]
#       8     if (neighbor not in explored_models_acc) :
# ----> 9       score_acc = cross_val_score(algo, transform(X, neighbor) , y, scoring='accuracy', cv=cv, n_jobs=-1)
#      10       mean_score_acc = np.mean(score_acc)
#      11       explored_models_acc.append(neighbor)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265     # independent, and that it is pickle-able.
#     266     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267     results = parallel(
#     268         delayed(_fit_and_score)(
#     269             clone(estimator),
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                     return self.__get_result()
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#     441                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
lst_var=[]
lst_nbv=[]
for i in range (len(var_acc)):
  pp=set(var_acc[i].columns)
  str = ','.join(pp)
  lst_var.append(str)
  lst_nbv.append(len(var_acc[i].columns))
df = pd.DataFrame({'var': lst_var,
     'nbv': lst_nbv,
     'score_acc': scores_acc
    })
df
df.to_excel("weka m3.xlsx")
