# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/10-2022--12-2022/blob/main/Cs_longia/%20weka_m4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ---"AdaBoostClassifier"

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot
from sklearn.ensemble import AdaBoostClassifier

# %%
Cl1 = '/content/cs-longia.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
data
# Out:
#      Cs_longia     X_long      Y_lat    Bovins    Volaille   Caprins  \
# 0            1 -15.911420  23.794740  0.000000    0.000000  0.000000
# 1            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 2            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 3            0 -13.185620  27.157940  0.000000    0.000000  0.000000
# 4            0 -13.167180  27.157730  0.000000    0.000000  0.000000
# ..         ...        ...        ...       ...         ...       ...
# 249          1  -5.366667  35.766667  8.495770  105.550156  8.691405
# 250          1  -5.816667  35.783333  0.000000    0.000000  0.000000
# 251          1  -5.366667  35.833333  7.411978  111.459663  7.364459
# 252          1  -5.558611  35.841944  5.696193    5.641273  0.602672
# 253          1  -5.483333  35.900000  6.839514   15.082421  0.782080
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.269410          0        100  ...        5.1         5.6
# 4     0.000000  0.379107          0        100  ...        5.0         5.2
# ..         ...       ...        ...        ...  ...        ...         ...
# 249  15.116930  0.698221          0          0  ...        4.6         4.3
# 250   0.000000  1.725019          0          0  ...        4.6         4.1
# 251  15.054404  0.991284          0          0  ...        4.5         4.3
# 252   4.306276  0.000000          0          0  ...        4.6         4.0
# 253   6.042903  0.595441          0          0  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 226 columns]

# %%
data["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cs_longia']
y = data.Cs_longia

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred)
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_pos
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %%
lst=["Y_lat","Coniferes","Max_TempJ", "Min_NDVI" , "IPT_sd" , "Tmax_Janv"]

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)

# %%
classifiers = {
"AdaBoost": AdaBoostClassifier(random_state=0)
}
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  X[lst], y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  X[lst], y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X[lst], y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X[lst], y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, X[lst], y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, X[lst], y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  X[lst], y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  X[lst], y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  X[lst], y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  X[lst], y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  X[lst], y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# AdaBoost
# Accuracy: [0.56862745 0.66666667 0.7254902  0.74509804 0.64      ]
# moy_accuracy: 0.669176
# -------------------------------------------------
# sensibilité : [0.5483871  0.72727273 0.6        0.75       0.75      ]
# moy_sensibilité: 0.675132
# -------------------------------------------------
# spécificité : [0.6        0.62068966 0.9047619  0.74193548 0.53846154]
# moy_spécificité: 0.681170
# -------------------------------------------------
# MCC : [0.14492233 0.34526705 0.50881628 0.48268195 0.2941742 ]
# MCC: 0.355172
# -------------------------------------------------
# precision-po: [0.68       0.59259259 0.9        0.65217391 0.6       ]
# moy_precision-po: 0.684953
# -------------------------------------------------
# precision-ne : [0.46153846 0.75       0.61290323 0.82142857 0.7       ]
# moy_precision-ne: 0.669174
# -------------------------------------------------
# AUC : [0.62580645 0.75940439 0.83015873 0.71693548 0.64022436]
# moy_AUC: 0.714506
# -------------------------------------------------
# VN : [12 18 19 23 14]
# VP : [17 16 18 15 18]
# FP : [ 8 11  2  8 12]
# FN : [14  6 12  5  6]
# -------------------------------------------------
# -------------------------------------------------

# %%
clmns=X.columns
def transform(X, fs) :
  X_ = X.copy()
  for i in range(len(fs)) :
    if fs[i] == False :
      X_.drop([clmns[i]], axis=1, inplace=True)
  return X_
def Retransform (lst):
  Fs=[]      
  for i in range(225):
    if clmns[i] in lst :
       Fs.append(True)
    else :
       Fs.append(False)
  return Fs

# %%
Fs_acc = Retransform (lst)
cv = KFold(n_splits=5, random_state=1, shuffle=True)

# %%
explored_models_acc = []
models_mm_acc=[]
var_acc=[]
scores_acc=[]

# %%
def explor_acc(fs, acc, algo) :
  if (sum(fs) > 225) :
    return
  explored_models_acc.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models_acc) :
      score_acc = cross_val_score(algo, transform(X, neighbor) , y, scoring='accuracy', cv=cv, n_jobs=-1)
      mean_score_acc = np.mean(score_acc)
      explored_models_acc.append(neighbor)
      if (mean_score_acc  > acc) :
        models_mm_acc.append(neighbor)
        print("acc : %f" % mean_score_acc)
        print(len(transform(X,neighbor).columns))
        print(transform(X,neighbor).columns)
        print("-----------")
        scores_acc.append(mean_score_acc)
        var_acc.append(transform(X,neighbor))
        explor_acc(neighbor, mean_score_acc, algo)

# %%
algo=AdaBoostClassifier(random_state=0)

# %%
explor_acc(Fs_acc,0.669176,algo)
# Out:
# acc : 0.672784
# 7
# Index(['Y_lat', 'Coniferes', 'Autres', 'Max_TempJ', 'Min_NDVI', 'IPT_sd',
#        'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.688863
# 8
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Autres', 'Max_TempJ', 'Min_NDVI',
#        'IPT_sd', 'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.700627
# 9
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Autres', 'VarT_tri_IRM', 'Max_TempJ',
#        'Min_NDVI', 'IPT_sd', 'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.704549
# 10
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Autres', 'VarT_tri_IRM', 'Max_TempJ',
#        'Min_NDVI', 'IPT_sd', 'Prec_Juin', 'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.704627
# 10
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Autres', 'VarT_tri_IRM', 'Max_TempJ',
#        'Min_NDVI', 'IPT_sd', 'Tmax_Janv', 'Vap_Fev'],
#       dtype='object')
# -----------
# acc : 0.704627
# 11
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Autres', 'VarT_tri_IRM', 'Max_TempJ',
#        'Min_NDVI', 'IPT_sd', 'Bio_Pre_hum', 'Tmax_Janv', 'Vap_Fev'],
#       dtype='object')
# -----------
# acc : 0.708549
# 10
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Autres', 'Max_TempJ', 'Min_NDVI',
#        'IPT_sd', 'Bio_Pre_hum', 'Tmax_Janv', 'Vap_Fev'],
#       dtype='object')
# -----------
# acc : 0.712471
# 11
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Autres', 'VarT_bi_TempJ', 'Max_TempJ',
#        'Min_NDVI', 'IPT_sd', 'Bio_Pre_hum', 'Tmax_Janv', 'Vap_Fev'],
#       dtype='object')
# -----------
# acc : 0.692706
# 9
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Autres', 'Moy_TempJ', 'Max_TempJ',
#        'Min_NDVI', 'IPT_sd', 'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.696627
# 10
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Max_TempJ', 'Min_NDVI', 'IPT_sd', 'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.700235
# 11
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.704392
# 12
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd',
#        'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.708235
# 13
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Rad_Aout',
#        'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.708314
# 14
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd',
#        'Prec_Juin', 'Rad_Aout', 'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.712314
# 13
# Index(['Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'Moy_TempJ', 'Max_TempJ',
#        'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Prec_Juin', 'Rad_Aout',
#        'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.712235
# 14
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Rad_Aout',
#        'Tmax_Janv', 'Tmin_Janv'],
#       dtype='object')
# -----------
# acc : 0.724000
# 13
# Index(['Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'Moy_TempJ', 'Max_TempJ',
#        'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Rad_Aout', 'Tmax_Janv',
#        'Tmin_Janv'],
#       dtype='object')
# -----------
# acc : 0.716235
# 15
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmin_Janv'],
#       dtype='object')
# -----------
# acc : 0.720157
# 16
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'VarT_cy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmin_Janv'],
#       dtype='object')
# -----------
# acc : 0.724078
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'VarT_cy_TempJ', 'Max_TempJ', 'Ph3_TempJ',
#        'VarT_ann_TempN', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Rad_Aout',
#        'Tmax_Janv', 'Tmin_Janv'],
#       dtype='object')
# -----------
# acc : 0.724078
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'VarT_cy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Rugosite_Min', 'IPT_sd', 'Rad_Aout', 'Tmax_Janv',
#        'Tmin_Janv'],
#       dtype='object')
# -----------
# acc : 0.720078
# 16
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmax_Nov', 'Tmin_Janv'],
#       dtype='object')
# -----------
# acc : 0.724000
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'ZoneAride', 'Lesfeuillus', 'Autres',
#        'VarT_ann_IRM', 'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmax_Nov', 'Tmin_Janv'],
#       dtype='object')
# -----------
# acc : 0.732000
# 18
# Index(['Y_lat', 'Bovins', 'Coniferes', 'ZoneAride', 'Lesfeuillus', 'Autres',
#        'VarT_ann_IRM', 'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmax_Nov', 'Tmin_Janv',
#        'Tmin_Mai'],
#       dtype='object')
# -----------
# acc : 0.727922
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'IPT_sd', 'Bio_Pre_Qsec', 'Rad_Aout', 'Tmax_Janv', 'Tmax_Nov',
#        'Tmin_Janv'],
#       dtype='object')
# -----------
# acc : 0.731765
# 18
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'VarT_cy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Bio_Pre_Qsec', 'Rad_Aout', 'Tmax_Janv',
#        'Tmax_Nov', 'Tmin_Janv'],
#       dtype='object')
# -----------
# acc : 0.731608
# 18
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'IPT_sd', 'Bio_Pre_Qsec', 'Rad_Aout', 'Tmax_Janv', 'Tmax_Nov',
#        'Tmin_Janv', 'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.731765
# 19
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'IPT_sd', 'Bio_Pre_Qsec', 'Prec_Aout', 'Rad_Aout', 'Tmax_Janv',
#        'Tmax_Nov', 'Tmin_Janv', 'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.751373
# 20
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'IPT_sd', 'Bio_Pre_Qsec', 'Prec_Juin', 'Prec_Aout', 'Rad_Aout',
#        'Tmax_Janv', 'Tmax_Nov', 'Tmin_Janv', 'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.755294
# 19
# Index(['Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM', 'Moy_TempJ',
#        'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd',
#        'Bio_Pre_Qsec', 'Prec_Juin', 'Prec_Aout', 'Rad_Aout', 'Tmax_Janv',
#        'Tmax_Nov', 'Tmin_Janv', 'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.727843
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmax_Nov', 'Tmin_Janv', 'Vent_Mai'],
#       dtype='object')
# -----------
# acc : 0.728000
# 16
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmin_Janv', 'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.731922
# 15
# Index(['Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM', 'Moy_TempJ',
#        'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Rad_Aout',
#        'Tmax_Janv', 'Tmin_Janv', 'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.731922
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'ZonePel', 'Lesfeuillus', 'Autres',
#        'VarT_ann_IRM', 'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmin_Janv',
#        'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.731922
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VegInond',
#        'VarT_ann_IRM', 'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmin_Janv',
#        'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.731922
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'VarT_tri_IRM', 'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmin_Janv',
#        'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.732000
# 18
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'VarT_tri_IRM', 'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN',
#        'VarT_bi_NDVI', 'Min_NDVI', 'IPT_sd', 'Rad_Aout', 'Tmax_Janv',
#        'Tmin_Janv', 'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.735843
# 19
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'VarT_tri_IRM', 'Moy_TempJ', 'VarT_cy_TempJ', 'Max_TempJ', 'Ph3_TempJ',
#        'Ph2_TempN', 'VarT_bi_NDVI', 'Min_NDVI', 'IPT_sd', 'Rad_Aout',
#        'Tmax_Janv', 'Tmin_Janv', 'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.731922
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Var_IRM', 'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmin_Janv',
#        'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.731922
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'VarT_tri_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmin_Janv',
#        'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.731922
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VarT_ann_IRM',
#        'Moy_TempJ', 'Max_TempJ', 'Ph3_TempJ', 'VarT_tri_TempN', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Rad_Aout', 'Tmax_Janv', 'Tmin_Janv',
#        'Tmin_Mars'],
#       dtype='object')
# -----------
# acc : 0.700392
# 12
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Max_TempJ', 'VarT_bi_TempN', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd',
#        'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.700549
# 13
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'VarT_bi_TempN', 'Ph2_TempN', 'Min_NDVI',
#        'IPT_sd', 'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.708392
# 14
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN', 'VarT_bi_TempN', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Tmax_Janv'],
#       dtype='object')
# -----------
# acc : 0.712392
# 15
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN', 'VarT_bi_TempN', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Tmax_Janv', 'Tmax_Sept'],
#       dtype='object')
# -----------
# acc : 0.720235
# 16
# Index(['Y_lat', 'Bovins', 'Coniferes', 'ZoneAride', 'Lesfeuillus', 'Autres',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN', 'VarT_bi_TempN',
#        'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Tmax_Janv', 'Tmax_Sept'],
#       dtype='object')
# -----------
# acc : 0.728000
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'ZoneAride', 'Lesfeuillus', 'Caduc',
#        'Autres', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN',
#        'VarT_bi_TempN', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Tmax_Janv',
#        'Tmax_Sept'],
#       dtype='object')
# -----------
# acc : 0.720314
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'ZoneAride', 'Lesfeuillus', 'Autres',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN', 'VarT_bi_TempN',
#        'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Rad_Fev', 'Tmax_Janv', 'Tmax_Sept'],
#       dtype='object')
# -----------
# acc : 0.728157
# 16
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN', 'VarT_bi_TempN', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Rad_Fev', 'Tmax_Janv', 'Tmax_Sept'],
#       dtype='object')
# -----------
# acc : 0.732078
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN', 'VarT_bi_TempN', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Prec_Juin', 'Rad_Fev', 'Tmax_Janv', 'Tmax_Sept'],
#       dtype='object')
# -----------
# acc : 0.724000
# 18
# Index(['Y_lat', 'Bovins', 'Coniferes', 'ZoneAride', 'Lesfeuillus', 'Autres',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN', 'VarT_bi_TempN',
#        'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Prec_Oct', 'Rad_Fev', 'Tmax_Janv',
#        'Tmax_Sept'],
#       dtype='object')
# -----------
# acc : 0.728078
# 19
# Index(['Y_lat', 'Bovins', 'Coniferes', 'ZoneAride', 'Lesfeuillus', 'Autres',
#        'Moy_TempJ', 'Amp2_TempJ', 'VarT_ann_TempJ', 'Max_TempJ', 'Amp1_TempN',
#        'VarT_bi_TempN', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Prec_Oct',
#        'Rad_Fev', 'Tmax_Janv', 'Tmax_Sept'],
#       dtype='object')
# -----------
# acc : 0.728000
# 19
# Index(['Y_lat', 'Bovins', 'Coniferes', 'ZoneAride', 'Lesfeuillus', 'Autres',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN', 'VarT_bi_TempN',
#        'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Prec_Oct', 'Rad_Fev', 'Tmax_Janv',
#        'Tmax_Sept', 'Vap_Nov'],
#       dtype='object')
# -----------
# acc : 0.716314
# 16
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VegCul',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN', 'VarT_bi_TempN',
#        'Ph2_TempN', 'Min_NDVI', 'IPT_sd', 'Tmax_Janv', 'Tmax_Sept'],
#       dtype='object')
# -----------
# acc : 0.724157
# 17
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'VegCul',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN', 'VarT_bi_TempN',
#        'Ph2_TempN', 'Min_NDVI', 'Substratum', 'IPT_sd', 'Tmax_Janv',
#        'Tmax_Sept'],
#       dtype='object')
# -----------
# acc : 0.716235
# 15
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN', 'VarT_bi_TempN', 'Ph2_TempN',
#        'Min_NDVI', 'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.728000
# 14
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Amp1_TempN', 'Ph2_TempN', 'Min_NDVI',
#        'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.731843
# 13
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'IPT_sd',
#        'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.731922
# 14
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'VarT_tri_EVI',
#        'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.747843
# 15
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'ZoneUrbaine',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'VarT_tri_EVI', 'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.739843
# 15
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'Ph3_NDVI',
#        'VarT_tri_EVI', 'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.732157
# 15
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Lesfeuillus', 'Autres', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'VarT_tri_EVI',
#        'Prob_R', 'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.747843
# 16
# Index(['Y_lat', 'Bovins', 'Ovins', 'Coniferes', 'Lesfeuillus', 'Autres',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.751765
# 17
# Index(['Y_lat', 'Bovins', 'Ovins', 'Coniferes', 'Lesfeuillus', 'Autres',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'VarT_tri_EVI', 'Substratum', 'Prob_R', 'IPT_sd', 'Tmax_Janv',
#        'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.736078
# 14
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Autres', 'Moy_TempJ', 'Amp2_TempJ',
#        'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'VarT_tri_EVI', 'Prob_R',
#        'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.740078
# 15
# Index(['Y_lat', 'Bovins', 'Coniferes', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'VarT_tri_EVI',
#        'Prob_R', 'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.744000
# 14
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ', 'Amp2_TempJ',
#        'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'VarT_tri_EVI', 'Prob_R',
#        'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.747843
# 13
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ', 'Amp2_TempJ',
#        'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'VarT_tri_EVI', 'IPT_sd',
#        'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.755765
# 15
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ', 'Amp2_TempJ',
#        'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'VarT_tri_EVI', 'Prob_R', 'CEC',
#        'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.759686
# 16
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ', 'Amp2_TempJ',
#        'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'Ph3_NDVI', 'VarT_tri_EVI',
#        'Prob_R', 'CEC', 'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.767608
# 17
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ', 'Amp2_TempJ',
#        'Max_TempJ', 'Ph2_TempN', 'VarT_bi_NDVI', 'Min_NDVI', 'Ph3_NDVI',
#        'VarT_tri_EVI', 'Prob_R', 'CEC', 'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775451
# 18
# Index(['Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'VarT_bi_NDVI', 'Min_NDVI',
#        'Ph3_NDVI', 'VarT_tri_EVI', 'Prob_R', 'CEC', 'IPT_sd', 'Tmax_Janv',
#        'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.767686
# 18
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ', 'Amp2_TempJ',
#        'Max_TempJ', 'VarT_ann_TempN', 'Ph2_TempN', 'VarT_bi_NDVI', 'Min_NDVI',
#        'Ph3_NDVI', 'VarT_tri_EVI', 'Prob_R', 'CEC', 'IPT_sd', 'Tmax_Janv',
#        'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775529
# 19
# Index(['Y_lat', 'Bovins', 'Autres', 'Pl_herb', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'VarT_ann_TempN', 'Ph2_TempN',
#        'VarT_bi_NDVI', 'Min_NDVI', 'Ph3_NDVI', 'VarT_tri_EVI', 'Prob_R', 'CEC',
#        'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.783373
# 20
# Index(['Y_lat', 'Bovins', 'Autres', 'Pl_herb', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'VarT_tri_TempJ', 'Max_TempJ', 'VarT_ann_TempN',
#        'Ph2_TempN', 'VarT_bi_NDVI', 'Min_NDVI', 'Ph3_NDVI', 'VarT_tri_EVI',
#        'Prob_R', 'CEC', 'IPT_sd', 'Tmax_Janv', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.747765
# 15
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ', 'Amp2_TempJ',
#        'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'VarT_tri_EVI', 'Prob_R',
#        'IPT_sd', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.751608
# 16
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ', 'Amp2_TempJ',
#        'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'VarT_tri_EVI', 'Prob_R',
#        'IPT_sd', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.751765
# 17
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ', 'Amp2_TempJ',
#        'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI',
#        'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.767451
# 18
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'Ph1_NDVI',
#        'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev',
#        'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.771373
# 19
# Index(['X_long', 'Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'ZoneUrbaine',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'ZoneUrbaine',
#        'VarT_tri_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.783137
# 21
# Index(['X_long', 'Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'ZoneUrbaine',
#        'VarT_tri_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Rad_Oct', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'ZoneUrbaine',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'Elev_Moyenne', 'IPT_sd',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.783216
# 21
# Index(['X_long', 'Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'ZoneUrbaine',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_bi_EVI', 'VarT_tri_EVI', 'Prob_R', 'Elev_Moyenne',
#        'IPT_sd', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'ZoneUrbaine',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Bio_Pre_Qch',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.787294
# 21
# Index(['X_long', 'Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'ZoneUrbaine',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Bio_Pre_Qch',
#        'Prec_Mai', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.791137
# 22
# Index(['X_long', 'Y_lat', 'Bovins', 'Lesfeuillus', 'Autres', 'ZoneUrbaine',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Bio_Pre_Qch',
#        'Prec_Mai', 'Rad_Mai', 'Rad_Oct', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.771373
# 19
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'VegInond', 'ZoneUrbaine',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'VegInond', 'ZoneUrbaine',
#        'VarT_tri_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.779216
# 21
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'VegInond', 'ZoneUrbaine',
#        'VarT_tri_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Rad_Oct', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.783137
# 22
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'VegInond', 'ZoneUrbaine',
#        'VarT_tri_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd',
#        'Bio_Pre_Qch', 'Rad_Mai', 'Rad_Oct', 'Tmax_Janv', 'Tmax_Fev',
#        'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.791137
# 23
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'VegInond', 'ZoneUrbaine',
#        'VarT_tri_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd',
#        'Bio_Pre_Qch', 'Prec_Mai', 'Rad_Mai', 'Rad_Oct', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'VegInond', 'ZoneUrbaine',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'Elev_Moyenne', 'IPT_sd',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.771373
# 19
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Var_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Var_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.779216
# 21
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Var_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Rad_Oct', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.783137
# 22
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Var_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd',
#        'Bio_Pre_Qch', 'Rad_Mai', 'Rad_Oct', 'Tmax_Janv', 'Tmax_Fev',
#        'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.791137
# 23
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Var_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd',
#        'Bio_Pre_Qch', 'Prec_Mai', 'Rad_Mai', 'Rad_Oct', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.783059
# 21
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Var_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmax_Mars', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.786980
# 22
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'Pl_herb', 'ZoneUrbaine',
#        'VarT_tri_IRM', 'Var_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ',
#        'Ph2_TempN', 'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmax_Mars', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.786980
# 22
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Var_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Prec_Juin',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmax_Mars', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Var_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'Elev_Moyenne', 'IPT_sd',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.771373
# 19
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'Elev_Moyenne', 'IPT_sd',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.771373
# 19
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'VarT_tri_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'VarT_tri_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.783059
# 21
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'VarT_tri_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmax_Mars', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.786980
# 22
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'Pl_herb', 'ZoneUrbaine',
#        'VarT_tri_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'VarT_tri_TempJ',
#        'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI',
#        'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmax_Mars',
#        'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.786980
# 22
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'VarT_tri_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Prec_Juin',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmax_Mars', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'VarT_tri_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'Elev_Moyenne', 'IPT_sd',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.771373
# 19
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'VarT_tri_TempN', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'VarT_tri_TempN', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.779216
# 21
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'VarT_tri_TempN', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Rad_Oct', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.783137
# 22
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'VarT_tri_TempN', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd',
#        'Bio_Pre_Qch', 'Rad_Mai', 'Rad_Oct', 'Tmax_Janv', 'Tmax_Fev',
#        'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.791137
# 23
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'VarT_tri_TempN', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd',
#        'Bio_Pre_Qch', 'Prec_Mai', 'Rad_Mai', 'Rad_Oct', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'VarT_tri_TempN', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'Elev_Moyenne', 'IPT_sd',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.771373
# 19
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'Ph1_NDVI',
#        'VarT_tri_EVI', 'Substratum', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Substratum', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.779216
# 21
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Substratum', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Rad_Oct', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.783137
# 22
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Substratum', 'Prob_R', 'IPT_sd',
#        'Bio_Pre_Qch', 'Rad_Mai', 'Rad_Oct', 'Tmax_Janv', 'Tmax_Fev',
#        'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.791137
# 23
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Substratum', 'Prob_R', 'IPT_sd',
#        'Bio_Pre_Qch', 'Prec_Mai', 'Rad_Mai', 'Rad_Oct', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.779059
# 21
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Substratum', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmax_Mars', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.782980
# 22
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'Pl_herb', 'ZoneUrbaine',
#        'VarT_tri_IRM', 'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Substratum', 'Prob_R',
#        'IPT_sd', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmax_Mars', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.786980
# 22
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Substratum', 'Prob_R', 'IPT_sd',
#        'Prec_Juin', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmax_Mars',
#        'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'Ph1_NDVI',
#        'VarT_tri_EVI', 'Substratum', 'Prob_R', 'Elev_Moyenne', 'IPT_sd',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.779216
# 19
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'Ph1_NDVI',
#        'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Rad_Oct', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.783137
# 20
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'Ph1_NDVI',
#        'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Bio_Pre_Qch', 'Rad_Mai', 'Rad_Oct',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.783059
# 19
# Index(['X_long', 'Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'Ph1_NDVI',
#        'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev',
#        'Tmax_Mars', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.755529
# 18
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Amp2_IRM', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Min_NDVI', 'Ph1_NDVI',
#        'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev',
#        'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.759529
# 19
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Amp2_IRM', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph1_TempN', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.771294
# 20
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Amp2_IRM', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph1_TempN', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Min_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.771451
# 21
# Index(['Y_lat', 'Bovins', 'Caduc', 'Autres', 'ZoneUrbaine', 'Amp2_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Max_TempJ', 'Ph1_TempN', 'Ph2_TempN',
#        'Min_NDVI', 'Ph1_NDVI', 'VarT_tri_EVI', 'Min_EVI', 'Prob_R', 'IPT_sd',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.763373
# 20
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Amp2_IRM', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph1_TempN', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'ProfAbs_Sub', 'IPT_sd',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.767373
# 20
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Amp2_IRM', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph1_TempN', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec', 'Vap_Janv'],
#       dtype='object')
# -----------
# acc : 0.771294
# 21
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Amp2_IRM', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph1_TempN', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Rad_Oct',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec', 'Vap_Janv'],
#       dtype='object')
# -----------
# acc : 0.771451
# 20
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Amp2_IRM', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph1_TempN', 'Ph2_TempN', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec', 'Vap_Aout'],
#       dtype='object')
# -----------
# acc : 0.759608
# 18
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'Moy_TempJ', 'Amp2_TempJ',
#        'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI', 'Ph1_NDVI',
#        'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Fev',
#        'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.771373
# 19
# Index(['Y_lat', 'Bovins', 'ZoneAride', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 20
# Index(['Y_lat', 'Bovins', 'ZoneAride', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec', 'Vap_Janv'],
#       dtype='object')
# -----------
# acc : 0.783137
# 21
# Index(['Y_lat', 'Bovins', 'ZoneAride', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec', 'Vap_Janv', 'Vap_Fev'],
#       dtype='object')
# -----------
# acc : 0.763529
# 19
# Index(['Y_lat', 'Bovins', 'ZonePel', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.767451
# 20
# Index(['Y_lat', 'Bovins', 'ZonePel', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Rad_Oct',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 21
# Index(['Y_lat', 'Bovins', 'ZonePel', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Rad_Oct',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec', 'Vap_Janv'],
#       dtype='object')
# -----------
# acc : 0.783137
# 22
# Index(['Y_lat', 'Bovins', 'ZonePel', 'Autres', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Rad_Oct',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec', 'Vap_Janv', 'Vap_Fev'],
#       dtype='object')
# -----------
# acc : 0.763529
# 19
# Index(['Y_lat', 'Bovins', 'Autres', 'VegInond', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.767451
# 20
# Index(['Y_lat', 'Bovins', 'Autres', 'VegInond', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Rad_Oct',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# acc : 0.775294
# 21
# Index(['Y_lat', 'Bovins', 'Autres', 'VegInond', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Rad_Oct',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec', 'Vap_Janv'],
#       dtype='object')
# -----------
# acc : 0.783137
# 22
# Index(['Y_lat', 'Bovins', 'Autres', 'VegInond', 'ZoneUrbaine', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Rad_Oct',
#        'Tmax_Janv', 'Tmax_Fev', 'Tmin_Dec', 'Vap_Janv', 'Vap_Fev'],
#       dtype='object')
# -----------
# acc : 0.763529
# 19
# Index(['Y_lat', 'Bovins', 'Autres', 'ZoneUrbaine', 'VarT_tri_IRM', 'Moy_TempJ',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempN', 'Amp3_NDVI', 'Min_NDVI',
#        'Ph1_NDVI', 'VarT_tri_EVI', 'Prob_R', 'IPT_sd', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmin_Dec'],
#       dtype='object')
# -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-4ae4a884e0f6> in <module>
# ----> 1 explor_acc(Fs_acc,0.669176,algo)
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#      18         scores_acc.append(mean_score_acc)
#      19         var_acc.append(transform(X,neighbor))
# ---> 20         explor_acc(neighbor, mean_score_acc, algo)
#      21
#
# <ipython-input-13-83800041fae5> in explor_acc(fs, acc, algo)
#       7     neighbor[i] = not fs[i]
#       8     if (neighbor not in explored_models_acc) :
# ----> 9       score_acc = cross_val_score(algo, transform(X, neighbor) , y, scoring='accuracy', cv=cv, n_jobs=-1)
#      10       mean_score_acc = np.mean(score_acc)
#      11       explored_models_acc.append(neighbor)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265     # independent, and that it is pickle-able.
#     266     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267     results = parallel(
#     268         delayed(_fit_and_score)(
#     269             clone(estimator),
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                     return self.__get_result()
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#     441                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
lst_var=[]
lst_nbv=[]
for i in range (len(var_acc)):
  pp=set(var_acc[i].columns)
  str = ','.join(pp)
  lst_var.append(str)
  lst_nbv.append(len(var_acc[i].columns))
df = pd.DataFrame({'var': lst_var,
     'nbv': lst_nbv,
     'score_acc': scores_acc
    })
df
df.to_excel("weka m4.xlsx")
