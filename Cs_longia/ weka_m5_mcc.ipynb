# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/10-2022--12-2022/blob/main/Cs_longia/%20weka_m5_mcc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ---

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %%
Cl1 = '/content/cs-longia.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
data
# Out:
#      Cs_longia     X_long      Y_lat    Bovins    Volaille   Caprins  \
# 0            1 -15.911420  23.794740  0.000000    0.000000  0.000000
# 1            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 2            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 3            0 -13.185620  27.157940  0.000000    0.000000  0.000000
# 4            0 -13.167180  27.157730  0.000000    0.000000  0.000000
# ..         ...        ...        ...       ...         ...       ...
# 249          1  -5.366667  35.766667  8.495770  105.550156  8.691405
# 250          1  -5.816667  35.783333  0.000000    0.000000  0.000000
# 251          1  -5.366667  35.833333  7.411978  111.459663  7.364459
# 252          1  -5.558611  35.841944  5.696193    5.641273  0.602672
# 253          1  -5.483333  35.900000  6.839514   15.082421  0.782080
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.269410          0        100  ...        5.1         5.6
# 4     0.000000  0.379107          0        100  ...        5.0         5.2
# ..         ...       ...        ...        ...  ...        ...         ...
# 249  15.116930  0.698221          0          0  ...        4.6         4.3
# 250   0.000000  1.725019          0          0  ...        4.6         4.1
# 251  15.054404  0.991284          0          0  ...        4.5         4.3
# 252   4.306276  0.000000          0          0  ...        4.6         4.0
# 253   6.042903  0.595441          0          0  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 226 columns]

# %%
data["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cs_longia']
y = data.Cs_longia

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred)
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_pos
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %%
lst=["Moy_IRM","Min_IRM", "Ph3_IRM", "Amp3_TempJ", "Prob_R",  "Prec_Juill", "Rad_Janv", "Rad_Mai","Tmax_Janv", "Vent_Oct"]

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)

# %%
classifiers = {
"Gradient_boosting": GradientBoostingClassifier(random_state=0)
}
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  X[lst], y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  X[lst], y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X[lst], y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X[lst], y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, X[lst], y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, X[lst], y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  X[lst], y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  X[lst], y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  X[lst], y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  X[lst], y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  X[lst], y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# Gradient_boosting
# Accuracy: [0.68627451 0.7254902  0.64705882 0.64705882 0.66      ]
# moy_accuracy: 0.673176
# -------------------------------------------------
# sensibilité : [0.5483871  0.81818182 0.56666667 0.7        0.70833333]
# moy_sensibilité: 0.668314
# -------------------------------------------------
# spécificité : [0.9        0.65517241 0.76190476 0.61290323 0.61538462]
# moy_spécificité: 0.709073
# -------------------------------------------------
# MCC : [0.45279035 0.47114401 0.32650492 0.30559708 0.32449893]
# MCC: 0.376107
# -------------------------------------------------
# precision-po: [0.89473684 0.64285714 0.77272727 0.53846154 0.62962963]
# moy_precision-po: 0.695682
# -------------------------------------------------
# precision-ne : [0.5625     0.82608696 0.55172414 0.76       0.69565217]
# moy_precision-ne: 0.679193
# -------------------------------------------------
# AUC : [0.6983871  0.79075235 0.74444444 0.79032258 0.68429487]
# moy_AUC: 0.741640
# -------------------------------------------------
# VN : [18 19 16 19 16]
# VP : [17 18 17 14 17]
# FP : [ 2 10  5 12 10]
# FN : [14  4 13  6  7]
# -------------------------------------------------
# -------------------------------------------------

# %%
clmns=X.columns
def transform(X, fs) :
  X_ = X.copy()
  for i in range(len(fs)) :
    if fs[i] == False :
      X_.drop([clmns[i]], axis=1, inplace=True)
  return X_
def Retransform (lst):
  Fs=[]      
  for i in range(225):
    if clmns[i] in lst :
       Fs.append(True)
    else :
       Fs.append(False)
  return Fs

# %%
Fs_mcc = Retransform (lst)
cv = KFold(n_splits=5, random_state=1, shuffle=True)

# %%
explored_models_mcc = []
models_mm_mcc=[]
var_mcc=[]
scores_mcc=[]

# %%
def explor_mcc(fs, mcc, algo) :
  if (sum(fs) > 225) :
    return
  explored_models_mcc.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models_mcc) :
      score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
      mean_score_mcc = np.mean(score_mcc)
      explored_models_mcc.append(neighbor)
      if (mean_score_mcc  > mcc) :
        models_mm_mcc.append(neighbor)
        print("acc : %f" % mean_score_mcc)
        print(len(transform(X,neighbor).columns))
        print(transform(X,neighbor).columns)
        print("-----------")
        scores_mcc.append(mean_score_mcc)
        var_mcc.append(transform(X,neighbor))
        explor_mcc(neighbor, mean_score_mcc, algo)

# %%
algo=GradientBoostingClassifier(random_state=0)

# %%
explor_mcc(Fs_mcc,0.376107,algo)
# Out:
# acc : 0.384927
# 11
# Index(['X_long', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Amp3_TempJ', 'Prob_R',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.437111
# 12
# Index(['X_long', 'Volaille', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Amp3_TempJ',
#        'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.448386
# 13
# Index(['X_long', 'Volaille', 'Ovins', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM',
#        'Amp3_TempJ', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.455916
# 14
# Index(['X_long', 'Y_lat', 'Volaille', 'Ovins', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM',
#        'Amp3_TempJ', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.461682
# 15
# Index(['X_long', 'Y_lat', 'Volaille', 'Ovins', 'Lesfeuillus', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Amp3_TempJ', 'Prob_R', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.467515
# 14
# Index(['X_long', 'Volaille', 'Ovins', 'Lesfeuillus', 'Moy_IRM', 'Min_IRM',
#        'Ph3_IRM', 'Amp3_TempJ', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.477314
# 13
# Index(['X_long', 'Ovins', 'Lesfeuillus', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM',
#        'Amp3_TempJ', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.481124
# 14
# Index(['X_long', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Moy_IRM', 'Min_IRM',
#        'Ph3_IRM', 'Amp3_TempJ', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.484809
# 15
# Index(['X_long', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Moy_IRM', 'Min_IRM',
#        'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Prob_R', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.486415
# 16
# Index(['X_long', 'Volaille', 'Ovins', 'ZonePel', 'Lesfeuillus', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Prob_R', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.506308
# 17
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Prob_R',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.510388
# 18
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.516689
# 19
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegCul', 'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ',
#        'Amp3_TempJ', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.520750
# 18
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegCul', 'VegInond', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.525008
# 19
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegCul', 'VegInond', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Substratum', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.527557
# 20
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegCul', 'VegInond', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Moy_EVI', 'Substratum', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.529980
# 19
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'VegCul',
#        'VegInond', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Moy_EVI',
#        'Substratum', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.534689
# 20
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'VegCul', 'VegInond', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Moy_EVI', 'Substratum', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.527353
# 19
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegCul', 'VegInond', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Fev', 'Rad_Mai', 'Tmax_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.533844
# 19
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegCul', 'VegInond', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.541001
# 18
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Prob_R',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.536463
# 20
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegCul', 'VegInond', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmin_Sept', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.515656
# 19
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_bi_TempN', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.522269
# 20
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Prob_R', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.524819
# 21
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'Prob_R', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.535562
# 22
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'Prob_R', 'Bio_Pre_hum',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.531788
# 22
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'Prob_R', 'Prec_Juill',
#        'Prec_Oct', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.546607
# 22
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'Prob_R', 'Prec_Juill',
#        'Prec_Nov', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.529255
# 22
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'Prob_R', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Juin', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.535314
# 21
# Index(['X_long', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'Moy_TempN', 'VarT_bi_TempN', 'Prob_R', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Vent_Juin', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.542603
# 20
# Index(['X_long', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'Moy_TempN', 'VarT_bi_TempN', 'Prob_R', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Vent_Juin', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.551933
# 21
# Index(['X_long', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'Moy_TempN', 'VarT_bi_TempN', 'Prob_R', 'Prec_Juin', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Juin', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.538844
# 20
# Index(['X_long', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'Moy_TempN', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Vent_Juin', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.537018
# 22
# Index(['X_long', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'Moy_TempN', 'VarT_bi_TempN', 'Max_EVI', 'Prob_R', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Juin', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.530818
# 23
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'Substratum', 'Prob_R',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Juin',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.535314
# 24
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ',
#        'Amp3_TempJ', 'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'Substratum',
#        'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Juin',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.546675
# 25
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ',
#        'Amp3_TempJ', 'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'VarT_tri_EVI',
#        'Substratum', 'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Juin', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.536571
# 25
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ',
#        'Amp3_TempJ', 'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'Substratum',
#        'Prob_R', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Rad_Nov', 'Tmax_Janv',
#        'Vent_Juin', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.546412
# 24
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZoneAride', 'ZonePel',
#        'Lesfeuillus', 'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ',
#        'Amp3_TempJ', 'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'Prob_R',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Rad_Nov', 'Tmax_Janv',
#        'Vent_Juin', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.552255
# 22
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'Moy_TempN', 'Substratum', 'Prob_R', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Juin', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.565122
# 21
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'Lesfeuillus', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'Moy_TempN', 'Substratum', 'Prob_R', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Vent_Juin', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.540806
# 23
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'Prob_R', 'Bio_Pre_Qsec',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Juin',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.542578
# 22
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'Prob_R', 'Bio_Pre_Qsec',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Juin',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.549692
# 23
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'Moy_TempN', 'VarT_bi_TempN', 'Prob_R', 'Isoth',
#        'Bio_Pre_Qsec', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Vent_Juin', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.554255
# 21
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Min_TempN', 'Prob_R', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.526873
# 21
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.528356
# 22
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.537764
# 23
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'VarT_tri_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.539540
# 24
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'VarT_tri_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Prec_Janv', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.539918
# 25
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'VarT_tri_TempN', 'Max_TempN',
#        'Amp1_NDVI', 'Prob_R', 'Elev_Moy', 'Prec_Janv', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.528814
# 23
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moyenne',
#        'Elev_Moy', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.538601
# 24
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_cy_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moyenne', 'Elev_Moy', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.534953
# 24
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Max',
#        'Elev_Moyenne', 'Elev_Moy', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.536339
# 23
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Max', 'Elev_Moyenne',
#        'Elev_Moy', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.551747
# 24
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Max', 'Elev_Moyenne',
#        'Elev_Moy', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vap_Fev',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.552965
# 25
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'Ph3_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Max', 'Elev_Moyenne', 'Elev_Moy', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.557596
# 25
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Amp2_NDVI', 'Prob_R',
#        'Elev_Max', 'Elev_Moyenne', 'Elev_Moy', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.535125
# 25
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Sol_teneur', 'Prob_R',
#        'Elev_Max', 'Elev_Moyenne', 'Elev_Moy', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.535981
# 25
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Max',
#        'Elev_Moyenne', 'Elev_Moy', 'Prec_Juill', 'Prec_Aout', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.547474
# 26
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Ph3_NDVI', 'Prob_R',
#        'Elev_Max', 'Elev_Moyenne', 'Elev_Moy', 'Prec_Juill', 'Prec_Aout',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.553239
# 25
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'Ph3_NDVI', 'Prob_R', 'Elev_Max',
#        'Elev_Moyenne', 'Elev_Moy', 'Prec_Juill', 'Prec_Aout', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.534579
# 24
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moyenne',
#        'Elev_Moy', 'Bio_Pre_sec', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.532445
# 24
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moyenne',
#        'Elev_Moy', 'Bio_Pre_Saison', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.529222
# 23
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Prec_Juin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.532523
# 24
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'IR_Max', 'Prec_Juin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.537321
# 25
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'VarT_tri_EVI', 'Prob_R',
#        'Elev_Moy', 'IR_Max', 'Prec_Juin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.531237
# 23
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Vap_Mars',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.531477
# 24
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'Autres', 'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ',
#        'Amp3_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Vap_Mars', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.532052
# 25
# Index(['X_long', 'Volaille', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'Autres', 'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ',
#        'Amp3_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.537128
# 24
# Index(['X_long', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus', 'Autres',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.550272
# 25
# Index(['X_long', 'Bovins', 'Ovins', 'Coniferes', 'ZonePel', 'Lesfeuillus',
#        'Autres', 'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ',
#        'Amp3_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.547457
# 23
# Index(['X_long', 'Coniferes', 'ZonePel', 'Lesfeuillus', 'Autres', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.549150
# 22
# Index(['X_long', 'Coniferes', 'Lesfeuillus', 'Autres', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.561317
# 23
# Index(['X_long', 'Coniferes', 'Lesfeuillus', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.574155
# 24
# Index(['X_long', 'Coniferes', 'ZonePel', 'Lesfeuillus', 'Autres', 'Pl_herb',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.576633
# 23
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.579839
# 24
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.599689
# 25
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Tmin_Mars', 'Vap_Mars', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.582454
# 25
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.588684
# 26
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Prob_R', 'Elev_Moy', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.594598
# 27
# Index(['X_long', 'Coniferes', 'ZonePel', 'Caduc', 'Autres', 'Pl_herb',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN',
#        'VarT_tri_NDVI', 'Prob_R', 'Elev_Moy', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.588741
# 26
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.597732
# 25
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.602494
# 24
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'Moy_IRM', 'Min_IRM',
#        'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ', 'Min_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.603104
# 23
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'Moy_IRM', 'Min_IRM',
#        'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ', 'Min_TempJ',
#        'Max_TempN', 'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.611923
# 24
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ',
#        'Min_TempJ', 'Max_TempN', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.611923
# 22
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'Moy_IRM', 'Min_IRM',
#        'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ', 'Max_TempN',
#        'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.615364
# 24
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'Moy_IRM', 'Min_IRM',
#        'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ', 'Min_TempJ',
#        'VarT_tri_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.600488
# 24
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.602911
# 25
# Index(['X_long', 'ZonePel', 'Lesfeuillus', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.601143
# 23
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_bi_TempN',
#        'Max_TempN', 'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.607197
# 24
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_bi_TempN',
#        'VarT_tri_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.611635
# 25
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ',
#        'VarT_bi_TempN', 'VarT_tri_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.612936
# 25
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_bi_TempN',
#        'VarT_tri_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moyenne', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.601155
# 24
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_bi_TempN',
#        'Max_TempN', 'VarT_tri_EVI', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.604082
# 24
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_bi_TempN',
#        'Max_TempN', 'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Tmin_Sept', 'Vap_Mars',
#        'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.605571
# 25
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_bi_TempN',
#        'Max_TempN', 'VarT_tri_NDVI', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmin_Sept', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.612345
# 26
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_bi_TempN',
#        'Max_TempN', 'VarT_tri_NDVI', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Tmin_Avril', 'Tmin_Sept', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.612936
# 25
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moyenne', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.603159
# 26
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vap_Nov', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.609739
# 27
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vap_Oct', 'Vap_Nov', 'Vent_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.611915
# 26
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ',
#        'Min_TempJ', 'Max_TempN', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vap_Oct', 'Vap_Nov', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.613227
# 27
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Var_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vap_Oct', 'Vap_Nov', 'Vent_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.615111
# 27
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ',
#        'Min_TempJ', 'VarT_tri_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vap_Oct', 'Vap_Nov', 'Vent_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.615111
# 27
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ',
#        'Min_TempJ', 'Max_TempN', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Fev', 'Vap_Mars', 'Vap_Oct', 'Vap_Nov', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.616217
# 28
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmax_Avril', 'Vap_Mars', 'Vap_Oct', 'Vap_Nov', 'Vent_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.622587
# 29
# Index(['X_long', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'VarT_tri_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Fev', 'Tmax_Avril', 'Vap_Mars', 'Vap_Aout', 'Vap_Oct', 'Vap_Nov',
#        'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.592580
# 27
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.615069
# 26
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.616979
# 27
# Index(['X_long', 'Coniferes', 'ZonePel', 'Caduc', 'Autres', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.618559
# 26
# Index(['X_long', 'Coniferes', 'ZonePel', 'Caduc', 'Autres', 'Moy_IRM',
#        'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.617556
# 26
# Index(['X_long', 'Coniferes', 'ZonePel', 'Caduc', 'Autres', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.618559
# 27
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Var_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.616146
# 25
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'VegInond', 'Moy_IRM',
#        'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Prob_R',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.597659
# 28
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph2_IRM', 'Ph3_IRM', 'Moy_TempJ',
#        'Amp3_TempJ', 'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN',
#        'Max_TempN', 'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.594243
# 28
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Max_NDVI',
#        'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.607497
# 29
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Max_NDVI',
#        'Prob_R', 'Elev_Moy', 'IPT_Max', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv',
#        'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.600937
# 29
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Max_NDVI',
#        'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Bio_Pre_sec', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars',
#        'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.604308
# 30
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Max_NDVI',
#        'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Bio_Pre_sec', 'Prec_Janv',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.616451
# 31
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Max_NDVI',
#        'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Bio_Pre_sec', 'Prec_Janv',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vap_Dec', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.606724
# 30
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Max_NDVI',
#        'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Bio_Pre_sec', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Rad_Nov', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars',
#        'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.619614
# 31
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_bi_TempJ', 'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN',
#        'Max_TempN', 'Max_NDVI', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Bio_Pre_sec', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Rad_Nov',
#        'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.614366
# 31
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'VarT_tri_TempN',
#        'Max_TempN', 'Max_NDVI', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Bio_Pre_sec', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Rad_Nov',
#        'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.608520
# 31
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Max_NDVI',
#        'Prob_R', 'Elev_Moyenne', 'Elev_Moy', 'Bio_Tmin', 'Bio_Pre_sec',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Rad_Nov', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.612457
# 32
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Max_NDVI',
#        'Prob_R', 'Elev_Moyenne', 'Elev_Moy', 'Isoth', 'Bio_Tmin',
#        'Bio_Pre_sec', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Rad_Nov',
#        'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.609080
# 32
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Max_NDVI',
#        'Prob_R', 'Elev_Moyenne', 'Elev_Moy', 'Bio_Tmin', 'Bio_Pre_sec',
#        'Prec_Juill', 'Prec_Aout', 'Rad_Janv', 'Rad_Mai', 'Rad_Nov',
#        'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.596821
# 29
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Max_NDVI',
#        'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmin_Avril', 'Vap_Mars', 'Vent_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.599582
# 29
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN', 'Max_NDVI',
#        'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai',
#        'Tmax_Janv', 'Tmax_Avril', 'Tmin_Mai', 'Vap_Mars', 'Vent_Janv',
#        'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.593865
# 28
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'VegInond',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN',
#        'VarT_tri_EVI', 'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars',
#        'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.604844
# 29
# Index(['X_long', 'Coniferes', 'ZonePel', 'Caduc', 'Autres', 'Pl_herb',
#        'VegInond', 'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ',
#        'Amp3_TempJ', 'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN',
#        'Max_TempN', 'VarT_tri_EVI', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.608665
# 28
# Index(['X_long', 'Coniferes', 'ZonePel', 'Caduc', 'Autres', 'Pl_herb',
#        'Moy_IRM', 'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN',
#        'VarT_tri_EVI', 'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars',
#        'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.615411
# 27
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'Moy_IRM',
#        'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ',
#        'VarT_tri_TempJ', 'Min_TempJ', 'VarT_bi_TempN', 'Max_TempN',
#        'VarT_tri_EVI', 'Prob_R', 'Elev_Moy', 'Bio_Tmin', 'Prec_Juill',
#        'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril', 'Vap_Mars',
#        'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.616419
# 26
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'Moy_IRM',
#        'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'VarT_bi_TempN', 'Max_TempN', 'VarT_tri_EVI', 'Prob_R', 'Elev_Moy',
#        'Bio_Tmin', 'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv',
#        'Tmax_Avril', 'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# acc : 0.617637
# 25
# Index(['X_long', 'Coniferes', 'ZonePel', 'Autres', 'Pl_herb', 'Moy_IRM',
#        'Min_IRM', 'Max_IRM', 'Ph3_IRM', 'Moy_TempJ', 'Amp3_TempJ', 'Min_TempJ',
#        'Max_TempN', 'VarT_tri_EVI', 'Prob_R', 'Elev_Moy', 'Bio_Tmin',
#        'Prec_Juill', 'Rad_Janv', 'Rad_Mai', 'Tmax_Janv', 'Tmax_Avril',
#        'Vap_Mars', 'Vent_Janv', 'Vent_Oct'],
#       dtype='object')
# -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-7c6bfdcb7ee6> in <module>
# ----> 1 explor_mcc(Fs_mcc,0.376107,algo)
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#      18         scores_mcc.append(mean_score_mcc)
#      19         var_mcc.append(transform(X,neighbor))
# ---> 20         explor_mcc(neighbor, mean_score_mcc, algo)
#      21
#
# <ipython-input-15-e4aa2ff6fe71> in explor_mcc(fs, mcc, algo)
#       7     neighbor[i] = not fs[i]
#       8     if (neighbor not in explored_models_mcc) :
# ----> 9       score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
#      10       mean_score_mcc = np.mean(score_mcc)
#      11       explored_models_mcc.append(neighbor)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265     # independent, and that it is pickle-able.
#     266     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267     results = parallel(
#     268         delayed(_fit_and_score)(
#     269             clone(estimator),
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                     return self.__get_result()
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#     441                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
lst_var=[]
lst_nbv=[]
for i in range (len(var_mcc)):
  pp=set(var_mcc[i].columns)
  str = ','.join(pp)
  lst_var.append(str)
  lst_nbv.append(len(var_mcc[i].columns))
df = pd.DataFrame({'var': lst_var,
     'nbv': lst_nbv,
     'score_acc': scores_mcc
    })
df
df.to_excel("weka m5_mcc.xlsx")
