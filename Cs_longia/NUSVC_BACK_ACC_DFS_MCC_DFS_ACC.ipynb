# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/10-2022--12-2022/blob/main/Cs_longia/NUSVC_BACK_ACC_DFS_MCC_DFS_ACC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ----

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_auc_score, r2_score
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
import numpy as np
from sklearn import svm, datasets
from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, metrics, model_selection, svm
from sklearn.metrics import matthews_corrcoef
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from matplotlib import pyplot
from sklearn.svm import SVC

# %%
Cl1 = '/content/cs-longia.xlsx' 
data=pd.read_excel(Cl1, sheet_name=0,header=0,index_col=False, keep_default_na=True)

# %%
data
# Out:
#      Cs_longia     X_long      Y_lat    Bovins    Volaille   Caprins  \
# 0            1 -15.911420  23.794740  0.000000    0.000000  0.000000
# 1            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 2            1 -13.188370  27.132950  0.000214    0.000000  0.063449
# 3            0 -13.185620  27.157940  0.000000    0.000000  0.000000
# 4            0 -13.167180  27.157730  0.000000    0.000000  0.000000
# ..         ...        ...        ...       ...         ...       ...
# 249          1  -5.366667  35.766667  8.495770  105.550156  8.691405
# 250          1  -5.816667  35.783333  0.000000    0.000000  0.000000
# 251          1  -5.366667  35.833333  7.411978  111.459663  7.364459
# 252          1  -5.558611  35.841944  5.696193    5.641273  0.602672
# 253          1  -5.483333  35.900000  6.839514   15.082421  0.782080
#
#          Ovins   Equides  Coniferes  ZoneAride  ...  Vent_Mars  Vent_Avril  \
# 0     0.000000  0.624435          0         97  ...        6.1         6.9
# 1     0.034352  0.040295          0        100  ...        4.8         5.6
# 2     0.034352  0.040295          0        100  ...        4.8         5.6
# 3     0.000000  0.269410          0        100  ...        5.1         5.6
# 4     0.000000  0.379107          0        100  ...        5.0         5.2
# ..         ...       ...        ...        ...  ...        ...         ...
# 249  15.116930  0.698221          0          0  ...        4.6         4.3
# 250   0.000000  1.725019          0          0  ...        4.6         4.1
# 251  15.054404  0.991284          0          0  ...        4.5         4.3
# 252   4.306276  0.000000          0          0  ...        4.6         4.0
# 253   6.042903  0.595441          0          0  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 226 columns]

# %%
data["Cs_longia"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# Name: Cs_longia, Length: 254, dtype: int64

# %%
X = data.loc[:, data.columns != 'Cs_longia']
y = data.Cs_longia

# %%
X
# Out:
#         X_long      Y_lat    Bovins    Volaille   Caprins      Ovins  \
# 0   -15.911420  23.794740  0.000000    0.000000  0.000000   0.000000
# 1   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 2   -13.188370  27.132950  0.000214    0.000000  0.063449   0.034352
# 3   -13.185620  27.157940  0.000000    0.000000  0.000000   0.000000
# 4   -13.167180  27.157730  0.000000    0.000000  0.000000   0.000000
# ..         ...        ...       ...         ...       ...        ...
# 249  -5.366667  35.766667  8.495770  105.550156  8.691405  15.116930
# 250  -5.816667  35.783333  0.000000    0.000000  0.000000   0.000000
# 251  -5.366667  35.833333  7.411978  111.459663  7.364459  15.054404
# 252  -5.558611  35.841944  5.696193    5.641273  0.602672   4.306276
# 253  -5.483333  35.900000  6.839514   15.082421  0.782080   6.042903
#
#       Equides  Coniferes  ZoneAride  ZonePel  ...  Vent_Mars  Vent_Avril  \
# 0    0.624435          0         97        3  ...        6.1         6.9
# 1    0.040295          0        100        0  ...        4.8         5.6
# 2    0.040295          0        100        0  ...        4.8         5.6
# 3    0.269410          0        100        0  ...        5.1         5.6
# 4    0.379107          0        100        0  ...        5.0         5.2
# ..        ...        ...        ...      ...  ...        ...         ...
# 249  0.698221          0          0        0  ...        4.6         4.3
# 250  1.725019          0          0        0  ...        4.6         4.1
# 251  0.991284          0          0        0  ...        4.5         4.3
# 252  0.000000          0          0       58  ...        4.6         4.0
# 253  0.595441          0          0        5  ...        4.7         4.4
#
#      Vent_Mai  Vent_Juin  Vent_Juill  Vent_Aout  Vent_Sept  Vent_Oct  \
# 0         7.2        7.1         7.5        7.2        6.3       5.4
# 1         5.7        6.4         5.9        5.9        5.7       4.3
# 2         5.7        6.4         5.9        5.9        5.7       4.3
# 3         5.5        6.2         6.2        6.2        5.7       4.1
# 4         5.4        5.7         6.2        5.8        5.6       4.2
# ..        ...        ...         ...        ...        ...       ...
# 249       4.1        3.9         3.9        4.1        4.0       4.0
# 250       3.8        3.7         3.7        3.7        3.3       3.6
# 251       4.0        4.0         3.9        4.0        3.9       4.0
# 252       3.8        4.1         3.7        3.4        3.6       3.6
# 253       3.9        3.8         3.9        3.7        4.0       4.0
#
#      Vent_Nov  Vent_Dec
# 0         5.5       4.9
# 1         3.7       3.8
# 2         3.7       3.8
# 3         3.7       3.9
# 4         3.6       3.8
# ..        ...       ...
# 249       4.0       4.2
# 250       3.8       4.0
# 251       3.9       4.3
# 252       3.4       3.6
# 253       4.0       4.2
#
# [254 rows x 225 columns]

# %%
T=X.columns

# %%
lst=[3, 5, 6, 7, 13, 14, 15, 18, 24, 28, 31, 34, 44, 48, 58, 65, 70, 72, 78, 82, 84, 90, 94, 100, 120, 134, 135, 137, 148, 159]

# %%
FX=[]
for i in lst:
  FX.append(T[i])

# %%
X1=X[FX]

# %%
X1
# Out:
#        Volaille      Ovins   Equides  Coniferes  Arbrisseau  Pl_herb  VegCul  \
# 0      0.000000   0.000000  0.624435          0           0        0       0
# 1      0.000000   0.034352  0.040295          0           0        0       0
# 2      0.000000   0.034352  0.040295          0           0        0       0
# 3      0.000000   0.000000  0.269410          0           0        0       0
# 4      0.000000   0.000000  0.379107          0           0        0       0
# ..          ...        ...       ...        ...         ...      ...     ...
# 249  105.550156  15.116930  0.698221          0          13        0      39
# 250    0.000000   0.000000  1.725019          0           0        0       0
# 251  111.459663  15.054404  0.991284          0          21        0      60
# 252    5.641273   4.306276  0.000000          0          14       12       6
# 253   15.082421   6.042903  0.595441          0           9       12      33
#
#      Moy_IRM  VarT_tri_IRM  Ph1_IRM  ...  Ph1_EVI  Substratum  Sol_Argile  \
# 0       3340             0      566  ...      227         200   22.250000
# 1       4010             0      581  ...      232         199   32.583333
# 2       4010             0      581  ...      232         199   32.583333
# 3       3580             0      600  ...      502         166   37.916667
# 4       3000             0      577  ...      421         200   18.500000
# ..       ...           ...      ...  ...      ...         ...         ...
# 249     1390             0      647  ...      253         200   26.250000
# 250     2050             0      593  ...      289         200   26.083333
# 251     1670             0      700  ...      229         200   30.750000
# 252     1070             0      660  ...      312         200   23.666667
# 253     1400             0      674  ...      237         188   23.583333
#
#      Sol_Sable  IPT_Med  Bio_Ta_moy  Bio_Tj_Moy  Bio_Saison  Bio_Pre_Saison  \
# 0    64.833333  -0.1875   20.354167    7.125000  172.263782      105.140599
# 1    52.583333  -0.5000   20.800000    9.816667  271.167506       77.394709
# 2    52.583333  -0.5000   20.800000    9.816667  271.167506       77.394709
# 3    51.083333   1.5625   20.937500    9.558333  269.975813       84.137238
# 4    73.333333  -3.7500   21.075000    9.616666  269.473410       79.471941
# ..         ...      ...         ...         ...         ...             ...
# 249  45.500000   1.3125   17.904167    5.891667  450.436476       79.066686
# 250  39.083333   1.6250   18.087500    5.225000  444.077830       75.152004
# 251  41.333333   2.2500   17.904167    5.858334  449.244095       78.300556
# 252  40.500000  -2.0000   17.766666    7.066666  409.996286       80.065714
# 253  46.250000   0.3125   17.362500    6.691667  397.389906       79.895116
#
#      Prec_Juill
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0
# ..          ...
# 249           1
# 250           1
# 251           1
# 252           1
# 253           1
#
# [254 rows x 30 columns]

# %%
from sklearn.pipeline import make_pipeline
from sklearn.svm import NuSVC
from sklearn.preprocessing import StandardScaler

# %%
def specificite(y_true, y_pred):
  specificite= confusion_matrix(y_true, y_pred)[0,0]/(confusion_matrix(y_true,y_pred)[0,0] + confusion_matrix(y_true, y_pred)[0,1])
  return specificite
my_scorer = make_scorer(specificite, greater_is_better=True)
def MCC(y_true, y_pred):
  MCC= matthews_corrcoef(y_true, y_pred) 
  return MCC
my_scorer1 = make_scorer(MCC, greater_is_better=True)
def présicion_positive(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[1,1])/(cf_matrix[1,1]+cf_matrix[0,1])
  return pre_pos
my_scorer2 = make_scorer(présicion_positive, greater_is_better=True)
def présicion_négative(y_val, preds):
  cf_matrix = confusion_matrix(y_val, preds)
  pre_pos =  (cf_matrix[0,0])/(cf_matrix[0,0]+cf_matrix[1,0])
  return pre_pos
my_scorer3 = make_scorer(présicion_négative, greater_is_better=True)
def VN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,0]
    return value
my_scorer4 = make_scorer(VN, greater_is_better=True)
def VP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,1]
    return value
my_scorer5 = make_scorer(VP, greater_is_better=True)
def FP(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[0,1]
    return value
my_scorer6 = make_scorer(FP, greater_is_better=True)
def FN(y_true, y_pred):
    value = confusion_matrix(y_true, y_pred)[1,0]
    return value
my_scorer7 = make_scorer(FN, greater_is_better=True)

# %%
classifiers = {
"SVC-NU": make_pipeline(StandardScaler(), NuSVC())
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  X1, y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  X1, y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, X1, y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, X1, y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, X1, y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, X1, y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  X1, y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  X1, y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  X1, y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  X1, y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  X1, y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# SVC-NU
# Accuracy: [0.76470588 0.78431373 0.74509804 0.82352941 0.76      ]
# moy_accuracy: 0.775529
# -------------------------------------------------
# sensibilité : [0.64516129 0.77272727 0.66666667 0.7        0.58333333]
# moy_sensibilité: 0.673578
# -------------------------------------------------
# spécificité : [0.95       0.79310345 0.85714286 0.90322581 0.92307692]
# moy_spécificité: 0.885310
# -------------------------------------------------
# MCC : [0.59041889 0.5631887  0.51808466 0.62475802 0.5423696 ]
# MCC: 0.567764
# -------------------------------------------------
# precision-po: [0.95238095 0.73913043 0.86956522 0.82352941 0.875     ]
# moy_precision-po: 0.851921
# -------------------------------------------------
# precision-ne : [0.63333333 0.82142857 0.64285714 0.82352941 0.70588235]
# moy_precision-ne: 0.725406
# -------------------------------------------------
# AUC : [0.78064516 0.78526646 0.73968254 0.7483871  0.75961538]
# moy_AUC: 0.762719
# -------------------------------------------------
# VN : [19 23 18 28 24]
# VP : [20 17 20 14 14]
# FP : [1 6 3 3 2]
# FN : [11  5 10  6 10]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # DFS

# %%
clmns=X.columns

# %%
clmns
# Out:
# Index(['X_long', 'Y_lat', 'Bovins', 'Volaille', 'Caprins', 'Ovins', 'Equides',
#        'Coniferes', 'ZoneAride', 'ZonePel',
#        ...
#        'Vent_Mars', 'Vent_Avril', 'Vent_Mai', 'Vent_Juin', 'Vent_Juill',
#        'Vent_Aout', 'Vent_Sept', 'Vent_Oct', 'Vent_Nov', 'Vent_Dec'],
#       dtype='object', length=225)

# %%
def transform(X, fs) :
  X_ = X.copy()
  for i in range(len(fs)) :
    if fs[i] == False :
      X_.drop([clmns[i]], axis=1, inplace=True)
  return X_

# %%
def Retransform (lst):
  Fs=[]      
  for i in range(225):
    if clmns[i] in lst :
       Fs.append(True)
    else :
       Fs.append(False)
  return Fs

# %%
X1.columns
# Out:
# Index(['Volaille', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
#        'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'VarT_ann_EVI', 'Min_EVI', 'Ph1_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill'],
#       dtype='object')

# %%
lst_v=['Volaille', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
       'VegCul', 'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
       'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI', 'Ph1_NDVI',
       'Ph3_NDVI', 'VarT_ann_EVI', 'Min_EVI', 'Ph1_EVI', 'Substratum',
       'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
       'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill']

# %%
Fs = Retransform (lst_v)

# %%
Fs
# Out:
# [False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
transform(X,Fs)
# Out:
#        Volaille      Ovins   Equides  Coniferes  Arbrisseau  Pl_herb  VegCul  \
# 0      0.000000   0.000000  0.624435          0           0        0       0
# 1      0.000000   0.034352  0.040295          0           0        0       0
# 2      0.000000   0.034352  0.040295          0           0        0       0
# 3      0.000000   0.000000  0.269410          0           0        0       0
# 4      0.000000   0.000000  0.379107          0           0        0       0
# ..          ...        ...       ...        ...         ...      ...     ...
# 249  105.550156  15.116930  0.698221          0          13        0      39
# 250    0.000000   0.000000  1.725019          0           0        0       0
# 251  111.459663  15.054404  0.991284          0          21        0      60
# 252    5.641273   4.306276  0.000000          0          14       12       6
# 253   15.082421   6.042903  0.595441          0           9       12      33
#
#      Moy_IRM  VarT_tri_IRM  Ph1_IRM  ...  Ph1_EVI  Substratum  Sol_Argile  \
# 0       3340             0      566  ...      227         200   22.250000
# 1       4010             0      581  ...      232         199   32.583333
# 2       4010             0      581  ...      232         199   32.583333
# 3       3580             0      600  ...      502         166   37.916667
# 4       3000             0      577  ...      421         200   18.500000
# ..       ...           ...      ...  ...      ...         ...         ...
# 249     1390             0      647  ...      253         200   26.250000
# 250     2050             0      593  ...      289         200   26.083333
# 251     1670             0      700  ...      229         200   30.750000
# 252     1070             0      660  ...      312         200   23.666667
# 253     1400             0      674  ...      237         188   23.583333
#
#      Sol_Sable  IPT_Med  Bio_Ta_moy  Bio_Tj_Moy  Bio_Saison  Bio_Pre_Saison  \
# 0    64.833333  -0.1875   20.354167    7.125000  172.263782      105.140599
# 1    52.583333  -0.5000   20.800000    9.816667  271.167506       77.394709
# 2    52.583333  -0.5000   20.800000    9.816667  271.167506       77.394709
# 3    51.083333   1.5625   20.937500    9.558333  269.975813       84.137238
# 4    73.333333  -3.7500   21.075000    9.616666  269.473410       79.471941
# ..         ...      ...         ...         ...         ...             ...
# 249  45.500000   1.3125   17.904167    5.891667  450.436476       79.066686
# 250  39.083333   1.6250   18.087500    5.225000  444.077830       75.152004
# 251  41.333333   2.2500   17.904167    5.858334  449.244095       78.300556
# 252  40.500000  -2.0000   17.766666    7.066666  409.996286       80.065714
# 253  46.250000   0.3125   17.362500    6.691667  397.389906       79.895116
#
#      Prec_Juill
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0
# ..          ...
# 249           1
# 250           1
# 251           1
# 252           1
# 253           1
#
# [254 rows x 30 columns]

# %%
classifiers = {
"SVC-NU":make_pipeline(StandardScaler(), NuSVC())
}

cv = KFold(n_splits=5, random_state=1, shuffle=True)
for name, clf in classifiers.items():
    print(name)
    # evaluate model
    scores1 = cross_val_score(clf,  transform(X,Fs), y, scoring='accuracy', cv=cv, n_jobs=-1)
    scores2 = cross_val_score(clf,  transform(X,Fs), y, scoring='recall', cv=cv, n_jobs=-1)
    scores3 = cross_val_score(clf, transform(X,Fs), y, scoring=my_scorer, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(clf, transform(X,Fs), y, scoring=my_scorer1, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(clf, transform(X,Fs), y, scoring=my_scorer2, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(clf, transform(X,Fs), y, scoring=my_scorer3, cv=cv, n_jobs=-1)
    scores7 = cross_val_score(clf,  transform(X,Fs), y, scoring='roc_auc', cv=cv, n_jobs=-1)
    scores8 = cross_val_score(clf,  transform(X,Fs), y, scoring=my_scorer4, cv=cv, n_jobs=-1)
    scores9 = cross_val_score(clf,  transform(X,Fs), y, scoring=my_scorer5, cv=cv, n_jobs=-1)
    scores10 = cross_val_score(clf,  transform(X,Fs), y, scoring=my_scorer6, cv=cv, n_jobs=-1)
    scores11 = cross_val_score(clf,  transform(X,Fs), y, scoring=my_scorer7, cv=cv, n_jobs=-1)
    # report performance
    print('Accuracy:',scores1)
    print('moy_accuracy: %f' % mean(scores1))
    print("-------------------------------------------------")
    print('sensibilité :',scores2)
    print('moy_sensibilité: %f' % mean(scores2))
    print("-------------------------------------------------")
    print('spécificité :',scores3)
    print('moy_spécificité: %f' % mean(scores3))
    print("-------------------------------------------------")
    print('MCC :',scores4)
    print('MCC: %f' % mean(scores4))
    print("-------------------------------------------------")
    print('precision-po:',scores5)
    print('moy_precision-po: %f' % mean(scores5))
    print("-------------------------------------------------")
    print('precision-ne :',scores6)
    print('moy_precision-ne: %f' % mean(scores6))
    print("-------------------------------------------------")
    print('AUC :',scores7)
    print('moy_AUC: %f' % mean(scores7))
    print("-------------------------------------------------")
    print('VN :',scores8)
    print('VP :',scores9)
    print('FP :',scores10)
    print('FN :',scores11)
    print("-------------------------------------------------")
    print("-------------------------------------------------")
# Out:
# SVC-NU
# Accuracy: [0.76470588 0.78431373 0.74509804 0.82352941 0.76      ]
# moy_accuracy: 0.775529
# -------------------------------------------------
# sensibilité : [0.64516129 0.77272727 0.66666667 0.7        0.58333333]
# moy_sensibilité: 0.673578
# -------------------------------------------------
# spécificité : [0.95       0.79310345 0.85714286 0.90322581 0.92307692]
# moy_spécificité: 0.885310
# -------------------------------------------------
# MCC : [0.59041889 0.5631887  0.51808466 0.62475802 0.5423696 ]
# MCC: 0.567764
# -------------------------------------------------
# precision-po: [0.95238095 0.73913043 0.86956522 0.82352941 0.875     ]
# moy_precision-po: 0.851921
# -------------------------------------------------
# precision-ne : [0.63333333 0.82142857 0.64285714 0.82352941 0.70588235]
# moy_precision-ne: 0.725406
# -------------------------------------------------
# AUC : [0.78064516 0.78526646 0.73968254 0.7483871  0.75961538]
# moy_AUC: 0.762719
# -------------------------------------------------
# VN : [19 23 18 28 24]
# VP : [20 17 20 14 14]
# FP : [1 6 3 3 2]
# FN : [11  5 10  6 10]
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # DFS-ACC

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)
explored_models_acc = []
scores_accuracy = []
models_mm_acc=[]
var_acc=[]
def explor_acc(fs, acc, algo) :
  if (sum(fs) > 225) :
    return
  explored_models_acc.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models_acc) :
      score_acc = cross_val_score(algo, transform(X, neighbor) , y, scoring="accuracy", cv=cv, n_jobs=-1)
      mean_score_acc = np.mean(score_acc)
      explored_models_acc.append(neighbor)
      if (mean_score_acc  > acc) :
        models_mm_acc.append(neighbor)
        print("accuarcy %f" %mean_score_acc)
        print(len(transform(X,neighbor).columns))
        print(transform(X,neighbor).columns)
        print("-----------")
        scores_accuracy.append(mean_score_acc)
        var_acc.append(transform(X,neighbor))
        explor_acc(neighbor, mean_score_acc, algo)

# %%
algo=make_pipeline(StandardScaler(), NuSVC())

# %%
explor_acc(Fs, 0.775529,algo)
# Out:
# accuarcy 0.775529
# 31
# Index(['Volaille', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
#        'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'VarT_ann_EVI', 'Min_EVI', 'Ph1_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# accuarcy 0.775529
# 31
# Index(['Volaille', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
#        'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'VarT_ann_EVI', 'Min_EVI', 'Ph1_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Aout'],
#       dtype='object')
# -----------

# %% [markdown]
# # dfs mcc

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)
explored_models_mcc = []
scores_mcc = []
models_mm_mcc=[]
var_mcc=[]
def explor_mcc(fs, mcc, algo) :
  if (sum(fs) > 225) :
    return
  explored_models_mcc.append(fs)
  for i in range(225) :
    neighbor = fs.copy()
    neighbor[i] = not fs[i]
    if (neighbor not in explored_models_mcc) :
      score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
      mean_score_mcc = np.mean(score_mcc)
      explored_models_mcc.append(neighbor)
      if (mean_score_mcc  > mcc) :
        models_mm_mcc.append(neighbor)
        print("mcc : %f" % mean_score_mcc)
        print(len(transform(X,neighbor).columns))
        print(transform(X,neighbor).columns)
        print("-----------")
        scores_mcc.append(mean_score_mcc)
        var_mcc.append(transform(X,neighbor))
        explor_mcc(neighbor, mean_score_mcc, algo)

# %%
explor_mcc(Fs,0.567764,algo)
# Out:
# mcc : 0.568514
# 31
# Index(['Volaille', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
#        'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'VarT_ann_EVI', 'Min_EVI', 'Ph1_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.569686
# 32
# Index(['Volaille', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.569867
# 33
# Index(['Volaille', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.574226
# 32
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.585139
# 33
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.575411
# 33
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN',
#        'VarT_bi_NDVI', 'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.579237
# 34
# Index(['Bovins', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN',
#        'VarT_bi_NDVI', 'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.584647
# 33
# Index(['Bovins', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
#        'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.586768
# 32
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
#        'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.585538
# 34
# Index(['Bovins', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
#        'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Isoth', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.586502
# 35
# Index(['Bovins', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
#        'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'Rugosite_Moy',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Isoth', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.587156
# 36
# Index(['Bovins', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
#        'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'Rugosite_Moy',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Isoth', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Prec_Nov', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.586502
# 35
# Index(['Bovins', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
#        'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'IR_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Isoth', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.588517
# 36
# Index(['Bovins', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN',
#        'VarT_bi_NDVI', 'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'IR_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Isoth', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.586502
# 35
# Index(['Bovins', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
#        'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'IR_Moy',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Isoth', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.587156
# 36
# Index(['Bovins', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM', 'Amp2_TempJ',
#        'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'IR_Moy',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Isoth', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Prec_Nov', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.584647
# 35
# Index(['Bovins', 'Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN',
#        'VarT_bi_NDVI', 'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Carbone',
#        'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.581359
# 34
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Min_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN',
#        'VarT_bi_NDVI', 'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Ph1_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.576023
# 34
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN',
#        'VarT_bi_NDVI', 'Ph1_NDVI', 'Ph3_NDVI', 'Moy_EVI', 'VarT_ann_EVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Substratum', 'Sol_Argile',
#        'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.581359
# 35
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN',
#        'VarT_bi_NDVI', 'Ph1_NDVI', 'Ph3_NDVI', 'Moy_EVI', 'VarT_ann_EVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Substratum', 'Sol_Argile',
#        'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill', 'Vent_Avril'],
#       dtype='object')
# -----------
# mcc : 0.581359
# 34
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN',
#        'VarT_bi_NDVI', 'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI',
#        'VarT_cy_EVI', 'Min_EVI', 'Ph1_EVI', 'Substratum', 'Sol_Argile',
#        'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.581359
# 34
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN',
#        'VarT_bi_NDVI', 'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Max_EVI', 'Ph1_EVI', 'Substratum', 'Sol_Argile',
#        'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.581359
# 34
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN',
#        'VarT_bi_NDVI', 'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile',
#        'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.586768
# 35
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.593927
# 36
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.594581
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Min_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599990
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Min_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Janv',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.601627
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Janv',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.602415
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'ZonePel', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Janv',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 39
# Index(['Ovins', 'Equides', 'Coniferes', 'ZonePel', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_ann_NDVI', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Janv', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.608478
# 40
# Index(['Ovins', 'Equides', 'Coniferes', 'ZonePel', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_ann_NDVI', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_hum',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Janv', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.608478
# 40
# Index(['Ovins', 'Equides', 'Coniferes', 'ZonePel', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_ann_NDVI', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Tmin_Oct', 'Vap_Janv', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'Amp1_EVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Janv', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599990
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Min_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Fev',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.601627
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Fev',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.602415
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'ZonePel', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Fev',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp1_TempJ', 'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ',
#        'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Fev', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_ann_NDVI', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Fev', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'Amp1_EVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Fev', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Fev',
#        'Vap_Juill', 'Vap_Nov'],
#       dtype='object')
# -----------
# mcc : 0.599990
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Min_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Avril',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Avril',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599990
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Min_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juin',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.602281
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Amp3_IRM', 'VarT_tri_IRM', 'Min_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juin',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599990
# 36
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Min_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599990
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Min_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill',
#        'Vap_Oct'],
#       dtype='object')
# -----------
# mcc : 0.601627
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill',
#        'Vap_Oct'],
#       dtype='object')
# -----------
# mcc : 0.602415
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'ZonePel', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill',
#        'Vap_Oct'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp1_TempJ', 'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ',
#        'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill', 'Vap_Oct'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_ann_NDVI', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill', 'Vap_Oct'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'Amp1_EVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill', 'Vap_Oct'],
#       dtype='object')
# -----------
# mcc : 0.599990
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Min_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill',
#        'Vap_Nov'],
#       dtype='object')
# -----------
# mcc : 0.599990
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Min_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill',
#        'Vent_Fev'],
#       dtype='object')
# -----------
# mcc : 0.595123
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'Var_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.600532
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'Var_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Tmin_Janv', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.600532
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'Var_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Mars', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.601627
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Mars',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_ann_NDVI', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Mars', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'Amp1_EVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Mars', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Mars',
#        'Vap_Juill', 'Vap_Nov'],
#       dtype='object')
# -----------
# mcc : 0.600532
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'Var_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill', 'Vap_Nov'],
#       dtype='object')
# -----------
# mcc : 0.600532
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'Var_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill', 'Vap_Dec'],
#       dtype='object')
# -----------
# mcc : 0.601627
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill',
#        'Vap_Dec'],
#       dtype='object')
# -----------
# mcc : 0.602415
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'ZonePel', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill',
#        'Vap_Dec'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 39
# Index(['Ovins', 'Equides', 'Coniferes', 'ZonePel', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_ann_NDVI', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill', 'Vap_Dec'],
#       dtype='object')
# -----------
# mcc : 0.608478
# 40
# Index(['Ovins', 'Equides', 'Coniferes', 'ZonePel', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'VarT_bi_TempN', 'Ph3_TempN', 'VarT_ann_NDVI', 'VarT_bi_NDVI',
#        'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile',
#        'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill', 'Vap_Dec'],
#       dtype='object')
# -----------
# mcc : 0.608478
# 40
# Index(['Ovins', 'Equides', 'Coniferes', 'ZonePel', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_ann_NDVI', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_hum',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill', 'Vap_Dec'],
#       dtype='object')
# -----------
# mcc : 0.608478
# 40
# Index(['Ovins', 'Equides', 'Coniferes', 'ZonePel', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_ann_NDVI', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Bio_Pre_Qhum', 'Prec_Juill', 'Vap_Juill', 'Vap_Dec'],
#       dtype='object')
# -----------
# mcc : 0.608478
# 39
# Index(['Ovins', 'Equides', 'Coniferes', 'ZonePel', 'Arbrisseau', 'Pl_herb',
#        'VegCul', 'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'Amp1_EVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill', 'Vap_Dec'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp1_TempJ', 'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ',
#        'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill', 'Vap_Dec'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'VarT_bi_TempN', 'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill', 'Vap_Dec'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill',
#        'Vap_Nov', 'Vap_Dec'],
#       dtype='object')
# -----------
# mcc : 0.599430
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'Var_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.613194
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_ann_NDVI', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'Var_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile',
#        'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.601627
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'Var_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Tint', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Tint', 'Bio_Pre_Saison', 'Prec_Juill',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.601627
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'Var_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Mai', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.607690
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Mai',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599990
# 38
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'Var_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI',
#        'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med',
#        'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill', 'Vent_Fev'],
#       dtype='object')
# -----------
# mcc : 0.605493
# 39
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ', 'Ph3_TempJ',
#        'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI',
#        'Ph3_NDVI', 'Var_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI', 'Min_EVI',
#        'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile', 'Sol_Sable',
#        'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison',
#        'Prec_Juill', 'Vap_Juill', 'Vent_Fev'],
#       dtype='object')
# -----------
# mcc : 0.605493
# 39
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ',
#        'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'Var_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile',
#        'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Vap_Juill', 'Vent_Fev'],
#       dtype='object')
# -----------
# mcc : 0.606035
# 40
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_ann_TempJ', 'VarT_bi_TempJ', 'Ph2_TempJ',
#        'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI',
#        'Ph1_NDVI', 'Ph3_NDVI', 'Var_NDVI', 'VarT_ann_EVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile',
# ...
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Juill',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Juill',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph1_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Juill',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Moy_TempN', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Juill',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Min_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Juill',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Max_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Juill',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.594469
# 36
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph3_TempN',
#        'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI', 'VarT_tri_EVI',
#        'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum', 'Sol_Argile',
#        'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy', 'Bio_Saison',
#        'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Aout', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Aout', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_ann_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Aout', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'VarT_cy_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Aout', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Min_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Aout', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Max_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Aout', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph1_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Aout', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Moy_TempN', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Aout', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Min_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Aout', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Max_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Aout', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.599972
# 37
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Max_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN', 'Ph1_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph3_NDVI', 'Var_NDVI',
#        'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI', 'Substratum',
#        'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy', 'Bio_Tj_Moy',
#        'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill', 'Tmax_Aout', 'Vap_Juill'],
#       dtype='object')
# -----------
# mcc : 0.592272
# 36
# Index(['Ovins', 'Equides', 'Coniferes', 'Arbrisseau', 'Pl_herb', 'VegCul',
#        'Moy_IRM', 'Amp3_IRM', 'VarT_tri_IRM', 'Ph1_IRM', 'Var_IRM',
#        'Moy_TempJ', 'Amp2_TempJ', 'Ph2_TempJ', 'Ph3_TempJ', 'Amp2_TempN',
#        'Ph3_TempN', 'VarT_bi_NDVI', 'VarT_cy_NDVI', 'Ph1_NDVI', 'Ph3_NDVI',
#        'Var_NDVI', 'VarT_tri_EVI', 'Min_EVI', 'Ph1_EVI', 'Var_EVI',
#        'Substratum', 'Sol_Argile', 'Sol_Sable', 'IPT_Med', 'Bio_Ta_moy',
#        'Bio_Tj_Moy', 'Bio_Saison', 'Bio_Pre_Saison', 'Prec_Juill',
#        'Vap_Juill'],
#       dtype='object')
# -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-88eafa6a58b8> in <module>
# ----> 1 explor_mcc(Fs,0.567764,algo)
#
# <ipython-input-29-05a3c622ed84> in explor_mcc(fs, mcc, algo)
#      23         scores_mcc.append(mean_score_mcc)
#      24         var_mcc.append(transform(X,neighbor))
# ---> 25         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-29-05a3c622ed84> in explor_mcc(fs, mcc, algo)
#      23         scores_mcc.append(mean_score_mcc)
#      24         var_mcc.append(transform(X,neighbor))
# ---> 25         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-29-05a3c622ed84> in explor_mcc(fs, mcc, algo)
#      23         scores_mcc.append(mean_score_mcc)
#      24         var_mcc.append(transform(X,neighbor))
# ---> 25         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-29-05a3c622ed84> in explor_mcc(fs, mcc, algo)
#      23         scores_mcc.append(mean_score_mcc)
#      24         var_mcc.append(transform(X,neighbor))
# ---> 25         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-29-05a3c622ed84> in explor_mcc(fs, mcc, algo)
#      23         scores_mcc.append(mean_score_mcc)
#      24         var_mcc.append(transform(X,neighbor))
# ---> 25         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-29-05a3c622ed84> in explor_mcc(fs, mcc, algo)
#      23         scores_mcc.append(mean_score_mcc)
#      24         var_mcc.append(transform(X,neighbor))
# ---> 25         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-29-05a3c622ed84> in explor_mcc(fs, mcc, algo)
#      23         scores_mcc.append(mean_score_mcc)
#      24         var_mcc.append(transform(X,neighbor))
# ---> 25         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-29-05a3c622ed84> in explor_mcc(fs, mcc, algo)
#      23         scores_mcc.append(mean_score_mcc)
#      24         var_mcc.append(transform(X,neighbor))
# ---> 25         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-29-05a3c622ed84> in explor_mcc(fs, mcc, algo)
#      23         scores_mcc.append(mean_score_mcc)
#      24         var_mcc.append(transform(X,neighbor))
# ---> 25         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-29-05a3c622ed84> in explor_mcc(fs, mcc, algo)
#      23         scores_mcc.append(mean_score_mcc)
#      24         var_mcc.append(transform(X,neighbor))
# ---> 25         explor_mcc(neighbor, mean_score_mcc, algo)
#
# <ipython-input-29-05a3c622ed84> in explor_mcc(fs, mcc, algo)
#      12     neighbor[i] = not fs[i]
#      13     if (neighbor not in explored_models_mcc) :
# ---> 14       score_mcc = cross_val_score(algo, transform(X, neighbor) , y, scoring=my_scorer1, cv=cv, n_jobs=-1)
#      15       mean_score_mcc = np.mean(score_mcc)
#      16       explored_models_mcc.append(neighbor)
#
# <ipython-input-17-5173102bc845> in transform(X, fs)
#       3   for i in range(len(fs)) :
#       4     if fs[i] == False :
# ----> 5       X_.drop([clmns[i]], axis=1, inplace=True)
#       6   return X_
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4184             else:
#    4185                 new_axis = axis.drop(labels, errors=errors)
# -> 4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#    4188         # Case for non-unique axis
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    4770         kwargs.pop("axis", None)
#    4771         kwargs.pop("labels", None)
# -> 4772         return super().reindex(**kwargs)
#    4773
#    4774     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4802         # if all axes that are requested to reindex are equal, then only copy
#    4803         # if indicated must have index names equal here as well as values
# -> 4804         if all(
#    4805             self._get_axis(axis).identical(ax)
#    4806             for axis, ax in axes.items()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in <genexpr>(.0)
#    4803         # if indicated must have index names equal here as well as values
#    4804         if all(
# -> 4805             self._get_axis(axis).identical(ax)
#    4806             for axis, ax in axes.items()
#    4807             if ax is not None
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in identical(self, other)
#    4817         """
#    4818         return (
# -> 4819             self.equals(other)
#    4820             and all(
#    4821                 getattr(self, c, None) == getattr(other, c, None)
#
# KeyboardInterrupt:

# %%
var_mcc
# Out:
# [       Volaille      Ovins   Equides  Coniferes  Arbrisseau  Pl_herb  VegCul  \
#  0      0.000000   0.000000  0.624435          0           0        0       0
#  1      0.000000   0.034352  0.040295          0           0        0       0
#  2      0.000000   0.034352  0.040295          0           0        0       0
#  3      0.000000   0.000000  0.269410          0           0        0       0
#  4      0.000000   0.000000  0.379107          0           0        0       0
#  ..          ...        ...       ...        ...         ...      ...     ...
#  249  105.550156  15.116930  0.698221          0          13        0      39
#  250    0.000000   0.000000  1.725019          0           0        0       0
#  251  111.459663  15.054404  0.991284          0          21        0      60
#  252    5.641273   4.306276  0.000000          0          14       12       6
#  253   15.082421   6.042903  0.595441          0           9       12      33
#
#       Moy_IRM  VarT_tri_IRM  Ph1_IRM  ...  Substratum  Sol_Argile  Sol_Sable  \
#  0       3340             0      566  ...         200   22.250000  64.833333
#  1       4010             0      581  ...         199   32.583333  52.583333
#  2       4010             0      581  ...         199   32.583333  52.583333
#  3       3580             0      600  ...         166   37.916667  51.083333
#  4       3000             0      577  ...         200   18.500000  73.333333
#  ..       ...           ...      ...  ...         ...         ...        ...
#  249     1390             0      647  ...         200   26.250000  45.500000
#  250     2050             0      593  ...         200   26.083333  39.083333
#  251     1670             0      700  ...         200   30.750000  41.333333
#  252     1070             0      660  ...         200   23.666667  40.500000
#  253     1400             0      674  ...         188   23.583333  46.250000
#
#       IPT_Med  Bio_Ta_moy  Bio_Tj_Moy  Bio_Saison  Bio_Pre_Saison  Prec_Juill  \
#  0    -0.1875   20.354167    7.125000  172.263782      105.140599           1
#  1    -0.5000   20.800000    9.816667  271.167506       77.394709           0
#  2    -0.5000   20.800000    9.816667  271.167506       77.394709           0
#  3     1.5625   20.937500    9.558333  269.975813       84.137238           0
#  4    -3.7500   21.075000    9.616666  269.473410       79.471941           0
#  ..       ...         ...         ...         ...             ...         ...
#  249   1.3125   17.904167    5.891667  450.436476       79.066686           1
#  250   1.6250   18.087500    5.225000  444.077830       75.152004           1
#  251   2.2500   17.904167    5.858334  449.244095       78.300556           1
#  252  -2.0000   17.766666    7.066666  409.996286       80.065714           1
#  253   0.3125   17.362500    6.691667  397.389906       79.895116           1
#
#       Vap_Juill
#  0         2.07
#  1         2.03
#  2         2.03
#  3         2.04
#  4         2.07
#  ..         ...
#  249       1.96
#  250       1.97
#  251       1.97
#  252       2.03
#  253       1.97
#
#  [254 rows x 31 columns],
#         Volaille      Ovins   Equides  Coniferes  Arbrisseau  Pl_herb  VegCul  \
#  
#  253   17.362500    6.691667  397.389906       79.895116           1
#
#       Tmax_Aout  Vap_Juill
#  0    26.200001       2.07
#  1    29.700001       2.03
#  2    29.700001       2.03
#  3    29.700001       2.04
#  4    29.900000       2.07
#  ..         ...        ...
#  249  27.700001       1.96
#  250  27.299999       1.97
#  251  27.600000       1.97
#  252  26.799999       2.03
#  253  26.400000       1.97
#
#  [254 rows x 37 columns],
#           Ovins   Equides  Coniferes  Arbrisseau  Pl_herb  VegCul  Moy_IRM  \
#  0     0.000000  0.624435          0           0        0       0     3340
#  1     0.034352  0.040295          0           0        0       0     4010
#  2     0.034352  0.040295          0           0        0       0     4010
#  3     0.000000  0.269410          0           0        0       0     3580
#  4     0.000000  0.379107          0           0        0       0     3000
#  ..         ...       ...        ...         ...      ...     ...      ...
#  249  15.116930  0.698221          0          13        0      39     1390
#  250   0.000000  1.725019          0           0        0       0     2050
#  251  15.054404  0.991284          0          21        0      60     1670
#  252   4.306276  0.000000          0          14       12       6     1070
#  253   6.042903  0.595441          0           9       12      33     1400
#
#       Amp3_IRM  VarT_tri_IRM  Ph1_IRM  ...  Substratum  Sol_Argile  Sol_Sable  \
#  0          50             0      566  ...         200   22.250000  64.833333
#  1          50             0      581  ...         199   32.583333  52.583333
#  2          50             0      581  ...         199   32.583333  52.583333
#  3          50             0      600  ...         166   37.916667  51.083333
#  4          10             0      577  ...         200   18.500000  73.333333
#  ..        ...           ...      ...  ...         ...         ...        ...
#  249        20             0      647  ...         200   26.250000  45.500000
#  250        10             0      593  ...         200   26.083333  39.083333
#  251        30             0      700  ...         200   30.750000  41.333333
#  252        10             0      660  ...         200   23.666667  40.500000
#  253        20             0      674  ...         188   23.583333  46.250000
#
#       IPT_Med  Bio_Ta_moy  Bio_Tj_Moy  Bio_Saison  Bio_Pre_Saison  Prec_Juill  \
#  0    -0.1875   20.354167    7.125000  172.263782      105.140599           1
#  1    -0.5000   20.800000    9.816667  271.167506       77.394709           0
#  2    -0.5000   20.800000    9.816667  271.167506       77.394709           0
#  3     1.5625   20.937500    9.558333  269.975813       84.137238           0
#  4    -3.7500   21.075000    9.616666  269.473410       79.471941           0
#  ..       ...         ...         ...         ...             ...         ...
#  249   1.3125   17.904167    5.891667  450.436476       79.066686           1
#  250   1.6250   18.087500    5.225000  444.077830       75.152004           1
#  251   2.2500   17.904167    5.858334  449.244095       78.300556           1
#  252  -2.0000   17.766666    7.066666  409.996286       80.065714           1
#  253   0.3125   17.362500    6.691667  397.389906       79.895116           1
#
#       Vap_Juill
#  0         2.07
#  1         2.03
#  2         2.03
#  3         2.04
#  4         2.07
#  ..         ...
#  249       1.96
#  250       1.97
#  251       1.97
#  252       2.03
#  253       1.97
#
#  [254 rows x 36 columns]]

# %%
lst_var=[]
lst_nbv=[]
for i in range (len(var_acc)):
  pp=set(var_acc[i].columns)
  str = ','.join(pp)
  lst_var.append(str)
  lst_nbv.append(len(var_acc[i].columns))
df = pd.DataFrame({'var': lst_var,
     'nbv': lst_nbv,
     'score_mcc': scores_accuracy
    })
df
df.to_excel("NUSVC-BACK-ACC-DFS-MCC-DFS-ACC.xlsx")
